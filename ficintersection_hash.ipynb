# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'C:\Users\paton\Pick2ReadData\ForCleansingHashtag\readawrite_ints2.csv')
df1.drop('Unnamed: 0', axis=1, inplace=True)
df1.dropna(subset=['hashtag'],inplace=True)
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#            author category commentCount isComplete numOfchap  \
# 0        พี่ติ๊ส.  นิยาย y           80        NaN         6
# 1     blacksummer  นิยาย y           44        NaN        12
# 2       garoo-pop  นิยาย y            4        NaN         1
# 3     jokerginger  นิยาย y           35        NaN         5
# 4           สีดำ?  นิยาย y          530        NaN        32
# ...           ...      ...          ...        ...       ...
# 1586           โฟ  นิยาย y            0        NaN         2
# 1587      พลาสลอน  นิยาย y            0        NaN         0
# 1588     sunday48  นิยาย y            0        NaN         0
# 1589          เบญ  นิยาย y            0        NaN         1
# 1590       Navvip  นิยาย y            1         จบ        42
#
#                                                     pic ratingCount  \
# 0     https://cdn-th.tunwalai.net/files/story/1414/6...         230
# 1     https://cdn-th.tunwalai.net/files/story/13054/...         145
# ...

# %%
df2 = pd.read_csv(r'C:\Users\paton\Pick2ReadData\ForCleansingHashtag\tunwalai_ints2.csv')
df2.drop('Unnamed: 0', axis=1, inplace=True)
df2.dropna(subset=['hashtag'],inplace=True)
df2.reset_index(drop=True, inplace=True)
#df1.drop(df1.columns[0], axis=1)
#df2.drop(df2.columns[0], axis=1)
df2
# Out:
#            author category commentCount isComplete numOfchap  \
# 0        พี่ติ๊ส.  นิยาย y           80        NaN         6
# 1     blacksummer  นิยาย y           44        NaN        12
# 2       garoo-pop  นิยาย y            4        NaN         1
# 3     jokerginger  นิยาย y           35        NaN         5
# 4           สีดำ?  นิยาย y          530        NaN        32
# ...           ...      ...          ...        ...       ...
# 1586           โฟ  นิยาย y            0        NaN         2
# 1587      พลาสลอน  นิยาย y            0        NaN         0
# 1588     sunday48  นิยาย y            0        NaN         0
# 1589          เบญ  นิยาย y            0        NaN         1
# 1590       Navvip  นิยาย y            1         จบ        42
#
#                                                     pic ratingCount  \
# 0     https://cdn-th.tunwalai.net/files/story/1414/6...         230
# 1     https://cdn-th.tunwalai.net/files/story/13054/...         145
# ...

# %%
h_df = pd.merge(df1, df2, how='inner', on=['hashtag'])
h_df
# Out:
#          author_x category_x commentCount_x isComplete_x numOfchap_x  \
# 0        พี่ติ๊ส.    นิยาย y             80          NaN           6
# 1     blacksummer    นิยาย y             44          NaN          12
# 2       garoo-pop    นิยาย y              4          NaN           1
# 3     jokerginger    นิยาย y             35          NaN           5
# 4           สีดำ?    นิยาย y            530          NaN          32
# ...           ...        ...            ...          ...         ...
# 4570           โฟ    นิยาย y              0          NaN           2
# 4571      พลาสลอน    นิยาย y              0          NaN           0
# 4572     sunday48    นิยาย y              0          NaN           0
# 4573          เบญ    นิยาย y              0          NaN           1
# 4574       Navvip    นิยาย y              1           จบ          42
#
#                                                   pic_x ratingCount_x  \
# ...

# %%
#h_df.to_csv(r'C:\Users\paton\Pick2ReadData\TwitterSearch\intersection_hash3.csv',encoding='utf-8')
h_df[['hashtag','title_x','title_y']]
# Out:
#                    hashtag                                            title_x  \
# 0             จัสยูยิมเซย์                      Just U ♥ #จัสยูยิมเซย์ [Yaoi]
# 1                พี่ครับผม             [Yaoi&NC18+] #พี่ครับ ผม(ไม่)ชอบผู้ชาย
# 2           บ่ายสองต้องรอด  [แฟนฟิค] 2 : PM Deadline...บ่ายสอง #บ่ายสองต้อ...
# 3            ฟิคเด็กเถื่อน             GOT7 WICKED #ฟิคเด็กเถื่อน { NC PART }
# 4     ร้ายนักจับทำเมียแม่ง                  #ร้ายนัก....จับทำเมียแม่ง ( 18+ )
# ...                    ...                                                ...
# 4570                วรัณยู                                 #วรัณยู | yinwar 𝐼
# 4571                 ฮาเดส  PHENOMENAL\n\nโคตรร้ายแต่ก็จะรัก#ฮาเดสxเพอร์เซ...
# 4572         ท้องฟ้าสีคราม                          SKY Blue\n #ท้องฟ้าสีคราม
# 4573              คิวเตอร์                   เพื่อน(สนิท)เลื่อนขั้น #คิวเตอร์
# 4574          ภรรยาผมดุมาก                         [Omegaverse] #ภรรยาผมดุมาก
#
# ...
