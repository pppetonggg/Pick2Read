# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'C:\Users\paton\Pick2ReadData\readawrite_ints1.csv')
df1.drop('Unnamed: 0', axis=1, inplace=True)
df1.dropna(subset=['hashtag'],inplace=True)
df1.reset_index(drop=True, inplace=True)
df1
# Out:
#             author                    category commentCount  \
# 0          mplusss  นิยาย Boy Love Secret Room        2,359
# 1     กลิ่นหอมกำจร  นิยาย Boy Love Secret Room           18
# 2     อยากกินลูกอม  นิยาย Boy Love Secret Room           30
# 3        j\'li___.  นิยาย Boy Love Lovely Room            6
# 4         Overrain  นิยาย Boy Love Lovely Room       15,500
# ...            ...                         ...          ...
# 1117  Babybaphomet  นิยาย Boy Love Lovely Room           54
# 1118     CLAZZICAL  นิยาย Boy Love Secret Room          378
# 1119          พาพา  นิยาย Boy Love Lovely Room          172
# 1120   Cinzano 505  นิยาย Boy Love Secret Room       16,331
# 1121    penguin_23  นิยาย Boy Love Lovely Room            5
#
#                                             description favouriteCount  \
# 0     'เมื่อ 3P มาแบบ 4K พูดได้คำเดียวว่างานนี้ Full...          8,158
# 1     "หลวงพี่จะสึกเมื่อไหร่ครับ" จันทร์หอมเป็นเด็กเ...             78
# 2     ใครจะไปรู้ว่าสองพี่น้องเลือดบริสุทธิ์แห่งสลิธี...             92
# 3      Shark#ฉลามอยากกินพืช: นิยาย Boy Love Lovely Room             13
# 4     ความสัมพันธ์เพียงแค่คืนเดียว เปลี่ยนชีวิตของธี...         32,697
# ...                                                 ...            ...
# 1117                            “พี่เห็นหนูด้วยเหรอคะ?”            226
# 1118  เสียงร้องไห้และกลิ่นความทุกข์ของมนุษย์ผู้หนึ่ง...            892
# 1119  "แฟนมึงนิสัยเหมือนแมวเลย เคยเป็นแมวมาก่อนปะเนี่ย"            785
# 1120  เขาเป็นคนสอนผมดื่มเหล้า สอนสูบบุหรี่ สอนกอด สอ...         23,072
# 1121  ยอมสละบัลลังก์เพื่อหลีกเลี่ยงแฟล็กความตายที่จะ...             30
#
#      isComplete  numOfchap                                                pic  \
# 0            จบ       18.0  https://cdn.readawrite.com/articles/1944/19436...
# 1            จบ        1.0  https://cdn.readawrite.com/articles/1944/19439...
# 2            จบ        3.0  https://cdn.readawrite.com/articles/1946/19450...
# 3            จบ        2.0  https://cdn.readawrite.com/articles/1954/19538...
# 4            จบ       48.0  https://cdn.readawrite.com/articles/1955/19546...
# ...         ...        ...                                                ...
# 1117         จบ        6.0  https://cdn.readawrite.com/articles/1896/18955...
# 1118         จบ       40.0  https://cdn.readawrite.com/articles/1896/18953...
# 1119         จบ        2.0  https://cdn.readawrite.com/articles/1898/18971...
# 1120         จบ       26.0  https://cdn.readawrite.com/articles/1898/18976...
# 1121         จบ        2.0  https://cdn.readawrite.com/articles/1898/18978...
#
#      ratingCount                                                tag  \
# 0          1,051  เข้ามาลึกๆ,insert here,Boy Love/Yaoi,18+,20+,น...
# 1              9                  18+,Boy Love/Yaoi,นิยายวาย,บาปหนา
# 2             24                          KhunBam,IlpyoMori,ToG,goh
# 3              4                                                NaN
# 4          5,490  Boy Love/Yaoi,Mpreg,นิยายวาย,18+,นิยายวายฟีลกู...
# ...          ...                                                ...
# 1117          32  Boy Love/Yaoi,นิยายวาย,18+,นิยายรัก,นิยายโรแมน...
# 1118         144                                                NaN
# 1119         117                                                NaN
# 1120       4,098  Boy Love/Yaoi,นิยายรัก,นิยายโรแมนติก,friends w...
# 1121           4   Boy Love/Yaoi,เกิดใหม่ในต่างโลก,ชารอนไม่ทิ้งผัก!
#
#                                                   title     viewer  \
# 0                    #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)    721,051
# 1                                            #คุณสงฆ์ขา        807
# 2     {AU Hogwarts} Slytherin twins #อิลเปียวโมริ #ค...      2,053
# 3                                  Shark#ฉลามอยากกินพืช        265
# 4     (Omegeverse) แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น...  3,098,602
# ...                                                 ...        ...
# 1117  Saturday in Mystery #เรื่องของชายที่ตายในวันเสาร์      2,669
# 1118  #รอนจะรัก Until true love fine you คำสาปร้าย.....     26,835
# 1119      Cat man #พรหนึ่งข้อผมขอให้คุณมีความสุข (yaoi)      6,365
# 1120                      UNKNOWN LOVER #เขาชื่ออันวาร์  1,340,550
# 1121  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต | #...        427
#
#                                        new_title  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4              แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น
# ...                                          ...
# 1117                                         NaN
# 1118                                         NaN
# 1119                                         NaN
# 1120                                         NaN
# 1121  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต
#
#                             hashtag
# 0                        เข้ามาลึกๆ
# 1                         คุณสงฆ์ขา
# 2                      อิลเปียวโมริ
# 3                    ฉลามอยากกินพืช
# 4                   แด๊ดดี้คลั่งรัก
# ...                             ...
# 1117   เรื่องของชายที่ตายในวันเสาร์
# 1118                       รอนจะรัก
# 1119  พรหนึ่งข้อผมขอให้คุณมีความสุข
# 1120                 เขาชื่ออันวาร์
# 1121               ชารอนอย่าทิ้งผัก
#
# [1122 rows x 14 columns]

# %%
df2 = pd.read_csv(r'C:\Users\paton\Pick2ReadData\tunwalai_ints1.csv')
df2.drop('Unnamed: 0', axis=1, inplace=True)
df2.dropna(subset=['hashtag'],inplace=True)
df2.reset_index(drop=True, inplace=True)
#df1.drop(df1.columns[0], axis=1)
#df2.drop(df2.columns[0], axis=1)
df2
# Out:
#            author category commentCount isComplete numOfchap  \
# 0        พี่ติ๊ส.  นิยาย y           80        NaN         6
# 1     blacksummer  นิยาย y           44        NaN        12
# 2       garoo-pop  นิยาย y            4        NaN         1
# 3     jokerginger  นิยาย y           35        NaN         5
# 4           สีดำ?  นิยาย y          530        NaN        32
# ...           ...      ...          ...        ...       ...
# 1604           โฟ  นิยาย y            0        NaN         2
# 1605      พลาสลอน  นิยาย y            0        NaN         0
# 1606     sunday48  นิยาย y            0        NaN         0
# 1607          เบญ  นิยาย y            0        NaN         1
# 1608       Navvip  นิยาย y            1         จบ        42
#
#                                                     pic ratingCount  \
# 0     https://cdn-th.tunwalai.net/files/story/1414/6...         230
# 1     https://cdn-th.tunwalai.net/files/story/13054/...         145
# 2     https://cdn-th.tunwalai.net/files/story/13184/...         105
# 3     https://cdn-th.tunwalai.net/files/story/13793/...         502
# 4     https://cdn-th.tunwalai.net/files/story/15008/...         351
# ...                                                 ...         ...
# 1604  https://cdn-th.tunwalai.net/files/story/508398...           0
# 1605  https://cdn-th.tunwalai.net/files/story/508411...           5
# 1606  https://cdn-th.tunwalai.net/files/story/508820...           0
# 1607  https://cdn-th.tunwalai.net/files/story/508838...           0
# 1608  https://cdn-th.tunwalai.net/files/story/508860...           3
#
#                                                     tag  \
# 0              yaoi,มัธยม,นิยายy,ชายรักชาย,จัสยูยิมเซย์
# 1                Yaoi , พี่ครับ ผม(ไม่)ชอบผู้ชาย , R18+
# 2                               2pm, fic, Yaoi, Fic2pm,
# 3             got7,markbam,yaoi,bnior,jackjae,yuglee,nc
# 4                             ร้ายนัก!....จับทำเมียแม่ง
# ...                                                 ...
# 1604        หยิ่นวอร์,พร้อมเบนซ์,เจฟเซฟ,บอนซ์วิน,วรัณยู
# 1605  โครตร้ายแต่ก็จะรัก,ฮาเดสxเพอร์เซโฟนี,แอดไฟ,พลา...
# 1606  อาม่าน,นิยายวาย,yaoi,รักโรแมนติก,sky,blue,ท้อง...
# 1607                                           คิวเตอร์
# 1608                                       ภรรยาผมดุมาก
#
#                                                   title   viewer  \
# 0                         Just U ♥ #จัสยูยิมเซย์ [Yaoi]   58,676
# 1                [Yaoi&NC18+] #พี่ครับ ผม(ไม่)ชอบผู้ชาย   29,144
# 2     [แฟนฟิค] 2 : PM Deadline...บ่ายสอง #บ่ายสองต้อ...    2,415
# 3                GOT7 WICKED #ฟิคเด็กเถื่อน { NC PART }  105,536
# 4                    #ร้ายนัก!....จับทำเมียแม่ง ( 18+ )  515,608
# ...                                                 ...      ...
# 1604                                 #วรัณยู | yinwar 𝐼      168
# 1605  PHENOMENAL\n\nโคตรร้ายแต่ก็จะรัก#ฮาเดสxเพอร์เซ...        7
# 1606                          SKY Blue\n #ท้องฟ้าสีคราม        1
# 1607                   เพื่อน(สนิท)เลื่อนขั้น #คิวเตอร์       34
# 1608                         [Omegaverse] #ภรรยาผมดุมาก    1,417
#
#                new_title         hashtag
# 0                    NaN    จัสยูยิมเซย์
# 1                    NaN       พี่ครับผม
# 2                 แฟนฟิค  บ่ายสองต้องรอด
# 3                    NaN   ฟิคเด็กเถื่อน
# 4                    NaN         ร้ายนัก
# ...                  ...             ...
# 1604                 NaN          วรัณยู
# 1605  โคตรร้ายแต่ก็จะรัก           ฮาเดส
# 1606                 NaN   ท้องฟ้าสีคราม
# 1607              เพื่อน        คิวเตอร์
# 1608                 NaN    ภรรยาผมดุมาก
#
# [1609 rows x 12 columns]

# %%
h_df = pd.merge(df1, df2, how='inner', on=['hashtag'])
h_df
# Out:
#                 author_x                  category_x commentCount_x  \
# 0                mplusss  นิยาย Boy Love Secret Room          2,359
# 1    รองเท้าแตะข้างเดียว  นิยาย Boy Love Secret Room             27
# 2    รองเท้าแตะข้างเดียว  นิยาย Boy Love Secret Room             27
# 3    รองเท้าแตะข้างเดียว  นิยาย Boy Love Secret Room             27
# 4    รองเท้าแตะข้างเดียว  นิยาย Boy Love Secret Room             27
# ..                   ...                         ...            ...
# 246        SS.Persimmons  นิยาย Boy Love Secret Room            336
# 247           ladyjairan  นิยาย Boy Love Secret Room            189
# 248            Howlsairy  นิยาย Boy Love Secret Room          1,834
# 249            CLAZZICAL  นิยาย Boy Love Secret Room            378
# 250                 พาพา  นิยาย Boy Love Lovely Room            172
#
#                                            description favouriteCount  \
# 0    'เมื่อ 3P มาแบบ 4K พูดได้คำเดียวว่างานนี้ Full...          8,158
# 1    เปรม : เค้าคือพี่ชายของเพื่อนสนิทผม เค้ามีแฟนแ...            131
# 2    เปรม : เค้าคือพี่ชายของเพื่อนสนิทผม เค้ามีแฟนแ...            131
# 3    เปรม : เค้าคือพี่ชายของเพื่อนสนิทผม เค้ามีแฟนแ...            131
# 4    เปรม : เค้าคือพี่ชายของเพื่อนสนิทผม เค้ามีแฟนแ...            131
# ..                                                 ...            ...
# 246  ใครจะไปรู้ว่านายแบบวาบหวิวชื่อดังที่มีสมาชิกใน...          1,314
# 247  ผม หญิง ผู้ชายตัวเล็กตูดใหญ่ เด็กเรียนที่ใครๆไ...            839
# 248  "มึงชอบอากาศร้อนมั้ยวะ?" "ไม่อะ กูชอบหนาวมากกว...          3,029
# 249  เสียงร้องไห้และกลิ่นความทุกข์ของมนุษย์ผู้หนึ่ง...            892
# 250  "แฟนมึงนิสัยเหมือนแมวเลย เคยเป็นแมวมาก่อนปะเนี่ย"            785
#
#     isComplete_x  numOfchap_x  \
# 0             จบ         18.0
# 1             จบ         31.0
# 2             จบ         31.0
# 3             จบ         31.0
# 4             จบ         31.0
# ..           ...          ...
# 246           จบ         29.0
# 247           จบ         12.0
# 248           จบ         19.0
# 249           จบ         40.0
# 250           จบ          2.0
#
#                                                  pic_x ratingCount_x  \
# 0    https://cdn.readawrite.com/articles/1944/19436...         1,051
# 1    https://cdn.readawrite.com/articles/1957/19565...            16
# 2    https://cdn.readawrite.com/articles/1957/19565...            16
# 3    https://cdn.readawrite.com/articles/1957/19565...            16
# 4    https://cdn.readawrite.com/articles/1957/19565...            16
# ..                                                 ...           ...
# 246  https://cdn.readawrite.com/articles/1908/19071...           143
# 247  https://cdn.readawrite.com/articles/1909/19088...            92
# 248  https://cdn.readawrite.com/articles/1890/18894...           682
# 249  https://cdn.readawrite.com/articles/1896/18953...           144
# 250  https://cdn.readawrite.com/articles/1898/18971...           117
#
#                                                  tag_x  ... category_y  \
# 0    เข้ามาลึกๆ,insert here,Boy Love/Yaoi,18+,20+,น...  ...    นิยาย y
# 1                                                  NaN  ...    นิยาย y
# 2                                                  NaN  ...    นิยาย y
# 3                                                  NaN  ...    นิยาย y
# 4                                                  NaN  ...    นิยาย y
# ..                                                 ...  ...        ...
# 246  Boy Love/Yaoi,นิยายวาย,18+,PWP,Onlyfans,พี่ครั...  ...    นิยาย y
# 247                                    18+,SM,โรงเรียน  ...    นิยาย y
# 248                                   ช่วงนี้เดือนหนาว  ...    นิยาย y
# 249                                                NaN  ...    นิยาย y
# 250                                                NaN  ...    นิยาย y
#
#     commentCount_y isComplete_y numOfchap_y  \
# 0               25          NaN          18
# 1                0          NaN           2
# 2               40          NaN          12
# 3                0          NaN           7
# 4                2           จบ          19
# ..             ...          ...         ...
# 246             42           จบ          29
# 247             42          NaN          12
# 248            267          NaN          19
# 249             55          NaN          30
# 250              0          NaN           2
#
#                                                  pic_y ratingCount_y  \
# 0    https://cdn-th.tunwalai.net/files/story/478050...            71
# 1    https://cdn-th.tunwalai.net/files/story/273047...            18
# 2    https://cdn-th.tunwalai.net/files/story/382814...            60
# 3    https://cdn-th.tunwalai.net/files/story/405767...            45
# 4    https://cdn-th.tunwalai.net/files/story/443240...            23
# ..                                                 ...           ...
# 246  https://cdn-th.tunwalai.net/files/story/472553...            77
# 247  https://cdn-th.tunwalai.net/files/story/471361...           137
# 248  https://cdn-th.tunwalai.net/files/story/469259...           499
# 249  https://cdn-th.tunwalai.net/files/story/475078...           158
# 250  https://cdn-th.tunwalai.net/files/story/490889...             2
#
#                                                  tag_y  \
# 0                                                  NaN
# 1                                                  NaN
# 2                             บุ๋นเปรม,bounprem,วินทีม
# 3    บุ๋นเปรม,วินทีม,โอห์มฟลุ๊ค,ดีนภาม,วิศวะ,รักวุ่...
# 4                                             บุ๋นเปรม
# ..                                                 ...
# 246  Yaoi, PWP, NC20+, Onlyfans, พี่ครับเบานะ, น้อง...
# 247                        Bdsm,Rape,ข่มขืน,แรด,น้ำกาม
# 248                                   ช่วงนี้เดือนหนาว
# 249                                                NaN
# 250                                                NaN
#
#                                                title_y viewer_y  \
# 0                  #เข้ามาลึกๆ #SideXL (3P,BDSMบางตอน)   24,311
# 1                          อาทิตย์ตอนกลางวัน #บุ๋นเปรม    1,359
# 2                             เด็กเฮียเบียร์ #บุ๋นเปรม   38,613
# 3                        รักวุ่นวายของนายปี1 #บุ๋นเปรม    2,586
# 4                             เพื่อนกันมั้ย? #บุ๋นเปรม    3,899
# ..                                                 ...      ...
# 246                 [ฺBL] #พี่ครับเบานะ (NC20+ ทุกตอน)   59,094
# 247                                            #น้ำกาม   40,927
# 248                                  #ช่วงนี้เดือนหนาว   64,797
# 249  #รอนจะรัก Until true love finds you คำสาปร้าย....   32,960
# 250      Cat man #พรหนึ่งข้อผมขอให้คุณมีความสุข (yaoi)      140
#
#             new_title_y
# 0                   NaN
# 1     อาทิตย์ตอนกลางวัน
# 2        เด็กเฮียเบียร์
# 3    รักวุ่นวายของนายปี
# 4         เพื่อนกันมั้ย
# ..                  ...
# 246                   ฺ
# 247                 NaN
# 248                 NaN
# 249                 NaN
# 250                 NaN
#
# [251 rows x 25 columns]

# %%
#h_df.to_csv('hash_intersection1.csv',encoding='utf-8')
h_df[['hashtag','title_x','title_y']]
# Out:
#                            hashtag  \
# 0                       เข้ามาลึกๆ
# 1                         บุ๋นเปรม
# 2                         บุ๋นเปรม
# 3                         บุ๋นเปรม
# 4                         บุ๋นเปรม
# ..                             ...
# 246                   พี่ครับเบานะ
# 247                         น้ำกาม
# 248               ช่วงนี้เดือนหนาว
# 249                       รอนจะรัก
# 250  พรหนึ่งข้อผมขอให้คุณมีความสุข
#
#                                                title_x  \
# 0                   #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)
# 1                              รักคนมีเจ้าของ#บุ๋นเปรม
# 2                              รักคนมีเจ้าของ#บุ๋นเปรม
# 3                              รักคนมีเจ้าของ#บุ๋นเปรม
# 4                              รักคนมีเจ้าของ#บุ๋นเปรม
# ..                                                 ...
# 246                                 [BL] #พี่ครับเบานะ
# 247                                            #น้ำกาม
# 248                                  #ช่วงนี้เดือนหนาว
# 249  #รอนจะรัก Until true love fine you คำสาปร้าย.....
# 250      Cat man #พรหนึ่งข้อผมขอให้คุณมีความสุข (yaoi)
#
#                                                title_y
# 0                  #เข้ามาลึกๆ #SideXL (3P,BDSMบางตอน)
# 1                          อาทิตย์ตอนกลางวัน #บุ๋นเปรม
# 2                             เด็กเฮียเบียร์ #บุ๋นเปรม
# 3                        รักวุ่นวายของนายปี1 #บุ๋นเปรม
# 4                             เพื่อนกันมั้ย? #บุ๋นเปรม
# ..                                                 ...
# 246                 [ฺBL] #พี่ครับเบานะ (NC20+ ทุกตอน)
# 247                                            #น้ำกาม
# 248                                  #ช่วงนี้เดือนหนาว
# 249  #รอนจะรัก Until true love finds you คำสาปร้าย....
# 250      Cat man #พรหนึ่งข้อผมขอให้คุณมีความสุข (yaoi)
#
# [251 rows x 3 columns]
