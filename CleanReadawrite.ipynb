# %%
import pandas as pd
import numpy as np
import string
import re

df = pd.read_csv(r'C:\Users\paton\Pick2ReadData\Data\readawrite1.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=103075, step=1)

# %%
df.dropna(subset=['title', 'category','author'],inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop_duplicates()

wordlist = '&#039;|&amp;|&bull;|&hearts;|&quot;|&lt;'
df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

df['title'] = df['title'].str.replace(wordlist, '')
df['author'] = df['author'].str.replace(wordlist, '')
df['category'] = df['category'].str.replace(wordlist, '')


#df[['title','author']] = df[['title','author']].replace(wordlist, '')
df
# Out:
#                 author                            category commentCount  \
# 0               feiing                         คาเฟ่อมยิ้ม           73
# 1       i3ananasociety               นิยาย Girl Love/ Yuri          195
# 2       ทิฟฟานี่มหาศาล                          แฟนฟิคชั่น          278
# 3              ว่านนรี               นิยายรักสำหรับผู้ใหญ่            3
# 4                   Ms       นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล            0
# ...                ...                                 ...          ...
# 103070         จั๊ซซี่               นิยายรักสำหรับผู้ใหญ่            8
# 103071   Dany_Daenerys                     ลิปสติกสีลิลลี่            9
# 103072      RITSUko_t’                     ลิปสติกสีลิลลี่          402
# 103073       bluemoonu                       ชุมชนคนขี้ชิป            4
# 103074         Chonlyt  นิยายลึกลับ/เขย่าขวัญ/สืบสวนสอบสวน            1
#
#                                               description favouriteCount  \
# 0                         เธอเก่งเรื่องทำให้คนกลายเป็นหมา            182
# 1       อยู่ๆ เจนนิเฟอร์ก็หายตัวไป ผู้หมวดเคซีย์พยายาม...            593
# 2       น้องพรีมแกล้งปวดฟันได้ไหมคะ แล้วอาพีชจะได้พาไป...            502
# 3       (ทดลองอ่าน) ความใคร่และตัณหานำมาซึ่งทุกอย่าง เ...             45
# 4         ศึกสงครามแห่งคอส: นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล              0
# ...                                                   ...            ...
# 103070  ลิลลี่เด้กสาวจอมแก่นต้องมาจับคู่อยู่บ้านชายคาเ...             36
# 103071  "ทำไมมึงไปร้านนั่นบ่อยจังวะ" "ที่นั่นมีหนังสือ...             38
# 103072  จะสงครามขนมปี๊บหรืออะไรก็แล้วแต่ กูไม่มีทางแพ้...             96
# 103073  เหอะ เธอก็ไม่ได้น่ารักขนาดนั้นมั้ย เธออย่ามาเบ...             18
# 103074  ความรักเปรียบเสมือนดอกไม้ที่มีกลิ่นหอม ดึงดูด ...              0
#
#        isComplete  numOfchap  \
# 0              จบ        7.0
# 1              จบ        7.0
# 2              จบ       16.0
# 3              จบ        4.0
# 4              จบ        5.0
# ...           ...        ...
# 103070         จบ        2.0
# 103071         จบ        3.0
# 103072         จบ       77.0
# 103073         จบ        0.0
# 103074         จบ        1.0
#
#                                                       pic ratingCount  \
# 0       https://cdn.readawrite.com/articles/1942/19419...          43
# 1       https://cdn.readawrite.com/articles/1942/19419...         118
# 2       https://cdn.readawrite.com/articles/1943/19420...         104
# 3       https://cdn.readawrite.com/articles/1943/19420...           2
# 4       https://cdn.readawrite.com/articles/1943/19420...           0
# ...                                                   ...         ...
# 103070  https://cdn.readawrite.com/articles/1898/18978...           7
# 103071  https://cdn.readawrite.com/articles/1898/18978...           6
# 103072  https://cdn.readawrite.com/articles/1898/18978...          47
# 103073  https://cdn.readawrite.com/articles/1898/18978...           4
# 103074  https://cdn.readawrite.com/articles/1898/18978...           1
#
#                                                       tag  \
# 0       อัตสึคาเง,อัตโทบ,AtsuKage,HIKYUU,ไฮคิวคู่ตบฟ้า...
# 1       Girl Love/Yuri,Yuri,หญิงรักหญิง,นิยายรัก,นิยาย...
# 2       SNSD,Tiffany,Taeyeon,Girl Love/Yuri,Taeny,Taey...
# 3                                                 อีโรติก
# 4                                                     NaN
# ...                                                   ...
# 103070  25+,Erotic,อีโรติก / erotic,นิยายโรมานซ์,นิยาย...
# 103071  ซึลรีน,ไอรีน,ซึลกิ,ซึลกิไอรีน,RedVelvet,suelre...
# 103072  เรลกัน,Railgun,Index,อินเดกซ์,มิโคมิซา,ยูริ,Yu...
# 103073                     Oikage,Haikyuu,Haikyuu AU thai
# 103074                              สืบสวน,ดราม่า,ความรัก
#
#                                             title     viewer
# 0                            น้องทับคะ | atsukage    172,357
# 1                           GONE ก่อ•การ•ลัก(รัก)     10,442
# 2                       ช่วยด้วยหมอสวยมาก [TAENY]     22,309
# 3                                   สอนสวาทพี่สาว      6,469
# 4                                ศึกสงครามแห่งคอส         28
# ...                                           ...        ...
# 103070  คู่ป่วนชวนรัก (NC+++) [Flower The Series]      3,204
# 103071                ร้านหนังสือที่ขายแต่ความรัก     29,188
# 103072   เสียตังค์ไม่ว่าเสียหน้าไม่ได้ (MikoMisa)  3,663,476
# 103073                 ( HQ ) เมลเป็นแมว — oikage          0
# 103074                              ความรักสองเรา         21
#
# [103075 rows x 12 columns]

# %%
#df.to_csv('readawrite.csv',encoding='utf-8')
df[df['title'].str.contains('อารัญ')]
# Out:
#                 author                    category commentCount  \
# 1565        Zoufflé-le  นิยาย Boy Love Secret Room            0
# 3169            จางจาง               ชุมชนคนขี้ชิป           15
# 17937       จิรัฐติกาล                    นิยายรัก            1
# 27894  พระเพื่อนพระแพง                   คืนโหยหวน           33
# 39410      Allrenlover                  แฟนฟิคชั่น           15
#
#                                              description favouriteCount  \
# 1565   นิยายไม่สนุกแต่รับวาดรูปนะคะ ติดต่อได้สองเฟสทั...              1
# 3169               บ่ลืมบ่จางรักสองเรา ยังไม่ลืมเลือนหาย             38
# 17937  พ่อแม่เธอถูกทำร้ายจนตาย ทางเดียวที่เธอจะล้างแค...              9
# 27894         แกเคยได้ยินเรื่องเล่าของป่าแห่งนั้นรึเปล่า            294
# 39410  'จะเป็นเช่นไรหากอาคาสะความทรงจำขาดห้วงลืมเลือน...             39
#
#       isComplete  numOfchap  \
# 1565          จบ        2.0
# 3169          จบ       19.0
# 17937         จบ        8.0
# 27894         จบ        2.0
# 39410         จบ        1.0
#
#                                                      pic ratingCount  \
# 1565   https://cdn.readawrite.com/articles/1959/19585...           0
# 3169   https://cdn.readawrite.com/articles/1972/19718...           5
# 17937  https://cdn.readawrite.com/articles/2061/20601...           1
# 27894  https://cdn.readawrite.com/articles/2203/22028...          20
# 39410  https://cdn.readawrite.com/articles/2292/22915...          12
#
#                                                      tag             title  \
# 1565                                                 NaN     #อารัญกับหนาว
# 3169                               kookv,กุกวี,เจ้าอารัญ  เจ้าอารัญ |kookv
# 17937                                                NaN  ยอดดวงใจของอารัญ
# 27894                                   jaeten,ศพอารัญjt  ศพอารัญ | jaeten
# 39410  Kimetsu no Yaiba,akaren,KNYfanfiction,ฟิคKNY,R...     อารัญลืมเลือน
#
#        viewer
# 1565      102
# 3169   40,144
# 17937     416
# 27894  48,666
# 39410     658

# %%
df[df['author'].str.contains('') == False]
# Out:
# Empty DataFrame
# Columns: [author, category, commentCount, description, favouriteCount, isComplete, numOfchap, pic, ratingCount, tag, title, viewer]
# Index: []

# %%
#delete common word
df2 = df
commonword = ['นิยายแปล','เรื่องสั้น','รวมฉาก','อ่านฟรี','!','จบ','จบแล้วจ้า','ตอนพิเศษ','ทดลองอ่าน','18+']
wordcut = '|'.join(commonword)
df2['title'] = df2['title'].str.replace(wordcut,'')
df2
df2[df2['category'].str.contains('Lovely|Secret')]
# Out:
#                 author                    category commentCount  \
# 1565        Zoufflé-le  นิยาย Boy Love Secret Room            0
# 3169            จางจาง               ชุมชนคนขี้ชิป           15
# 17937       จิรัฐติกาล                    นิยายรัก            1
# 27894  พระเพื่อนพระแพง                   คืนโหยหวน           33
# 39410      Allrenlover                  แฟนฟิคชั่น           15
#
#                                              description favouriteCount  \
# 1565   นิยายไม่สนุกแต่รับวาดรูปนะคะ ติดต่อได้สองเฟสทั...              1
# 3169               บ่ลืมบ่จางรักสองเรา ยังไม่ลืมเลือนหาย             38
# 17937  พ่อแม่เธอถูกทำร้ายจนตาย ทางเดียวที่เธอจะล้างแค...              9
# 27894         แกเคยได้ยินเรื่องเล่าของป่าแห่งนั้นรึเปล่า            294
# 39410  'จะเป็นเช่นไรหากอาคาสะความทรงจำขาดห้วงลืมเลือน...             39
#
#       isComplete  numOfchap  \
# 1565          จบ        2.0
# 3169          จบ       19.0
# 17937         จบ        8.0
# 27894         จบ        2.0
# 39410         จบ        1.0
#
#                                                      pic ratingCount  \
# 1565   https://cdn.readawrite.com/articles/1959/19585...           0
# 3169   https://cdn.readawrite.com/articles/1972/19718...           5
# 17937  https://cdn.readawrite.com/articles/2061/20601...           1
# 27894  https://cdn.readawrite.com/articles/2203/22028...          20
# 39410  https://cdn.readawrite.com/articles/2292/22915...          12
#
#                                                      tag             title  \
# 1565                                                 NaN     #อารัญกับหนาว
# 3169                               kookv,กุกวี,เจ้าอารัญ  เจ้าอารัญ |kookv
# 17937                                                NaN  ยอดดวงใจของอารัญ
# 27894                                   jaeten,ศพอารัญjt  ศพอารัญ | jaeten
# 39410  Kimetsu no Yaiba,akaren,KNYfanfiction,ฟิคKNY,R...     อารัญลืมเลือน
#
#        viewer
# 1565      102
# 3169   40,144
# 17937     416
# 27894  48,666
# 39410     658

# %%
df3 = pd.DataFrame(df2.title.str.split(r'#.*?(?=\S|$)',1).tolist(), 
                         columns = ['new_title','hashtag'])
df3['new_title'] = df3['new_title'].str.replace(' ', '')
df3['hashtag'] = df3['hashtag'].str.replace(' ', '')

df3['new_title'] = df3['new_title'].str.replace('.', '')
df3['hashtag'] = df3['hashtag'].str.replace('.', '')

#df[['new_title','hashtag']] = df.title.str.split(r'#.*?(?=\s|$)',expand = True) 

df3['hashtag'] = df3['hashtag'].str.extract(r'([\ก-\๙]+)')
df3['new_title'] = df3['new_title'].str.extract(r'([\ก-\๙]+)')

df_nodup = df3.drop_duplicates(subset=['hashtag'], keep=False)
df_nodup.reset_index(drop=True, inplace=True)
#df3[df3['hashtag'].str.contains('รักร้าย') == True]
df_nodup[df_nodup['hashtag'].str.contains('') == True]
# Out:
#                                        new_title  \
# 0          ถ้ามึงดูแลคนของมึงไม่ได้กูก็จะดูแลเอง
# 1                                            NaN
# 2                                 รักนะยัยมาเฟีย
# 3                                            NaN
# 4                                กับดักรักดวงดาว
# ...                                          ...
# 5431                                         NaN
# 5432                                         NaN
# 5433                                         NaN
# 5434                                         NaN
# 5435  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต
#
#                                           hashtag
# 0                                   คุณสามีที่รัก
# 1                                    แฟนผมเป็นแงว
# 2                                          กุกลิส
# 3                                     ทางกลับบ้าน
# 4                                 กับดักรักแจ็คแจ
# ...                                           ...
# 5431                                   จิวนิวจิ๋ว
# 5432                                  อินซมชางซึง
# 5433  จะชิปเป้กับใครก็ได้แต่จะชิปให้เป้เห็นไม่ได้
# 5434                               เขาชื่ออันวาร์
# 5435                             ชารอนอย่าทิ้งผัก
#
# [5436 rows x 2 columns]

# %%
df3[df3['new_title'].str.contains('ช่วยผมด้วย', na=False)]
# Out:
#                               new_title hashtag
# 10269                   เมตตาช่วยผมด้วย     NaN
# 20386             ช่วยผมด้วยผมโดนข่มขืน     NaN
# 28103  ช่วยผมด้วยครับผมโดนบังคับแต่งงาน     NaN
# 42394             ช่วยผมด้วยผมโดนแอบชอบ     NaN
# 43846                     เจ๊ช่วยผมด้วย     NaN
# 56271             เจ้าที่ครับช่วยผมด้วย     NaN

# %%
boyslove[boyslove['hashtag'].str.contains('ป๋อจ้าน') == True]
#df3.to_csv('readawrite_hashtag.csv')
# Out:
# Empty DataFrame
# Columns: [author, category, commentCount, description, favouriteCount, isComplete, numOfchap, pic, ratingCount, tag, title, viewer, new_title, hashtag]
# Index: []

# %%
df4 = df.join(df3)

#no duplicate for hashtag
df4_nodup = df4.drop_duplicates(subset=['hashtag'], keep=False)
df4_nodup[df4_nodup['hashtag'].str.contains('') == True]
df4_nodup = df4_nodup[df4_nodup['category'].str.contains('Lovely|Secret')]
df4_nodup.reset_index(drop=True, inplace=True)

df4_nodup
#df4_nodup[df4_nodup['title'].str.contains('เกียร์พันสิงห์')]
#df4
# Out:
#              author                    category commentCount  \
# 0           mplusss  นิยาย Boy Love Secret Room        2,359
# 1      กลิ่นหอมกำจร  นิยาย Boy Love Secret Room           18
# 2         j\'li___.  นิยาย Boy Love Lovely Room            6
# 3          Overrain  นิยาย Boy Love Lovely Room       15,500
# 4     navybroccoli.  นิยาย Boy Love Lovely Room           32
# ...             ...                         ...          ...
# 1038   Babybaphomet  นิยาย Boy Love Lovely Room           54
# 1039      CLAZZICAL  นิยาย Boy Love Secret Room          378
# 1040           พาพา  นิยาย Boy Love Lovely Room          172
# 1041    Cinzano 505  นิยาย Boy Love Secret Room       16,331
# 1042     penguin_23  นิยาย Boy Love Lovely Room            5
#
#                                             description favouriteCount  \
# 0     'เมื่อ 3P มาแบบ 4K พูดได้คำเดียวว่างานนี้ Full...          8,158
# 1     "หลวงพี่จะสึกเมื่อไหร่ครับ" จันทร์หอมเป็นเด็กเ...             78
# 2      Shark#ฉลามอยากกินพืช: นิยาย Boy Love Lovely Room             13
# 3     ความสัมพันธ์เพียงแค่คืนเดียว เปลี่ยนชีวิตของธี...         32,697
# 4                คุณอยากมาดูอควาเรี่ยมตอนเที่ยงคืนมั้ย?             93
# ...                                                 ...            ...
# 1038                            “พี่เห็นหนูด้วยเหรอคะ?”            226
# 1039  เสียงร้องไห้และกลิ่นความทุกข์ของมนุษย์ผู้หนึ่ง...            892
# 1040  "แฟนมึงนิสัยเหมือนแมวเลย เคยเป็นแมวมาก่อนปะเนี่ย"            785
# 1041  เขาเป็นคนสอนผมดื่มเหล้า สอนสูบบุหรี่ สอนกอด สอ...         23,072
# 1042  ยอมสละบัลลังก์เพื่อหลีกเลี่ยงแฟล็กความตายที่จะ...             30
#
#      isComplete  numOfchap                                                pic  \
# 0            จบ       18.0  https://cdn.readawrite.com/articles/1944/19436...
# 1            จบ        1.0  https://cdn.readawrite.com/articles/1944/19439...
# 2            จบ        2.0  https://cdn.readawrite.com/articles/1954/19538...
# 3            จบ       48.0  https://cdn.readawrite.com/articles/1955/19546...
# 4            จบ        1.0  https://cdn.readawrite.com/articles/1957/19568...
# ...         ...        ...                                                ...
# 1038         จบ        6.0  https://cdn.readawrite.com/articles/1896/18955...
# 1039         จบ       40.0  https://cdn.readawrite.com/articles/1896/18953...
# 1040         จบ        2.0  https://cdn.readawrite.com/articles/1898/18971...
# 1041         จบ       26.0  https://cdn.readawrite.com/articles/1898/18976...
# 1042         จบ        2.0  https://cdn.readawrite.com/articles/1898/18978...
#
#      ratingCount                                                tag  \
# 0          1,051  เข้ามาลึกๆ,insert here,Boy Love/Yaoi,18+,20+,น...
# 1              9                  18+,Boy Love/Yaoi,นิยายวาย,บาปหนา
# 2              4                                                NaN
# 3          5,490  Boy Love/Yaoi,Mpreg,นิยายวาย,18+,นิยายวายฟีลกู...
# 4             23  Midnight aquarium,อควาเรี่ยมเที่ยงคืน,boyslove...
# ...          ...                                                ...
# 1038          32  Boy Love/Yaoi,นิยายวาย,18+,นิยายรัก,นิยายโรแมน...
# 1039         144                                                NaN
# 1040         117                                                NaN
# 1041       4,098  Boy Love/Yaoi,นิยายรัก,นิยายโรแมนติก,friends w...
# 1042           4   Boy Love/Yaoi,เกิดใหม่ในต่างโลก,ชารอนไม่ทิ้งผัก!
#
#                                                   title     viewer  \
# 0                    #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)    721,051
# 1                                            #คุณสงฆ์ขา        807
# 2                                  Shark#ฉลามอยากกินพืช        265
# 3     (Omegeverse) แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น...  3,098,602
# 4                Midnight aquarium #อควาเรี่ยมเที่ยงคืน      1,326
# ...                                                 ...        ...
# 1038  Saturday in Mystery #เรื่องของชายที่ตายในวันเสาร์      2,669
# 1039  #รอนจะรัก Until true love fine you คำสาปร้าย.....     26,835
# 1040      Cat man #พรหนึ่งข้อผมขอให้คุณมีความสุข (yaoi)      6,365
# 1041                      UNKNOWN LOVER #เขาชื่ออันวาร์  1,340,550
# 1042  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต | #...        427
#
#                                        new_title  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3              แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น
# 4                                            NaN
# ...                                          ...
# 1038                                         NaN
# 1039                                         NaN
# 1040                                         NaN
# 1041                                         NaN
# 1042  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต
#
#                             hashtag
# 0                        เข้ามาลึกๆ
# 1                         คุณสงฆ์ขา
# 2                    ฉลามอยากกินพืช
# 3                   แด๊ดดี้คลั่งรัก
# 4               อควาเรี่ยมเที่ยงคืน
# ...                             ...
# 1038   เรื่องของชายที่ตายในวันเสาร์
# 1039                       รอนจะรัก
# 1040  พรหนึ่งข้อผมขอให้คุณมีความสุข
# 1041                 เขาชื่ออันวาร์
# 1042               ชารอนอย่าทิ้งผัก
#
# [1043 rows x 14 columns]

# %%
#df4.to_csv('readawrite_full_hash_set6.csv')
#df4_nodup.to_csv(r'C:\Users\paton\Pick2ReadData\TwitterSearch\readawrite_hash_nodup_3.csv')
df4_nodup['hashtag'].count()
# Out:
# 1043

# %%
boyslove = df4[df4['category'].str.contains('Lovely|Secret')]
boyslove.reset_index(drop=True, inplace=True)
ship = ['บุ๋นเปรม','ไบร์ทวิน','จ้านเกอ','โชซอก','ป๋อตี้จ้านเกอ','ไคฮุน','ชานแบค','กุกมิน','โยซอก','ป๋อจ้าน','จ้านป๋อ','กุกวี','แจโด','ซึงพโย','มาร์คแบม','แจ็คแจ','ปมนยอง','วีกุก','ออฟกัน','บกพพ','บิวกิ้นพีพี','วีมิน','คั่นกู','กันออฟ','แบมมาร์ค','เนียลอง','ซีเฉิง','ซึงยอนซอก']
boyslove = boyslove[~boyslove.hashtag.str.contains('|'.join(ship), na=False)]
#boyslove.to_csv(r'C:\Users\paton\Pick2ReadData\BoysloveFiltered\readawrite_y5.csv',encoding='utf-8')

test = pd.read_csv(r'C:\Users\paton\Pick2ReadData\BoysloveFiltered\readawrite_y4.csv')
test
# Out:
#        Unnamed: 0                   author                    category  \
# 0               0          ไก่ทอดมาแล้วจ้า  นิยาย Boy Love Lovely Room
# 1               1              Violet Rain  นิยาย Boy Love Lovely Room
# 2               2  ชายผู้ไม่มีปากกาน้ำเงิน  นิยาย Boy Love Lovely Room
# 3               3             ลูกหมูสามตัว  นิยาย Boy Love Secret Room
# 4               4            หัวยุ่ง ฟูเอง  นิยาย Boy Love Secret Room
# ...           ...                      ...                         ...
# 15221       15248                TJ Tommys  นิยาย Boy Love Lovely Room
# 15222       15249                 เรียลหริ  นิยาย Boy Love Lovely Room
# 15223       15250              pedseyellow  นิยาย Boy Love Lovely Room
# 15224       15251             EuraysiaSama  นิยาย Boy Love Secret Room
# 15225       15252               penguin_23  นิยาย Boy Love Lovely Room
#
#       commentCount                                        description  \
# 0            1,460  "ที่ผมกินลูกอมจนฟันผุ ก็แค่ข้ออ้างที่อยากมาหาพ...
# 1              119  ผมไม่แน่ใจว่ามันเกิดขึ้นได้ยังไง แต่ทุกครั้งที...
# 2                1  ย่อมแน่ล่ะ เขตไทม์โซนในนิยายจีนโบราณเวลาย่อมผั...
# 3               14  ด้วยความโง่ของผมทำให้ความลับที่ปกปิดมาเกือบยี่...
# 4                2  การเริ่มต้นชีวิตของเด็กมหาลัยปีสองคุณคิดว่าเริ...
# ...            ...                                                ...
# 15221          106  เมื่อหนุ่มหล่อสุดเพอร์เฟกต์ต้องเสียความบริสุทธ...
# 15222           16  องค์ชายรองแห่งแคว้นจ้าวเช่นเขา กลับกลายมาเป็นเ...
# 15223            0  "พี่ให้เธอทั้งหมดในบัญชีเธอเอาเท่าไหร่ว่ามา" "...
# 15224           12  "ถ้าจะจัดการคนเลว ก็คงต้องส่งไปเจอกับคนที่เลวก...
# 15225            5  ยอมสละบัลลังก์เพื่อหลีกเลี่ยงแฟล็กความตายที่จะ...
#
#       favouriteCount isComplete  numOfchap  \
# 0              4,159         จบ       30.0
# 1                225         จบ        6.0
# 2                  5         จบ        0.0
# 3                 79         จบ        8.0
# 4                  1         จบ        0.0
# ...              ...        ...        ...
# 15221            391         จบ       20.0
# 15222             67         จบ        2.0
# 15223              0         จบ        0.0
# 15224             35         จบ        1.0
# 15225             30         จบ        2.0
#
#                                                      pic ratingCount  \
# 0      https://cdn.readawrite.com/articles/1943/19420...         597
# 1      https://cdn.readawrite.com/articles/1943/19420...          61
# 2      https://cdn.readawrite.com/articles/1943/19421...           1
# 3      https://cdn.readawrite.com/articles/1943/19421...           9
# 4      https://cdn.readawrite.com/articles/1943/19422...           2
# ...                                                  ...         ...
# 15221  https://cdn.readawrite.com/articles/1898/18976...          44
# 15222  https://cdn.readawrite.com/articles/1898/18977...          12
# 15223  https://cdn.readawrite.com/articles/1898/18977...           0
# 15224  https://cdn.readawrite.com/articles/1898/18978...           8
# 15225  https://cdn.readawrite.com/articles/1898/18978...           4
#
#                                                      tag  \
# 0      นิยายวาย,นิยายสนุกๆ,ตลก / comedy,นิยายตลก,หวาน...
# 1                 Boy Love/Yaoi,นิยายวาย,นิยายรัก,ลึกลับ
# 2      เทพเซียน,วายจีนโบราณ,Boy love / Yaoi / ชายรักช...
# 3                                                    NaN
# 4      Boy Love/Yaoi,นิยายวาย,ตลก,ผีในห้อง,18+,สืบสวน...
# ...                                                  ...
# 15221  18+,Boy Love/Yaoi,นิยายโรแมนติก,ตลก,โรงเรียน,น...
# 15222                          เรียลหริ,นิยายวายจีนโบราณ
# 15223                                             ตามจีบ
# 15224                                Boy Love/Yaoi,Mpreg
# 15225   Boy Love/Yaoi,เกิดใหม่ในต่างโลก,ชารอนไม่ทิ้งผัก!
#
#                                                    title   viewer  \
# 0                                  ถ้าผมดื้อพี่จะดุผมไหม  171,581
# 1                                              เดือนพราง    3,437
# 2                               贺陈 | เหมันต์หนึ่งก้านธูป       83
# 3                         Deadly Nightshade (Omegaverse)    1,901
# 4                              ผม ผีในห้อง และคนข้างห้อง       38
# ...                                                  ...      ...
# 15221                               เพลงพราย กลร้ายกลรัก   22,477
# 15222                            จอมใจจักรพรรดิแดนเถื่อน      955
# 15223                          MONEYFORU | เท่าไหร่ว่ามา        5
# 15224       I Demon  King I จอมปีศาจกับราชาทรราช (Mpreg)      339
# 15225  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต | #...      427
#
#                                         new_title           hashtag
# 0                           ถ้าผมดื้อพี่จะดุผมไหม               NaN
# 1                                       เดือนพราง               NaN
# 2                             เหมันต์หนึ่งก้านธูป               NaN
# 3                                             NaN               NaN
# 4                         ผมผีในห้องและคนข้างห้อง               NaN
# ...                                           ...               ...
# 15221                         เพลงพรายกลร้ายกลรัก               NaN
# 15222                     จอมใจจักรพรรดิแดนเถื่อน               NaN
# 15223                               เท่าไหร่ว่ามา               NaN
# 15224                        จอมปีศาจกับราชาทรราช               NaN
# 15225  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต  ชารอนอย่าทิ้งผัก
#
# [15226 rows x 15 columns]

# %%
string.ascii_lowercase + string.ascii_uppercase
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
print(json.dumps(df4.to_dict('readawritetest')))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
