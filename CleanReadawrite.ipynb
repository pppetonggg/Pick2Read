# %%
import pandas as pd
import numpy as np
import string
import re

#df = pd.read_csv(r'C:\Users\paton\Pick2ReadData\Data\readawrite1.csv')
df = pd.read_csv(r'C:\Users\paton\Pick2ReadData\Data\readawrite_fiction_AL.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=42651, step=1)

# %%
df.dropna(subset=['title', 'category','author'],inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop_duplicates()

wordlist = '&#039;|&amp;|&bull;|&hearts;|&quot;|&lt;'
df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

df['title'] = df['title'].str.replace(wordlist, '')
df['author'] = df['author'].str.replace(wordlist, '')
df['category'] = df['category'].str.replace(wordlist, '')


#df[['title','author']] = df[['title','author']].replace(wordlist, '')
df
# Out:
#                              author                       category  \
# 0                           นวินกวี  นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล
# 1                           MMI827_                     แฟนฟิคชั่น
# 2                            ป่วนใจ     นิยาย Boy Love Secret Room
# 3                     Smoothie_mine  นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล
# 4                     plangpin 9092                       นิยายรัก
# ...                             ...                            ...
# 42646  แฟชั่น น่ากลัว หนุ่มquot;สาว                      สัพเพเหระ
# 42647                       vanvisa             นิยายรักวัยว้าวุ่น
# 42648                        ภโวทัย                   นิยายโรมานซ์
# 42649          ผู้ขี้เกียจเป็นหนึ่ง     นิยาย Boy Love Lovely Room
# 42650                     Junesnow​     นิยาย Boy Love Lovely Room
#
#       commentCount                                        description  \
# 0               20  การต่อสู้ของเด็กชายผู้โชคร้ายเพื่อเป็นฮันเตอร์...
# 1               32  ...เขาสบตากับใครคนหนึ่งนานเป็นนาที ชายหนุ่มผิว...
# 2            1,166  ถึงผมจะอยากได้เงิน แต่ก็ไม่ได้อยากเป็นดารา AV ...
# 3                2  โลกแฟนตาซีที่ดูเหมือนจะไม่มีอะไร ดลกเสมือนเกมอ...
# 4                2  จากวันที่แม่งนั้นขอฉันแต่งงานจากที่รักกัน ทำไม...
# ...            ...                                                ...
# 42646            0  แต่งตัวให้น่ารักดูดีสําหลับสาว 1"ต้องหา ชุด ที...
# 42647           11  เมื่อโชชะตาไม่ไม่เป็นใจทำให้สาวซื่อบื้ออย่างฉั...
# 42648            9  ดวงตาที่คอยแอบมองกระตุ้นให้สมภารที่ไม่คิดกินไก...
# 42649        2,306  ตายแล้วไปเกิดใหม่ ไฉนข้าจึงเกิดเป็นสิงโตทะเล แ...
# 42650          701  Part 1. หนึ่งคน #แกล้งไม่รู้ว่าถูกรัก หนึ่งคน ...
#
#       favouriteCount isComplete  numOfchap  \
# 0                 19         จบ       22.0
# 1                144         จบ       21.0
# 2              1,442         จบ       48.0
# 3                  3         จบ        0.0
# 4                  0         จบ        0.0
# ...              ...        ...        ...
# 42646              3         จบ        0.0
# 42647             37         จบ        6.0
# 42648             64         จบ        4.0
# 42649          4,103         จบ       18.0
# 42650            464         จบ       39.0
#
#                                                      pic ratingCount  \
# 0      https://cdn.readawrite.com/articles/442/441716...         2.0
# 1      https://cdn.readawrite.com/articles/444/443135...        25.0
# 2      https://cdn.readawrite.com/articles/444/443846...       354.0
# 3      https://cdn.readawrite.com/articles/445/444442...         2.0
# 4      https://cdn.readawrite.com/articles/444/443477...         1.0
# ...                                                  ...         ...
# 42646  https://cdn.readawrite.com/articles/397/396420...         0.0
# 42647  https://cdn.readawrite.com/articles/396/395746...         7.0
# 42648  https://cdn.readawrite.com/articles/396/395958...         6.0
# 42649  https://cdn.readawrite.com/articles/397/396003...       975.0
# 42650  https://cdn.readawrite.com/articles/398/397299...       123.0
#
#                                                      tag  \
# 0      เกมออนไลน์,game,มอสเตอร์,ต่อสู้,ดันเจี๋ยน,โลกต...
# 1      EXO,Boy Love/Yaoi,Fanfiction แฟนฟิคชั่น,HunHan...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 42646                               วิเคราะห์,ประสบการณ์
# 42647                                                NaN
# 42648                 รัก,คม,ซาตาน,นิยายรัก,โชติรส,นิยาย
# 42649  Boy Love/Yaoi,ตลก,แฟนตาซี,น่ารัก,คอมเมดี้,เกิด...
# 42650                    18+,Boy Love/Yaoi,Yaoi,นิยายวาย
#
#                                          title  \
# 0                             ฮันเตอร์ สิงหนาท
# 1      Yaoi GLACE {HunHan ft. ChanBaek KaiSoo}
# 2                       เขาบังคับผมให้เล่น AV!
# 3               Help me!ยัยฮีโร่พิชิตเวิลด์บอส
# 4                 ผมและคุณเราสองคนไม่เคยรักกัน
# ...                                        ...
# 42646                            โลกแห่งแฟชั่น
# 42647                  ร่างใหม่พิชิตใจนายปีศาจ
# 42648                        คมรักซาตาน E-Book
# 42649                  #เกิดเป็นสิงโตทะเล [จบ]
# 42650                 Moments of love 2 [Yaoi]
#
#                                        url   viewer
# 0      https://www.readawrite.com/a/azaakg    2,992
# 1      https://www.readawrite.com/a/azabq0    3,173
# 2      https://www.readawrite.com/a/azacbb  270,796
# 3      https://www.readawrite.com/a/azacsc      199
# 4      https://www.readawrite.com/a/azac0r       57
# ...                                    ...      ...
# 42646  https://www.readawrite.com/a/lz98la      137
# 42647  https://www.readawrite.com/a/lz9821    1,665
# 42648  https://www.readawrite.com/a/lz9883    3,307
# 42649  https://www.readawrite.com/a/lz989d  180,743
# 42650  https://www.readawrite.com/a/lz99be   69,911
#
# [42651 rows x 13 columns]

# %%
#df.to_csv('readawrite.csv',encoding='utf-8')
df[df['title'].str.contains('โอเมก้าตาบอด')]
# Out:
# Empty DataFrame
# Columns: [author, category, commentCount, description, favouriteCount, isComplete, numOfchap, pic, ratingCount, tag, title, url, viewer]
# Index: []

# %%
df[df['author'].str.contains('') == False]
# Out:
# Empty DataFrame
# Columns: [author, category, commentCount, description, favouriteCount, isComplete, numOfchap, pic, ratingCount, tag, title, url, viewer]
# Index: []

# %%
#delete common word
df2 = df
commonword = ['นิยายแปล','เรื่องสั้น','รวมฉาก','อ่านฟรี','!','จบ','จบแล้วจ้า','ตอนพิเศษ','ทดลองอ่าน','18+']
wordcut = '|'.join(commonword)
df2['title'] = df2['title'].str.replace(wordcut,'')
df2
# Out:
#                              author                       category  \
# 0                           นวินกวี  นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล
# 1                           MMI827_                     แฟนฟิคชั่น
# 2                            ป่วนใจ     นิยาย Boy Love Secret Room
# 3                     Smoothie_mine  นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล
# 4                     plangpin 9092                       นิยายรัก
# ...                             ...                            ...
# 42646  แฟชั่น น่ากลัว หนุ่มquot;สาว                      สัพเพเหระ
# 42647                       vanvisa             นิยายรักวัยว้าวุ่น
# 42648                        ภโวทัย                   นิยายโรมานซ์
# 42649          ผู้ขี้เกียจเป็นหนึ่ง     นิยาย Boy Love Lovely Room
# 42650                     Junesnow​     นิยาย Boy Love Lovely Room
#
#       commentCount                                        description  \
# 0               20  การต่อสู้ของเด็กชายผู้โชคร้ายเพื่อเป็นฮันเตอร์...
# 1               32  ...เขาสบตากับใครคนหนึ่งนานเป็นนาที ชายหนุ่มผิว...
# 2            1,166  ถึงผมจะอยากได้เงิน แต่ก็ไม่ได้อยากเป็นดารา AV ...
# 3                2  โลกแฟนตาซีที่ดูเหมือนจะไม่มีอะไร ดลกเสมือนเกมอ...
# 4                2  จากวันที่แม่งนั้นขอฉันแต่งงานจากที่รักกัน ทำไม...
# ...            ...                                                ...
# 42646            0  แต่งตัวให้น่ารักดูดีสําหลับสาว 1"ต้องหา ชุด ที...
# 42647           11  เมื่อโชชะตาไม่ไม่เป็นใจทำให้สาวซื่อบื้ออย่างฉั...
# 42648            9  ดวงตาที่คอยแอบมองกระตุ้นให้สมภารที่ไม่คิดกินไก...
# 42649        2,306  ตายแล้วไปเกิดใหม่ ไฉนข้าจึงเกิดเป็นสิงโตทะเล แ...
# 42650          701  Part 1. หนึ่งคน #แกล้งไม่รู้ว่าถูกรัก หนึ่งคน ...
#
#       favouriteCount isComplete  numOfchap  \
# 0                 19         จบ       22.0
# 1                144         จบ       21.0
# 2              1,442         จบ       48.0
# 3                  3         จบ        0.0
# 4                  0         จบ        0.0
# ...              ...        ...        ...
# 42646              3         จบ        0.0
# 42647             37         จบ        6.0
# 42648             64         จบ        4.0
# 42649          4,103         จบ       18.0
# 42650            464         จบ       39.0
#
#                                                      pic ratingCount  \
# 0      https://cdn.readawrite.com/articles/442/441716...         2.0
# 1      https://cdn.readawrite.com/articles/444/443135...        25.0
# 2      https://cdn.readawrite.com/articles/444/443846...       354.0
# 3      https://cdn.readawrite.com/articles/445/444442...         2.0
# 4      https://cdn.readawrite.com/articles/444/443477...         1.0
# ...                                                  ...         ...
# 42646  https://cdn.readawrite.com/articles/397/396420...         0.0
# 42647  https://cdn.readawrite.com/articles/396/395746...         7.0
# 42648  https://cdn.readawrite.com/articles/396/395958...         6.0
# 42649  https://cdn.readawrite.com/articles/397/396003...       975.0
# 42650  https://cdn.readawrite.com/articles/398/397299...       123.0
#
#                                                      tag  \
# 0      เกมออนไลน์,game,มอสเตอร์,ต่อสู้,ดันเจี๋ยน,โลกต...
# 1      EXO,Boy Love/Yaoi,Fanfiction แฟนฟิคชั่น,HunHan...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 42646                               วิเคราะห์,ประสบการณ์
# 42647                                                NaN
# 42648                 รัก,คม,ซาตาน,นิยายรัก,โชติรส,นิยาย
# 42649  Boy Love/Yaoi,ตลก,แฟนตาซี,น่ารัก,คอมเมดี้,เกิด...
# 42650                    18+,Boy Love/Yaoi,Yaoi,นิยายวาย
#
#                                          title  \
# 0                             ฮันเตอร์ สิงหนาท
# 1      Yaoi GLACE {HunHan ft. ChanBaek KaiSoo}
# 2                        เขาบังคับผมให้เล่น AV
# 3                Help meยัยฮีโร่พิชิตเวิลด์บอส
# 4                 ผมและคุณเราสองคนไม่เคยรักกัน
# ...                                        ...
# 42646                            โลกแห่งแฟชั่น
# 42647                  ร่างใหม่พิชิตใจนายปีศาจ
# 42648                        คมรักซาตาน E-Book
# 42649                    #เกิดเป็นสิงโตทะเล []
# 42650                 Moments of love 2 [Yaoi]
#
#                                        url   viewer
# 0      https://www.readawrite.com/a/azaakg    2,992
# 1      https://www.readawrite.com/a/azabq0    3,173
# 2      https://www.readawrite.com/a/azacbb  270,796
# 3      https://www.readawrite.com/a/azacsc      199
# 4      https://www.readawrite.com/a/azac0r       57
# ...                                    ...      ...
# 42646  https://www.readawrite.com/a/lz98la      137
# 42647  https://www.readawrite.com/a/lz9821    1,665
# 42648  https://www.readawrite.com/a/lz9883    3,307
# 42649  https://www.readawrite.com/a/lz989d  180,743
# 42650  https://www.readawrite.com/a/lz99be   69,911
#
# [42651 rows x 13 columns]

# %%
df3 = pd.DataFrame(df2.title.str.split(r'#.*?(?=\S|$)',1).tolist(), 
                         columns = ['new_title','hashtag'])
df3['new_title'] = df3['new_title'].str.replace(' ', '')
df3['hashtag'] = df3['hashtag'].str.replace(' ', '')

df3['new_title'] = df3['new_title'].str.replace('.', '')
df3['hashtag'] = df3['hashtag'].str.replace('.', '')

#df[['new_title','hashtag']] = df.title.str.split(r'#.*?(?=\s|$)',expand = True) 

df3['hashtag'] = df3['hashtag'].str.extract(r'([\ก-\๙]+)')
df3['new_title'] = df3['new_title'].str.extract(r'([\ก-\๙]+)')


#df3[df3['hashtag'].str.contains('โอเมก้าตาบอด') == True]

# %%
df3[df3['new_title'].str.contains('ช่วยผมด้วย', na=False)]
# Out:
#                               new_title hashtag
# 10269                   เมตตาช่วยผมด้วย     NaN
# 20386             ช่วยผมด้วยผมโดนข่มขืน     NaN
# 28103  ช่วยผมด้วยครับผมโดนบังคับแต่งงาน     NaN
# 42394             ช่วยผมด้วยผมโดนแอบชอบ     NaN
# 43846                     เจ๊ช่วยผมด้วย     NaN
# 56271             เจ้าที่ครับช่วยผมด้วย     NaN

# %%
df4 = df.join(df3)

#no duplicate for hashtag and title
df4_nodup = df4.drop_duplicates(subset=['new_title'], keep=False)
df4_nodup = df4_nodup[df4_nodup['category'].str.contains('Lovely|Secret')]
#df4_nodup.dropna(subset=['new_title'],inplace=True)
df4_nodup.reset_index(drop=True, inplace=True)

df4_nodup
#df4_nodup[df4_nodup['hashtag'].str.contains('ยทบ')]
#df4
# Out:
#                author                    category commentCount  \
# 0              ป่วนใจ  นิยาย Boy Love Secret Room        1,166
# 1         tomatoesbae  นิยาย Boy Love Lovely Room            1
# 2             varirin  นิยาย Boy Love Lovely Room            6
# 3            Jecun\'n  นิยาย Boy Love Lovely Room            0
# 4              Cayla☆  นิยาย Boy Love Lovely Room            6
# ...               ...                         ...          ...
# 4242        ควันหมอก.  นิยาย Boy Love Lovely Room            0
# 4243    I\'M WANNABLE  นิยาย Boy Love Lovely Room            4
# 4244  สลอธบนดาวอังคาร  นิยาย Boy Love Secret Room          273
# 4245     Rainpanpunch  นิยาย Boy Love Lovely Room          113
# 4246        Kawwansuk  นิยาย Boy Love Lovely Room          861
#
#                                             description favouriteCount  \
# 0     ถึงผมจะอยากได้เงิน แต่ก็ไม่ได้อยากเป็นดารา AV ...          1,442
# 1     ผู้มีพระคุณอันดับที่สองรองจากแม่ ผู้ที่ให้ทุกอ...              5
# 2     เทอร์เรนซ์ หยางรักเพื่อนสนิทข้างเดียว ทั้งที่อ...             40
# 3                "อยากมีชีวิตอยู่อย่าคิดเสือกกับน้องกุ"              0
# 4     Once upon a time, Love is pain. กาลครั้งหนึ่งน...              4
# ...                                                 ...            ...
# 4242  **ขออนุญาติเจ้าของภาพ** นิยายเรื่องนี้เป็นเรื่...              0
# 4243   แดนิค:ไอหมูโว้ยยยย!!!!! วี:กูชื่อวีว้อยยยยย!!!!!             12
# 4244  จากลูกบุญธรรมผู้น่ารัก...กลับกลายเป็นสามีของผม...            551
# 4245  Don't speak ความลับที่ผมปิดไว้: นิยาย Boy Love...            207
# 4246  หลังจากแม่เสียชีวิตจากรถชน ชีวิตของภูตะวัน ก็ไ...            732
#
#      isComplete  numOfchap                                                pic  \
# 0            จบ       48.0  https://cdn.readawrite.com/articles/444/443846...
# 1            จบ        1.0  https://cdn.readawrite.com/articles/444/443495...
# 2            จบ        2.0  https://cdn.readawrite.com/articles/448/447451...
# 3            จบ        1.0  https://cdn.readawrite.com/articles/450/449271...
# 4            จบ        1.0  https://cdn.readawrite.com/articles/451/450802...
# ...         ...        ...                                                ...
# 4242         จบ        0.0  https://cdn.readawrite.com/articles/388/387286...
# 4243         จบ        0.0  https://cdn.readawrite.com/articles/390/389457...
# 4244         จบ       27.0  https://cdn.readawrite.com/articles/389/388468...
# 4245         จบ       51.0  https://cdn.readawrite.com/articles/391/390900...
# 4246         จบ      150.0  https://cdn.readawrite.com/articles/392/391124...
#
#      ratingCount                                                tag  \
# 0          354.0                                                NaN
# 1            1.0                                  Boy Love/Yaoi,18+
# 2            3.0  18+,Boy Love/Yaoi,ดราม่า,นิยายรัก,นิยายแฟนตาซี...
# 3            0.0                                                NaN
# 4            4.0  นิยายวาย,#นิยายy,Boy Love/Yaoi,#บันทึกความสุขข...
# ...          ...                                                ...
# 4242         0.0                                                NaN
# 4243         4.0                                  Boy Love/Yaoi,18+
# 4244       119.0                                                NaN
# 4245        28.0  Boy Love/Yaoi,18+,SM,ดราม่า,นิยายรัก,นิยายโรแม...
# 4246       179.0                                                NaN
#
#                                    title                                  url  \
# 0                  เขาบังคับผมให้เล่น AV  https://www.readawrite.com/a/azacbb
# 1                        คุณธันย์ของธิชา  https://www.readawrite.com/a/azac1a
# 2             ANOTHER WORLD - รักต่างโลก  https://www.readawrite.com/a/azaf9b
# 3                          บ้านนี้สายโหด  https://www.readawrite.com/a/azagqb
# 4               บันทึกความสุขของเมื่อวาน  https://www.readawrite.com/a/azai02
# ...                                  ...                                  ...
# 4242                         ร้ายแล้วรัก  https://www.readawrite.com/a/lz915b
# 4243               มีเมียเป็นหมู #แดนฮวี  https://www.readawrite.com/a/lz92wc
# 4244                         คุณพ่อของผม  https://www.readawrite.com/a/lz9243
# 4245     Don\'t speak ความลับที่ผมปิดไว้  https://www.readawrite.com/a/lz943k
# 4246  โอกาสที่ได้ขอใช้ให้ดีที่สุด (YAOI)  https://www.readawrite.com/a/lz949y
#
#        viewer                    new_title hashtag
# 0     270,796           เขาบังคับผมให้เล่น     NaN
# 1         189              คุณธันย์ของธิชา     NaN
# 2       1,158                   รักต่างโลก     NaN
# 3          57                บ้านนี้สายโหด     NaN
# 4         515     บันทึกความสุขของเมื่อวาน     NaN
# ...       ...                          ...     ...
# 4242       62                  ร้ายแล้วรัก     NaN
# 4243      449                มีเมียเป็นหมู  แดนฮวี
# 4244   57,206                  คุณพ่อของผม     NaN
# 4245   26,268           ความลับที่ผมปิดไว้     NaN
# 4246  171,323  โอกาสที่ได้ขอใช้ให้ดีที่สุด     NaN
#
# [4247 rows x 15 columns]

# %%
#df4.to_csv('readawrite_full_hash_set6.csv')
#df4_nodup.to_csv(r'C:\Users\paton\Pick2ReadData\TwitterSearch\readawriteAL_hash_nodup_1.csv')
#df4_nodup.to_csv(r'C:\Users\paton\Pick2ReadData\TwitterSearch\readawriteAL_title_nodup_1.csv')
df4_nodup['hashtag'].count()
# Out:
# 94

# %%
boyslove = df4[df4['category'].str.contains('Lovely|Secret')]
boyslove.reset_index(drop=True, inplace=True)
ship = ['บุ๋นเปรม','ไบร์ทวิน','จ้านเกอ','โชซอก','ป๋อตี้จ้านเกอ','ไคฮุน','ชานแบค','กุกมิน','โยซอก','ป๋อจ้าน','จ้านป๋อ','กุกวี','แจโด','ซึงพโย','มาร์คแบม','แจ็คแจ','ปมนยอง','วีกุก','ออฟกัน','บกพพ','บิวกิ้นพีพี','วีมิน','คั่นกู','กันออฟ','แบมมาร์ค','เนียลอง','ซีเฉิง','ซึงยอนซอก']
boyslove = boyslove[~boyslove.hashtag.str.contains('|'.join(ship), na=False)]
#boyslove.to_csv(r'C:\Users\paton\Pick2ReadData\BoysloveFiltered\readawrite_y5.csv',encoding='utf-8')
boyslove[boyslove['hashtag'].str.contains('ป๋อจ้าน') == True]

test = pd.read_csv(r'C:\Users\paton\Pick2ReadData\TwitterSearch\readawrite_title_nodup_2.csv')
test[test['category'].str.contains('Lovely|Secret')]
test
# Out:
#        Unnamed: 0                   author                    category  \
# 0               0          ไก่ทอดมาแล้วจ้า  นิยาย Boy Love Lovely Room
# 1               1              Violet Rain  นิยาย Boy Love Lovely Room
# 2               2  ชายผู้ไม่มีปากกาน้ำเงิน  นิยาย Boy Love Lovely Room
# 3               3            หัวยุ่ง ฟูเอง  นิยาย Boy Love Secret Room
# 4               4                ซอมบี้คุง  นิยาย Boy Love Secret Room
# ...           ...                      ...                         ...
# 10423       10423                TJ Tommys  นิยาย Boy Love Lovely Room
# 10424       10424                 เรียลหริ  นิยาย Boy Love Lovely Room
# 10425       10425              pedseyellow  นิยาย Boy Love Lovely Room
# 10426       10426             EuraysiaSama  นิยาย Boy Love Secret Room
# 10427       10427               penguin_23  นิยาย Boy Love Lovely Room
#
#       commentCount                                        description  \
# 0            1,460  "ที่ผมกินลูกอมจนฟันผุ ก็แค่ข้ออ้างที่อยากมาหาพ...
# 1              119  ผมไม่แน่ใจว่ามันเกิดขึ้นได้ยังไง แต่ทุกครั้งที...
# 2                1  ย่อมแน่ล่ะ เขตไทม์โซนในนิยายจีนโบราณเวลาย่อมผั...
# 3                2  การเริ่มต้นชีวิตของเด็กมหาลัยปีสองคุณคิดว่าเริ...
# 4                3          ฟิคแต่งใช้หนี้คูมอมิตไม่ต้องกดเข้ามาก็ได้
# ...            ...                                                ...
# 10423          106  เมื่อหนุ่มหล่อสุดเพอร์เฟกต์ต้องเสียความบริสุทธ...
# 10424           16  องค์ชายรองแห่งแคว้นจ้าวเช่นเขา กลับกลายมาเป็นเ...
# 10425            0  "พี่ให้เธอทั้งหมดในบัญชีเธอเอาเท่าไหร่ว่ามา" "...
# 10426           12  "ถ้าจะจัดการคนเลว ก็คงต้องส่งไปเจอกับคนที่เลวก...
# 10427            5  ยอมสละบัลลังก์เพื่อหลีกเลี่ยงแฟล็กความตายที่จะ...
#
#       favouriteCount isComplete  numOfchap  \
# 0              4,159         จบ       30.0
# 1                225         จบ        6.0
# 2                  5         จบ        0.0
# 3                  1         จบ        0.0
# 4                  1         จบ        2.0
# ...              ...        ...        ...
# 10423            391         จบ       20.0
# 10424             67         จบ        2.0
# 10425              0         จบ        0.0
# 10426             35         จบ        1.0
# 10427             30         จบ        2.0
#
#                                                      pic ratingCount  \
# 0      https://cdn.readawrite.com/articles/1943/19420...         597
# 1      https://cdn.readawrite.com/articles/1943/19420...          61
# 2      https://cdn.readawrite.com/articles/1943/19421...           1
# 3      https://cdn.readawrite.com/articles/1943/19422...           2
# 4      https://cdn.readawrite.com/articles/1943/19424...           1
# ...                                                  ...         ...
# 10423  https://cdn.readawrite.com/articles/1898/18976...          44
# 10424  https://cdn.readawrite.com/articles/1898/18977...          12
# 10425  https://cdn.readawrite.com/articles/1898/18977...           0
# 10426  https://cdn.readawrite.com/articles/1898/18978...           8
# 10427  https://cdn.readawrite.com/articles/1898/18978...           4
#
#                                                      tag  \
# 0      นิยายวาย,นิยายสนุกๆ,ตลก / comedy,นิยายตลก,หวาน...
# 1                 Boy Love/Yaoi,นิยายวาย,นิยายรัก,ลึกลับ
# 2      เทพเซียน,วายจีนโบราณ,Boy love / Yaoi / ชายรักช...
# 3      Boy Love/Yaoi,นิยายวาย,ตลก,ผีในห้อง,18+,สืบสวน...
# 4                                                    NaN
# ...                                                  ...
# 10423  18+,Boy Love/Yaoi,นิยายโรแมนติก,ตลก,โรงเรียน,น...
# 10424                          เรียลหริ,นิยายวายจีนโบราณ
# 10425                                             ตามจีบ
# 10426                                Boy Love/Yaoi,Mpreg
# 10427   Boy Love/Yaoi,เกิดใหม่ในต่างโลก,ชารอนไม่ทิ้งผัก!
#
#                                                    title   viewer  \
# 0                                  ถ้าผมดื้อพี่จะดุผมไหม  171,581
# 1                                              เดือนพราง    3,437
# 2                               贺陈 | เหมันต์หนึ่งก้านธูป       83
# 3                              ผม ผีในห้อง และคนข้างห้อง       38
# 4                                          -- แด่อมิต --       87
# ...                                                  ...      ...
# 10423                               เพลงพราย กลร้ายกลรัก   22,477
# 10424                            จอมใจจักรพรรดิแดนเถื่อน      955
# 10425                          MONEYFORU | เท่าไหร่ว่ามา        5
# 10426       I Demon  King I จอมปีศาจกับราชาทรราช (Mpreg)      339
# 10427  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต | #...      427
#
#                                         new_title           hashtag
# 0                           ถ้าผมดื้อพี่จะดุผมไหม               NaN
# 1                                       เดือนพราง               NaN
# 2                             เหมันต์หนึ่งก้านธูป               NaN
# 3                         ผมผีในห้องและคนข้างห้อง               NaN
# 4                                         แด่อมิต               NaN
# ...                                           ...               ...
# 10423                         เพลงพรายกลร้ายกลรัก               NaN
# 10424                     จอมใจจักรพรรดิแดนเถื่อน               NaN
# 10425                               เท่าไหร่ว่ามา               NaN
# 10426                        จอมปีศาจกับราชาทรราช               NaN
# 10427  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต  ชารอนอย่าทิ้งผัก
#
# [10428 rows x 15 columns]

# %%
string.ascii_lowercase + string.ascii_uppercase
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
print(json.dumps(df4.to_dict('readawritetest')))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
