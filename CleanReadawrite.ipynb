# %%
import pandas as pd
import numpy as np
import string
import re

df = pd.read_csv(r'C:\Users\paton\Pick2ReadData\Data\readawrite1.csv')
df.index
# Out:
# RangeIndex(start=0, stop=103075, step=1)

# %%
df.dropna(subset=['title', 'category','author'],inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop_duplicates()

df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

wordlist = '&#039;|&amp;|&bull;|&hearts;|&quot;'
df['title'] = df['title'].str.replace(wordlist, '')
df['author'] = df['author'].str.replace(wordlist, '')
df.drop('Unnamed: 0', axis=1, inplace=True)
#df.drop(df.columns[[0]], axis=1) 
df
# Out:
#                 author                            category commentCount  \
# 0               feiing                         คาเฟ่อมยิ้ม           73
# 1       i3ananasociety               นิยาย Girl Love/ Yuri          195
# 2       ทิฟฟานี่มหาศาล                          แฟนฟิคชั่น          278
# 3              ว่านนรี               นิยายรักสำหรับผู้ใหญ่            3
# 4                   Ms       นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล            0
# ...                ...                                 ...          ...
# 103070         จั๊ซซี่               นิยายรักสำหรับผู้ใหญ่            8
# 103071   Dany_Daenerys                     ลิปสติกสีลิลลี่            9
# 103072      RITSUko_t’                     ลิปสติกสีลิลลี่          402
# 103073       bluemoonu                       ชุมชนคนขี้ชิป            4
# 103074         Chonlyt  นิยายลึกลับ/เขย่าขวัญ/สืบสวนสอบสวน            1
#
#                                               description favouriteCount  \
# 0                         เธอเก่งเรื่องทำให้คนกลายเป็นหมา            182
# 1       อยู่ๆ เจนนิเฟอร์ก็หายตัวไป ผู้หมวดเคซีย์พยายาม...            593
# 2       น้องพรีมแกล้งปวดฟันได้ไหมคะ แล้วอาพีชจะได้พาไป...            502
# 3       (ทดลองอ่าน) ความใคร่และตัณหานำมาซึ่งทุกอย่าง เ...             45
# 4         ศึกสงครามแห่งคอส: นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล              0
# ...                                                   ...            ...
# 103070  ลิลลี่เด้กสาวจอมแก่นต้องมาจับคู่อยู่บ้านชายคาเ...             36
# 103071  "ทำไมมึงไปร้านนั่นบ่อยจังวะ" "ที่นั่นมีหนังสือ...             38
# 103072  จะสงครามขนมปี๊บหรืออะไรก็แล้วแต่ กูไม่มีทางแพ้...             96
# 103073  เหอะ เธอก็ไม่ได้น่ารักขนาดนั้นมั้ย เธออย่ามาเบ...             18
# 103074  ความรักเปรียบเสมือนดอกไม้ที่มีกลิ่นหอม ดึงดูด ...              0
#
#        isComplete  numOfchap  \
# 0              จบ        7.0
# 1              จบ        7.0
# 2              จบ       16.0
# 3              จบ        4.0
# 4              จบ        5.0
# ...           ...        ...
# 103070         จบ        2.0
# 103071         จบ        3.0
# 103072         จบ       77.0
# 103073         จบ        0.0
# 103074         จบ        1.0
#
#                                                       pic ratingCount  \
# 0       https://cdn.readawrite.com/articles/1942/19419...          43
# 1       https://cdn.readawrite.com/articles/1942/19419...         118
# 2       https://cdn.readawrite.com/articles/1943/19420...         104
# 3       https://cdn.readawrite.com/articles/1943/19420...           2
# 4       https://cdn.readawrite.com/articles/1943/19420...           0
# ...                                                   ...         ...
# 103070  https://cdn.readawrite.com/articles/1898/18978...           7
# 103071  https://cdn.readawrite.com/articles/1898/18978...           6
# 103072  https://cdn.readawrite.com/articles/1898/18978...          47
# 103073  https://cdn.readawrite.com/articles/1898/18978...           4
# 103074  https://cdn.readawrite.com/articles/1898/18978...           1
#
#                                                       tag  \
# 0       อัตสึคาเง,อัตโทบ,AtsuKage,HIKYUU,ไฮคิวคู่ตบฟ้า...
# 1       Girl Love/Yuri,Yuri,หญิงรักหญิง,นิยายรัก,นิยาย...
# 2       SNSD,Tiffany,Taeyeon,Girl Love/Yuri,Taeny,Taey...
# 3                                                 อีโรติก
# 4                                                     NaN
# ...                                                   ...
# 103070  25+,Erotic,อีโรติก / erotic,นิยายโรมานซ์,นิยาย...
# 103071  ซึลรีน,ไอรีน,ซึลกิ,ซึลกิไอรีน,RedVelvet,suelre...
# 103072  เรลกัน,Railgun,Index,อินเดกซ์,มิโคมิซา,ยูริ,Yu...
# 103073                     Oikage,Haikyuu,Haikyuu AU thai
# 103074                              สืบสวน,ดราม่า,ความรัก
#
#                                             title     viewer
# 0                            น้องทับคะ | atsukage    172,357
# 1                           GONE ก่อ•การ•ลัก(รัก)     10,442
# 2                       ช่วยด้วยหมอสวยมาก [TAENY]     22,309
# 3                                   สอนสวาทพี่สาว      6,469
# 4                                ศึกสงครามแห่งคอส         28
# ...                                           ...        ...
# 103070  คู่ป่วนชวนรัก (NC+++) [Flower The Series]      3,204
# 103071                ร้านหนังสือที่ขายแต่ความรัก     29,188
# 103072   เสียตังค์ไม่ว่าเสียหน้าไม่ได้ (MikoMisa)  3,663,476
# 103073                 ( HQ ) เมลเป็นแมว — oikage          0
# 103074                              ความรักสองเรา         21
#
# [103075 rows x 12 columns]

# %%
#df.to_csv('readawrite.csv',encoding='utf-8')
df[df['title'].str.contains('ต้นน้ำของภูเขา', na=False)]
# Out:
#      author       category commentCount  \
# 28  นิรันดา  ชุมชนคนขี้ชิป           26
#
#                                 description favouriteCount isComplete  \
# 28  ต้นน้ำของภูเขา​ #ป๋อจ้าน: ชุมชนคนขี้ชิป             59         จบ
#
#     numOfchap                                                pic ratingCount  \
# 28       18.0  https://cdn.readawrite.com/articles/1943/19422...           7
#
#     tag                     title   viewer
# 28  NaN  ต้นน้ำของภูเขา​ #ป๋อจ้าน  118,197

# %%
df[df['author'].str.contains('') == False]
# Out:
# Empty DataFrame
# Columns: [author, category, commentCount, description, favouriteCount, isComplete, numOfchap, pic, ratingCount, tag, title, viewer]
# Index: []

# %%
df2 = df[df['title'].str.contains('#')]
df2
# Out:
#                 author                    category commentCount  \
# 14              papapy               ชุมชนคนขี้ชิป            2
# 28             นิรันดา               ชุมชนคนขี้ชิป           26
# 30      lemmebeyourbby               ชุมชนคนขี้ชิป            6
# 32            NaphasZA               ชุมชนคนขี้ชิป           16
# 33             นิรันดา               ชุมชนคนขี้ชิป           54
# ...                ...                         ...          ...
# 103049     Cinzano 505  นิยาย Boy Love Secret Room       16,331
# 103058  SWEET*ALAMODE_               ชุมชนคนขี้ชิป            5
# 103065     คว้าของเหลว               ชุมชนคนขี้ชิป            1
# 103067           ธิต้า                  แฟนฟิคชั่น            2
# 103069      penguin_23  นิยาย Boy Love Lovely Room            5
#
#                                               description favouriteCount  \
# 14                      ความแค้นมันทำได้ถึงขนาดนี้เลยเหรอ              4
# 28                ต้นน้ำของภูเขา​ #ป๋อจ้าน: ชุมชนคนขี้ชิป             59
# 30                          ไอวินน่ะหรอ ก็แค่หมาบ้าตัวนึง             96
# 32      NC+ นิยายเรื่องนี้มีNCนะ!! คนของมึงน่ะ ถ้ามึงด...             33
# 33                       น่านน้ำ​ #จ้านป๋อ: ชุมชนคนขี้ชิป             96
# ...                                                   ...            ...
# 103049  เขาเป็นคนสอนผมดื่มเหล้า สอนสูบบุหรี่ สอนกอด สอ...         23,072
# 103058          ค่อย ๆ ตกหลุมรักอย่างช้า ๆ นั่นแหละดีแล้ว             28
# 103065                กฎของเฟรนโซนคือมึงทำได้แค่รักเงียบๆ              2
# 103067  แบมแบม เด็กหนุ่มผู้สิ้นหวังทางการเงิน เพื่อทำง...              4
# 103069  ยอมสละบัลลังก์เพื่อหลีกเลี่ยงแฟล็กความตายที่จะ...             30
#
#        isComplete  numOfchap  \
# 14             จบ        0.0
# 28             จบ       18.0
# 30             จบ       11.0
# 32             จบ        2.0
# 33             จบ       20.0
# ...           ...        ...
# 103049         จบ       26.0
# 103058         จบ        4.0
# 103065         จบ        1.0
# 103067         จบ        2.0
# 103069         จบ        2.0
#
#                                                       pic ratingCount  \
# 14      https://cdn.readawrite.com/articles/1943/19420...           1
# 28      https://cdn.readawrite.com/articles/1943/19422...           7
# 30      https://cdn.readawrite.com/articles/1943/19422...           6
# 32      https://cdn.readawrite.com/articles/1943/19422...          12
# 33      https://cdn.readawrite.com/articles/1943/19422...          14
# ...                                                   ...         ...
# 103049  https://cdn.readawrite.com/articles/1898/18976...       4,098
# 103058  https://cdn.readawrite.com/articles/1898/18977...           4
# 103065  https://cdn.readawrite.com/articles/1898/18978...           1
# 103067  https://cdn.readawrite.com/articles/1898/18978...           1
# 103069  https://cdn.readawrite.com/articles/1898/18978...           4
#
#                                                       tag  \
# 14      #kookv,#yaoi #ชายชาย #ชxช #นิยายวาย #นิยายชายช...
# 28                                                    NaN
# 30      #jaeten,Ten,#WAYV,NCT,nctfiction,JAEHYUN,#Winw...
# 32                     บุ๋นเปรม,กองกำลังบุ๋นเปรม,นิยายวาย
# 33                                                    NaN
# ...                                                   ...
# 103049  Boy Love/Yaoi,นิยายรัก,นิยายโรแมนติก,friends w...
# 103058          minwon,meanie,mingyu,wonwoo,seventeen,svt
# 103065                                                NaN
# 103067  Fanfiction แฟนฟิคชั่น,Boy Love/Yaoi,18+,Markba...
# 103069   Boy Love/Yaoi,เกิดใหม่ในต่างโลก,ชารอนไม่ทิ้งผัก!
#
#                                                     title     viewer
# 14                                    รักนะคุณ​เจ้า#kookv          0
# 28                               ต้นน้ำของภูเขา​ #ป๋อจ้าน    118,197
# 30                           ทวงคืนเจย์ #jaeten ft.winwin    220,635
# 32      ถ้ามึงดูแลคนของมึงไม่ได้กูก็จะดูแลเอง #คุณสามี...     15,953
# 33                                      น่านน้ำ​ #จ้านป๋อ    286,726
# ...                                                   ...        ...
# 103049                      UNKNOWN LOVER #เขาชื่ออันวาร์  1,340,550
# 103058                                !allegretto #minwon     18,134
# 103065                                     fools #nielong          0
# 103067                                   Bought #BoughtMB        160
# 103069  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต | #...        427
#
# [13207 rows x 12 columns]

# %%
df3 = pd.DataFrame(df.title.str.split(r'#.*?(?=\S|$)',1).tolist(), 
                         columns = ['new_title','hashtag'])
#df[['new_title','hashtag']] = df.title.str.split(r'#.*?(?=\s|$)',expand = True) 
df3['hashtag'] = df3['hashtag'].str.extract('([\ก-\๙]+)')
#df3['new_title'] = df3['new_title'].str.extract('([\a-zA-Z-\ก-\๙]+)')
df3[df3['hashtag'].str.contains('') == True]
# Out:
#                                             new_title           hashtag
# 28                                   ต้นน้ำของภูเขา​            ป๋อจ้าน
# 32             ถ้ามึงดูแลคนของมึงไม่ได้กูก็จะดูแลเอง      คุณสามีที่รัก
# 33                                          น่านน้ำ​            จ้านป๋อ
# 58                                          kiss cat       แฟนผมเป็นแงว
# 69           ถึงจะเด๋อ แต่อย่าเผลอมารักแล้วกัน [NC ]            ป๋อจ้าน
# ...                                               ...               ...
# 103029                             น้องกูอย่าริจีบ |            ป๋อจ้าน
# 103034              [Fic] To my world (omegaverse) |              ซึงโย
# 103036                                  เจ๊ไม่จริง |              ซึงโย
# 103049                                 UNKNOWN LOVER     เขาชื่ออันวาร์
# 103069  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต |   ชารอนอย่าทิ้งผัก
#
# [7996 rows x 2 columns]

# %%
df3[df3['hashtag'].str.contains('โอเมก้าตาบอด', na=False)]
# Out:
#                                     new_title       hashtag
# 18046  [Omegaverse] Never Ωmega in the army (  โอเมก้าตาบอด

# %%
df3[df3['hashtag'].str.contains('') == True]
#df3.to_csv('readawrite_hashtag.csv')
# Out:
#                                             new_title           hashtag
# 28                                   ต้นน้ำของภูเขา​            ป๋อจ้าน
# 32             ถ้ามึงดูแลคนของมึงไม่ได้กูก็จะดูแลเอง      คุณสามีที่รัก
# 33                                          น่านน้ำ​            จ้านป๋อ
# 58                                          kiss cat       แฟนผมเป็นแงว
# 69           ถึงจะเด๋อ แต่อย่าเผลอมารักแล้วกัน [NC ]            ป๋อจ้าน
# ...                                               ...               ...
# 103029                             น้องกูอย่าริจีบ |            ป๋อจ้าน
# 103034              [Fic] To my world (omegaverse) |              ซึงโย
# 103036                                  เจ๊ไม่จริง |              ซึงโย
# 103049                                 UNKNOWN LOVER     เขาชื่ออันวาร์
# 103069  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต |   ชารอนอย่าทิ้งผัก
#
# [7996 rows x 2 columns]

# %%
df4 = df.join(df3)
df4
# Out:
#                 author                            category commentCount  \
# 0               feiing                         คาเฟ่อมยิ้ม           73
# 1       i3ananasociety               นิยาย Girl Love/ Yuri          195
# 2       ทิฟฟานี่มหาศาล                          แฟนฟิคชั่น          278
# 3              ว่านนรี               นิยายรักสำหรับผู้ใหญ่            3
# 4                   Ms       นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล            0
# ...                ...                                 ...          ...
# 103070         จั๊ซซี่               นิยายรักสำหรับผู้ใหญ่            8
# 103071   Dany_Daenerys                     ลิปสติกสีลิลลี่            9
# 103072      RITSUko_t’                     ลิปสติกสีลิลลี่          402
# 103073       bluemoonu                       ชุมชนคนขี้ชิป            4
# 103074         Chonlyt  นิยายลึกลับ/เขย่าขวัญ/สืบสวนสอบสวน            1
#
#                                               description favouriteCount  \
# 0                         เธอเก่งเรื่องทำให้คนกลายเป็นหมา            182
# 1       อยู่ๆ เจนนิเฟอร์ก็หายตัวไป ผู้หมวดเคซีย์พยายาม...            593
# 2       น้องพรีมแกล้งปวดฟันได้ไหมคะ แล้วอาพีชจะได้พาไป...            502
# 3       (ทดลองอ่าน) ความใคร่และตัณหานำมาซึ่งทุกอย่าง เ...             45
# 4         ศึกสงครามแห่งคอส: นิยายแฟนตาซี/Sci-Fi/ไลท์โนเวล              0
# ...                                                   ...            ...
# 103070  ลิลลี่เด้กสาวจอมแก่นต้องมาจับคู่อยู่บ้านชายคาเ...             36
# 103071  "ทำไมมึงไปร้านนั่นบ่อยจังวะ" "ที่นั่นมีหนังสือ...             38
# 103072  จะสงครามขนมปี๊บหรืออะไรก็แล้วแต่ กูไม่มีทางแพ้...             96
# 103073  เหอะ เธอก็ไม่ได้น่ารักขนาดนั้นมั้ย เธออย่ามาเบ...             18
# 103074  ความรักเปรียบเสมือนดอกไม้ที่มีกลิ่นหอม ดึงดูด ...              0
#
#        isComplete  numOfchap  \
# 0              จบ        7.0
# 1              จบ        7.0
# 2              จบ       16.0
# 3              จบ        4.0
# 4              จบ        5.0
# ...           ...        ...
# 103070         จบ        2.0
# 103071         จบ        3.0
# 103072         จบ       77.0
# 103073         จบ        0.0
# 103074         จบ        1.0
#
#                                                       pic ratingCount  \
# 0       https://cdn.readawrite.com/articles/1942/19419...          43
# 1       https://cdn.readawrite.com/articles/1942/19419...         118
# 2       https://cdn.readawrite.com/articles/1943/19420...         104
# 3       https://cdn.readawrite.com/articles/1943/19420...           2
# 4       https://cdn.readawrite.com/articles/1943/19420...           0
# ...                                                   ...         ...
# 103070  https://cdn.readawrite.com/articles/1898/18978...           7
# 103071  https://cdn.readawrite.com/articles/1898/18978...           6
# 103072  https://cdn.readawrite.com/articles/1898/18978...          47
# 103073  https://cdn.readawrite.com/articles/1898/18978...           4
# 103074  https://cdn.readawrite.com/articles/1898/18978...           1
#
#                                                       tag  \
# 0       อัตสึคาเง,อัตโทบ,AtsuKage,HIKYUU,ไฮคิวคู่ตบฟ้า...
# 1       Girl Love/Yuri,Yuri,หญิงรักหญิง,นิยายรัก,นิยาย...
# 2       SNSD,Tiffany,Taeyeon,Girl Love/Yuri,Taeny,Taey...
# 3                                                 อีโรติก
# 4                                                     NaN
# ...                                                   ...
# 103070  25+,Erotic,อีโรติก / erotic,นิยายโรมานซ์,นิยาย...
# 103071  ซึลรีน,ไอรีน,ซึลกิ,ซึลกิไอรีน,RedVelvet,suelre...
# 103072  เรลกัน,Railgun,Index,อินเดกซ์,มิโคมิซา,ยูริ,Yu...
# 103073                     Oikage,Haikyuu,Haikyuu AU thai
# 103074                              สืบสวน,ดราม่า,ความรัก
#
#                                             title     viewer  \
# 0                            น้องทับคะ | atsukage    172,357
# 1                           GONE ก่อ•การ•ลัก(รัก)     10,442
# 2                       ช่วยด้วยหมอสวยมาก [TAENY]     22,309
# 3                                   สอนสวาทพี่สาว      6,469
# 4                                ศึกสงครามแห่งคอส         28
# ...                                           ...        ...
# 103070  คู่ป่วนชวนรัก (NC+++) [Flower The Series]      3,204
# 103071                ร้านหนังสือที่ขายแต่ความรัก     29,188
# 103072   เสียตังค์ไม่ว่าเสียหน้าไม่ได้ (MikoMisa)  3,663,476
# 103073                 ( HQ ) เมลเป็นแมว — oikage          0
# 103074                              ความรักสองเรา         21
#
#                                         new_title hashtag
# 0                            น้องทับคะ | atsukage     NaN
# 1                           GONE ก่อ•การ•ลัก(รัก)     NaN
# 2                       ช่วยด้วยหมอสวยมาก [TAENY]     NaN
# 3                                   สอนสวาทพี่สาว     NaN
# 4                                ศึกสงครามแห่งคอส     NaN
# ...                                           ...     ...
# 103070  คู่ป่วนชวนรัก (NC+++) [Flower The Series]     NaN
# 103071                ร้านหนังสือที่ขายแต่ความรัก     NaN
# 103072   เสียตังค์ไม่ว่าเสียหน้าไม่ได้ (MikoMisa)     NaN
# 103073                 ( HQ ) เมลเป็นแมว — oikage     NaN
# 103074                              ความรักสองเรา     NaN
#
# [103075 rows x 14 columns]

# %%
#df4.to_csv('readawrite_full_hash_set2.csv')
df4['hashtag'].count()
# Out:
# 7996

# %%
boyslove = df4[df4['category'].str.contains('Lovely|Secret')]
boyslove.reset_index(drop=True, inplace=True)
#boyslove.to_csv('readawrite_y.csv',encoding='utf-8')

test = pd.read_csv(r'C:\Users\paton\Pick2ReadData\readawrite_y.csv')
test
# Out:
#        Unnamed: 0                   author                    category  \
# 0               0          ไก่ทอดมาแล้วจ้า  นิยาย Boy Love Lovely Room
# 1               1              Violet Rain  นิยาย Boy Love Lovely Room
# 2               2  ชายผู้ไม่มีปากกาน้ำเงิน  นิยาย Boy Love Lovely Room
# 3               3             ลูกหมูสามตัว  นิยาย Boy Love Secret Room
# 4               4            หัวยุ่ง ฟูเอง  นิยาย Boy Love Secret Room
# ...           ...                      ...                         ...
# 15248       15248                TJ Tommys  นิยาย Boy Love Lovely Room
# 15249       15249                 เรียลหริ  นิยาย Boy Love Lovely Room
# 15250       15250              pedseyellow  นิยาย Boy Love Lovely Room
# 15251       15251             EuraysiaSama  นิยาย Boy Love Secret Room
# 15252       15252               penguin_23  นิยาย Boy Love Lovely Room
#
#       commentCount                                        description  \
# 0            1,460  "ที่ผมกินลูกอมจนฟันผุ ก็แค่ข้ออ้างที่อยากมาหาพ...
# 1              119  ผมไม่แน่ใจว่ามันเกิดขึ้นได้ยังไง แต่ทุกครั้งที...
# 2                1  ย่อมแน่ล่ะ เขตไทม์โซนในนิยายจีนโบราณเวลาย่อมผั...
# 3               14  ด้วยความโง่ของผมทำให้ความลับที่ปกปิดมาเกือบยี่...
# 4                2  การเริ่มต้นชีวิตของเด็กมหาลัยปีสองคุณคิดว่าเริ...
# ...            ...                                                ...
# 15248          106  เมื่อหนุ่มหล่อสุดเพอร์เฟกต์ต้องเสียความบริสุทธ...
# 15249           16  องค์ชายรองแห่งแคว้นจ้าวเช่นเขา กลับกลายมาเป็นเ...
# 15250            0  "พี่ให้เธอทั้งหมดในบัญชีเธอเอาเท่าไหร่ว่ามา" "...
# 15251           12  "ถ้าจะจัดการคนเลว ก็คงต้องส่งไปเจอกับคนที่เลวก...
# 15252            5  ยอมสละบัลลังก์เพื่อหลีกเลี่ยงแฟล็กความตายที่จะ...
#
#       favouriteCount isComplete  numOfchap  \
# 0              4,159         จบ       30.0
# 1                225         จบ        6.0
# 2                  5         จบ        0.0
# 3                 79         จบ        8.0
# 4                  1         จบ        0.0
# ...              ...        ...        ...
# 15248            391         จบ       20.0
# 15249             67         จบ        2.0
# 15250              0         จบ        0.0
# 15251             35         จบ        1.0
# 15252             30         จบ        2.0
#
#                                                      pic ratingCount  \
# 0      https://cdn.readawrite.com/articles/1943/19420...         597
# 1      https://cdn.readawrite.com/articles/1943/19420...          61
# 2      https://cdn.readawrite.com/articles/1943/19421...           1
# 3      https://cdn.readawrite.com/articles/1943/19421...           9
# 4      https://cdn.readawrite.com/articles/1943/19422...           2
# ...                                                  ...         ...
# 15248  https://cdn.readawrite.com/articles/1898/18976...          44
# 15249  https://cdn.readawrite.com/articles/1898/18977...          12
# 15250  https://cdn.readawrite.com/articles/1898/18977...           0
# 15251  https://cdn.readawrite.com/articles/1898/18978...           8
# 15252  https://cdn.readawrite.com/articles/1898/18978...           4
#
#                                                      tag  \
# 0      นิยายวาย,นิยายสนุกๆ,ตลก / comedy,นิยายตลก,หวาน...
# 1                 Boy Love/Yaoi,นิยายวาย,นิยายรัก,ลึกลับ
# 2      เทพเซียน,วายจีนโบราณ,Boy love / Yaoi / ชายรักช...
# 3                                                    NaN
# 4      Boy Love/Yaoi,นิยายวาย,ตลก,ผีในห้อง,18+,สืบสวน...
# ...                                                  ...
# 15248  18+,Boy Love/Yaoi,นิยายโรแมนติก,ตลก,โรงเรียน,น...
# 15249                          เรียลหริ,นิยายวายจีนโบราณ
# 15250                                             ตามจีบ
# 15251                                Boy Love/Yaoi,Mpreg
# 15252   Boy Love/Yaoi,เกิดใหม่ในต่างโลก,ชารอนไม่ทิ้งผัก!
#
#                                                    title   viewer  \
# 0                                  ถ้าผมดื้อพี่จะดุผมไหม  171,581
# 1                                              เดือนพราง    3,437
# 2                               贺陈 | เหมันต์หนึ่งก้านธูป       83
# 3                         Deadly Nightshade (Omegaverse)    1,901
# 4                              ผม ผีในห้อง และคนข้างห้อง       38
# ...                                                  ...      ...
# 15248                               เพลงพราย กลร้ายกลรัก   22,477
# 15249                            จอมใจจักรพรรดิแดนเถื่อน      955
# 15250                          MONEYFORU | เท่าไหร่ว่ามา        5
# 15251       I Demon  King I จอมปีศาจกับราชาทรราช (Mpreg)      339
# 15252  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต | #...      427
#
#                                            new_title           hashtag
# 0                              ถ้าผมดื้อพี่จะดุผมไหม               NaN
# 1                                          เดือนพราง               NaN
# 2                           贺陈 | เหมันต์หนึ่งก้านธูป               NaN
# 3                     Deadly Nightshade (Omegaverse)               NaN
# 4                          ผม ผีในห้อง และคนข้างห้อง               NaN
# ...                                              ...               ...
# 15248                           เพลงพราย กลร้ายกลรัก               NaN
# 15249                        จอมใจจักรพรรดิแดนเถื่อน               NaN
# 15250                      MONEYFORU | เท่าไหร่ว่ามา               NaN
# 15251   I Demon  King I จอมปีศาจกับราชาทรราช (Mpreg)               NaN
# 15252  เกษียณบทตัวร้ายเพื่อกลับบ้านไปเลี้ยงเทวทูต |   ชารอนอย่าทิ้งผัก
#
# [15253 rows x 15 columns]

# %%
string.ascii_lowercase + string.ascii_uppercase
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
print(json.dumps(df4.to_dict('readawritetest')))
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
