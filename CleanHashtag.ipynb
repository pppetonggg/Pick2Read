# %%
import pandas as pd
import numpy as np
import string
import re

df_raw = pd.read_csv(r'C:\Users\paton\Pick2ReadData\readawrite_y1.csv')
df = pd.read_csv(r'C:\Users\paton\Pick2ReadData\tunwalai_y1.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.index
# Out:
# RangeIndex(start=0, stop=48755, step=1)

# %%
df
# Out:
#                author category commentCount isComplete numOfchap  \
# 0          SleepXcody  นิยาย y          154        NaN        23
# 1           PP2527555  นิยาย y           11        NaN         9
# 2          SleepXcody  นิยาย y           12        NaN         2
# 3              Pierre  นิยาย y        2,255         จบ        60
# 4      อัปสรา/วเนกำพู  นิยาย y            5        NaN         2
# ...               ...      ...          ...        ...       ...
# 48750           yuuya  นิยาย y            1        NaN         1
# 48751             ppp  นิยาย y            0        NaN         1
# 48752       Lalinkiss  นิยาย y            2        NaN         0
# 48753           วสุวี  นิยาย y            0        NaN         1
# 48754      Color Beer  นิยาย y            0        NaN         0
#
#                                                      pic ratingCount  \
# 0      https://cdn-th.tunwalai.net/files/story/story-...         628
# ...

# %%
df[df['hashtag'].str.contains('') == True]
# Out:
#             author category commentCount isComplete numOfchap  \
# 20        พี่ติ๊ส.  นิยาย y           80        NaN         6
# 256    blacksummer  นิยาย y           44        NaN        12
# 283      garoo-pop  นิยาย y            4        NaN         1
# 393    jokerginger  นิยาย y           35        NaN         5
# 643          สีดำ?  นิยาย y          530        NaN        32
# ...            ...      ...          ...        ...       ...
# 48675           โฟ  นิยาย y            0        NaN         2
# 48677      พลาสลอน  นิยาย y            0        NaN         0
# 48726     sunday48  นิยาย y            0        NaN         0
# 48730          เบญ  นิยาย y            0        NaN         1
# 48736       Navvip  นิยาย y            1         จบ        42
#
#                                                      pic ratingCount  \
# 20     https://cdn-th.tunwalai.net/files/story/1414/6...         230
# 256    https://cdn-th.tunwalai.net/files/story/13054/...         145
# ...

# %%
ship = ['จ้านเกอ','โชซอก','ป๋อตี้จ้านเกอ','ไคฮุน','ชานแบค','กุกมิน','โยซอก','ป๋อจ้าน','จ้านป๋อ','กุกวี','แจโด','ซึงพโย','มาร์คแบม','แจ็คแจ','ปมนยอง','วีกุก','ออฟกัน','บกพพ','บิวกิ้นพีพี','วีมิน','คั่นกู','กันออฟ','แบมมาร์ค','เนียลอง','ซีเฉิง','ซึงยอนซอก']
r_noship = df[~df.hashtag.str.contains('|'.join(ship), na=False)]
r_noship
# Out:
#                author category commentCount isComplete numOfchap  \
# 0          SleepXcody  นิยาย y          154        NaN        23
# 1           PP2527555  นิยาย y           11        NaN         9
# 2          SleepXcody  นิยาย y           12        NaN         2
# 3              Pierre  นิยาย y        2,255         จบ        60
# 4      อัปสรา/วเนกำพู  นิยาย y            5        NaN         2
# ...               ...      ...          ...        ...       ...
# 48750           yuuya  นิยาย y            1        NaN         1
# 48751             ppp  นิยาย y            0        NaN         1
# 48752       Lalinkiss  นิยาย y            2        NaN         0
# 48753           วสุวี  นิยาย y            0        NaN         1
# 48754      Color Beer  นิยาย y            0        NaN         0
#
#                                                      pic ratingCount  \
# 0      https://cdn-th.tunwalai.net/files/story/story-...         628
# ...

# %%
r_noship[r_noship['hashtag'].str.contains('') == True]
# Out:
#             author category commentCount isComplete numOfchap  \
# 20        พี่ติ๊ส.  นิยาย y           80        NaN         6
# 256    blacksummer  นิยาย y           44        NaN        12
# 283      garoo-pop  นิยาย y            4        NaN         1
# 393    jokerginger  นิยาย y           35        NaN         5
# 643          สีดำ?  นิยาย y          530        NaN        32
# ...            ...      ...          ...        ...       ...
# 48675           โฟ  นิยาย y            0        NaN         2
# 48677      พลาสลอน  นิยาย y            0        NaN         0
# 48726     sunday48  นิยาย y            0        NaN         0
# 48730          เบญ  นิยาย y            0        NaN         1
# 48736       Navvip  นิยาย y            1         จบ        42
#
#                                                      pic ratingCount  \
# 20     https://cdn-th.tunwalai.net/files/story/1414/6...         230
# 256    https://cdn-th.tunwalai.net/files/story/13054/...         145
# ...

# %%
#r_noship.to_csv('readawrite_ints1.csv',encoding='utf-8')
r_noship.to_csv('tunwalai_ints1.csv',encoding='utf-8')
