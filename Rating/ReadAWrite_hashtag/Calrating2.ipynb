# %%
import pandas as pd
import numpy as np
import string

df1 = pd.read_csv(r'C:\Users\paton\Pick2ReadData\TwitterSearch\readawrite_hash_nodup_2.csv')
df2 = pd.read_csv(r'C:\Users\paton\Pick2ReadData\TwitterSearch\readawriteAL_hash_nodup_1.csv')
df = pd.concat([df1, df2])
df.drop('Unnamed: 0', axis=1, inplace=True)
df.index
#df
#df[df['ratingCount'] == '0'] 
df.pic = [str(col) + 'small.gif' for col in df.pic]
df
# Out:
#                    author                    category commentCount  \
# 0                 mplusss  นิยาย Boy Love Secret Room        2,359
# 1            กลิ่นหอมกำจร  นิยาย Boy Love Secret Room           18
# 2               j\'li___.  นิยาย Boy Love Lovely Room            6
# 3                Overrain  นิยาย Boy Love Lovely Room       15,500
# 4           navybroccoli.  นิยาย Boy Love Lovely Room           32
# ..                    ...                         ...          ...
# 376                  24.8  นิยาย Boy Love Secret Room           47
# 377                วายศรี  นิยาย Boy Love Lovely Room           45
# 378    ฟองดูว์เป็นชื่อขนม  นิยาย Boy Love Lovely Room          103
# 379         I\'M WANNABLE  นิยาย Boy Love Lovely Room            4
# 380  ผู้ขี้เกียจเป็นหนึ่ง  นิยาย Boy Love Lovely Room        2,306
#
#                                            description favouriteCount  \
# 0    'เมื่อ 3P มาแบบ 4K พูดได้คำเดียวว่างานนี้ Full...          8,158
# 1    "หลวงพี่จะสึกเมื่อไหร่ครับ" จันทร์หอมเป็นเด็กเ...             78
# 2     Shark#ฉลามอยากกินพืช: นิยาย Boy Love Lovely Room             13
# 3    ความสัมพันธ์เพียงแค่คืนเดียว เปลี่ยนชีวิตของธี...         32,697
# 4               คุณอยากมาดูอควาเรี่ยมตอนเที่ยงคืนมั้ย?             93
# ..                                                 ...            ...
# 376  พ่อกับอาไม่ใช่พี่น้องกันแท้ๆ เพราะฉะนั้นผมกับอ...             74
# 377  คายง หนุ่มชาวบ้านที่สละตนเป็นเหยื่อเซ่นไหว้ภูต...            161
# 378                ขอสักคอมเม้นท์ได้ไหม ในฐานะค่ะก็ได้            445
# 379   แดนิค:ไอหมูโว้ยยยย!!!!! วี:กูชื่อวีว้อยยยยย!!!!!             12
# 380  ตายแล้วไปเกิดใหม่ ไฉนข้าจึงเกิดเป็นสิงโตทะเล แ...          4,103
#
#     isComplete  numOfchap                                                pic  \
# 0           จบ       18.0  https://cdn.readawrite.com/articles/1944/19436...
# 1           จบ        1.0  https://cdn.readawrite.com/articles/1944/19439...
# 2           จบ        2.0  https://cdn.readawrite.com/articles/1954/19538...
# 3           จบ       48.0  https://cdn.readawrite.com/articles/1955/19546...
# 4           จบ        1.0  https://cdn.readawrite.com/articles/1957/19568...
# ..         ...        ...                                                ...
# 376         จบ       10.0  https://cdn.readawrite.com/articles/307/306990...
# 377         จบ        6.0  https://cdn.readawrite.com/articles/385/384216...
# 378         จบ       15.0  https://cdn.readawrite.com/articles/407/406887...
# 379         จบ        0.0  https://cdn.readawrite.com/articles/390/389457...
# 380         จบ       18.0  https://cdn.readawrite.com/articles/397/396003...
#
#     ratingCount                                                tag  \
# 0         1,051  เข้ามาลึกๆ,insert here,Boy Love/Yaoi,18+,20+,น...
# 1             9                  18+,Boy Love/Yaoi,นิยายวาย,บาปหนา
# 2             4                                                NaN
# 3         5,490  Boy Love/Yaoi,Mpreg,นิยายวาย,18+,นิยายวายฟีลกู...
# 4            23  Midnight aquarium,อควาเรี่ยมเที่ยงคืน,boyslove...
# ..          ...                                                ...
# 376          16                               Boy Love/Yaoi,อาหลาน
# 377          28                                Boy Love/Yaoi,Mpreg
# 378        52.0                         Boy Love/Yaoi,ตลก,นิยายรัก
# 379         4.0                                  Boy Love/Yaoi,18+
# 380       975.0  Boy Love/Yaoi,ตลก,แฟนตาซี,น่ารัก,คอมเมดี้,เกิด...
#
#                                                  title     viewer  \
# 0                   #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)    721,051
# 1                                           #คุณสงฆ์ขา        807
# 2                                 Shark#ฉลามอยากกินพืช        265
# 3    (Omegeverse) แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น...  3,098,602
# 4               Midnight aquarium #อควาเรี่ยมเที่ยงคืน      1,326
# ..                                                 ...        ...
# 376                            ✎ #เขียนถึงคุณอา —☆「BL」      2,981
# 377              ・゜AROWANA\'s Bride・゜ #เจ้าสาวปลามังกร      5,256
# 378              (◉ω◉) #สมชาติไม่ชอบนะค่ะ (ಥ﹏ಥ) [Yaoi]     15,593
# 379                              มีเมียเป็นหมู #แดนฮวี        449
# 380                              #เกิดเป็นสิงโตทะเล []    180,743
#
#                              new_title              hashtag  \
# 0                                  NaN           เข้ามาลึกๆ
# 1                                  NaN            คุณสงฆ์ขา
# 2                                  NaN       ฉลามอยากกินพืช
# 3    แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น      แด๊ดดี้คลั่งรัก
# 4                                  NaN  อควาเรี่ยมเที่ยงคืน
# ..                                 ...                  ...
# 376                                NaN        เขียนถึงคุณอา
# 377                                NaN      เจ้าสาวปลามังกร
# 378                                NaN    สมชาติไม่ชอบนะค่ะ
# 379                      มีเมียเป็นหมู               แดนฮวี
# 380                                NaN    เกิดเป็นสิงโตทะเล
#
#                                      url
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 376  https://www.readawrite.com/a/lz75l5
# 377  https://www.readawrite.com/a/lz8xml
# 378  https://www.readawrite.com/a/lz9h5c
# 379  https://www.readawrite.com/a/lz92wc
# 380  https://www.readawrite.com/a/lz989d
#
# [1424 rows x 15 columns]

# %%
hashtag = df['hashtag'].tolist()
hfile = []
for i in hashtag:
    name = '#'+str(i)+'.xlsx'
    hfile.append(name)
#hfile

# %%
import os.path
from os import path
i = 0
count = 0
folder = 'C:/Users/paton/Pick2ReadData/Rating/ReadAWrite_hashtag/' 
noTweet = []
noAccountReview = []
noHashReview = []
for file in hfile:
    name = os.path.join(folder,file)
    #print(name)
    if path.exists(name): 
        #print(name)
        #print(hashtag[i])
        exec("%s = pd.read_excel('%s')" % (hashtag[i],name))
        exec("%s['user_descriptions_owner'] = %s['user_descriptions_owner'].astype('object')" % (hashtag[i],hashtag[i]))
        exec("%s.drop('Unnamed: 0', axis=1, inplace=True)" % (hashtag[i]))
        exec("noTweet.append(len(%s.index))" % (hashtag[i]))
        exec("noAccountReview.append(len(%s[%s['user_descriptions_owner'].str.contains('แนะนำนิยาย|รีวิวนิยาย') == True]))" % (hashtag[i],hashtag[i]))
        exec("noHashReview.append(len(%s[%s['text'].str.contains('#แนะนำนิยาย|#รีวิวนิยาย') == True]))" % (hashtag[i],hashtag[i]))
        count = count + 1
    else:
        noTweet.append(np.nan)
        noAccountReview.append(np.nan)
        noHashReview.append(np.nan)
    i = i+1
df['countTweet'] = noTweet
df['countAccountReview'] = noAccountReview
df['countHashReview'] = noHashReview
print(count)
# Out:
# 231

# %%
df[df['hashtag'].str.contains('เขาชื่ออันวาร์')]
เขาชื่ออันวาร์
# Out:
#               create_at      item_serach  user_account  \
# 0   2021-02-01 11:53:53  #เขาชื่ออันวาร์   Bambam__mie
# 1   2021-02-01 11:53:34  #เขาชื่ออันวาร์    bolovezhan
# 2   2021-02-01 11:52:11  #เขาชื่ออันวาร์     sinpba_oh
# 3   2021-02-01 11:45:01  #เขาชื่ออันวาร์     Temps_xxx
# 4   2021-02-01 11:00:00  #เขาชื่ออันวาร์       p_62442
# ..                  ...              ...           ...
# 373 2021-01-24 20:53:08  #เขาชื่ออันวาร์        czn505
# 374 2021-01-24 20:32:58  #เขาชื่ออันวาร์  Superautumnn
# 375 2021-01-24 20:18:17  #เขาชื่ออันวาร์        czn505
# 376 2021-01-24 20:18:09  #เขาชื่ออันวาร์        czn505
# 377 2021-01-24 20:18:07  #เขาชื่ออันวาร์        czn505
#
#                                       user_description  User_follower  \
# 0                                       💜 I purple U 💜            382
# 1    กูเคยคลั่งรักป๋อแต่ตอนนี้มากกว่าคลั่งรักแล้ว\n...             10
# 2       #succulember #plantober #veddie #stony #thorki             11
# 3    'เป็นหมีที่ชอบนอนและกิน'| working | 𝙱𝚎𝚊𝚛 𝚒𝚗 𝚝𝚑...            271
# 4                                               ~1999~              4
# ..                                                 ...            ...
# 373  🍸Do you know what it feels like to fall in lov...           3176
# 374                       ขอให้เติบโตไปอย่างมีความสุข.            309
# 375  🍸Do you know what it feels like to fall in lov...           3176
# 376  🍸Do you know what it feels like to fall in lov...           3176
# 377  🍸Do you know what it feels like to fall in lov...           3176
#
#                                                   text           hashtag  \
# 0    #เขาชื่ออันวาร์ สปอยล์ตอนล่าสุดคือรู้เลยว่ามีค...   /เขาชื่ออันวาร์
# 1    #เขาชื่ออันวาร์\n\nขอแนะนำให้อ่านจากใจจจ ตอนล่...   /เขาชื่ออันวาร์
# 2    #เขาชื่ออันวาร์ นึกตอนช่วยน้องแต่งตัว อยากเห็น...   /เขาชื่ออันวาร์
# 3    เป็นนิยายที่อ่านแล้วร้อนท้องทุกครั้งเวลามีเอนซ...   /เขาชื่ออันวาร์
# 4    เนี่ยยยย มาหวะ!!!! \n#เขาชื่ออันวาร์ https://t...   /เขาชื่ออันวาร์
# ..                                                 ...               ...
# 373  #เขาชื่ออันวาร์ ยกให้เป็นเดอะเบสเลยอ่า ดือมาก ...   /เขาชื่ออันวาร์
# 374  ลืมแปะเพลย์ลิสต์ประกอบพาร์ท 3 ใครอ่านอยู่เปิดค...   /เขาชื่ออันวาร์
# 375            #เขาชื่ออันวาร์ https://t.co/cEGMZLlL3E   /เขาชื่ออันวาร์
# 376  ไปข้างนอกรีบกลับเข้ามาอ่านข้าวปลาไม่กินมันเป็น...   /เขาชื่ออันวาร์
# 377  กำลังตัดใจนะคะคุณอันวาร์🥺 #เขาชื่ออันวาร์ http...   /เขาชื่ออันวาร์
#
#      retweet_count  favourite_count       at_tweet  \
# 0              114               80         czn505
# 1               58               97        PTHx4x4
# 2                0                0      sinpba_oh
# 3                0                0      Temps_xxx
# 4                1                2  kaormloveyibo
# ..             ...              ...            ...
# 373              1                1  taeissopretty
# 374             48               39         czn505
# 375              2                0    lonelyhold8
# 376              1                0       onlymmeq
# 377              1                0      jsbn_film
#
#                                user_descriptions_owner
# 0    🍸Do you know what it feels like to fall in lov...
# 1    ≫ #ปรมาจารย์ลัทธิมาร | #BIGBANG 👑 | #Yuzhou |T...
# 2       #succulember #plantober #veddie #stony #thorki
# 3    'เป็นหมีที่ชอบนอนและกิน'| working | 𝙱𝚎𝚊𝚛 𝚒𝚗 𝚝𝚑...
# 4    สเป็ค : บิวกิ้น พุฒิพงศ์ อัสสรัตนกุล ❤️💙 𝘀𝗶𝗻𝗰𝗲...
# ..                                                 ...
# 373                    ชาติ ศาสนา พระมหาบังทันโซยอนดัน
# 374  🍸Do you know what it feels like to fall in lov...
# 375  full-time mommeaw, part-time anime addictor ; ...
# 376                                                NaN
# 377                                         EXO-L 🧡KH🧡
#
# [378 rows x 11 columns]

# %%
#จำนวนTweet
print("จำนวนทวิต")
nTweet = len(เขาชื่ออันวาร์.index)
print(nTweet)

#แอคแนะนำนิยาย
print("จำนวนแอคแนะนำนิยาย")
nAccountReview = len(เขาชื่ออันวาร์[เขาชื่ออันวาร์['user_descriptions_owner'].str.contains('แนะนำนิยาย|รีวิวนิยาย') == True])
print(nAccountReview)
เขาชื่ออันวาร์[เขาชื่ออันวาร์['user_descriptions_owner'].str.contains('แนะนำนิยาย|รีวิวนิยาย') == True]

#จำนวน#แนะนำนิยาย
print("จำนวน#แนะนำนิยาย")
nHashReview = len(เขาชื่ออันวาร์[เขาชื่ออันวาร์['text'].str.contains('#แนะนำนิยาย|#รีวิวนิยาย') == True])
print(nHashReview)
เขาชื่ออันวาร์[เขาชื่ออันวาร์['text'].str.contains('#แนะนำนิยาย|#รีวิวนิยาย') == True]

เขาชื่ออันวาร์
#inTweet[inTweet['ratingNoTweet_q'] > 3.0]
#inTweet
# Out:
# จำนวนทวิต
# 378
# จำนวนแอคแนะนำนิยาย
# 3
# จำนวน#แนะนำนิยาย
# 2
#               create_at      item_serach  user_account  \
# 0   2021-02-01 11:53:53  #เขาชื่ออันวาร์   Bambam__mie
# 1   2021-02-01 11:53:34  #เขาชื่ออันวาร์    bolovezhan
# 2   2021-02-01 11:52:11  #เขาชื่ออันวาร์     sinpba_oh
# 3   2021-02-01 11:45:01  #เขาชื่ออันวาร์     Temps_xxx
# 4   2021-02-01 11:00:00  #เขาชื่ออันวาร์       p_62442
# ..                  ...              ...           ...
# 373 2021-01-24 20:53:08  #เขาชื่ออันวาร์        czn505
# 374 2021-01-24 20:32:58  #เขาชื่ออันวาร์  Superautumnn
# 375 2021-01-24 20:18:17  #เขาชื่ออันวาร์        czn505
# 376 2021-01-24 20:18:09  #เขาชื่ออันวาร์        czn505
# 377 2021-01-24 20:18:07  #เขาชื่ออันวาร์        czn505
#
#                                       user_description  User_follower  \
# 0                                       💜 I purple U 💜            382
# 1    กูเคยคลั่งรักป๋อแต่ตอนนี้มากกว่าคลั่งรักแล้ว\n...             10
# 2       #succulember #plantober #veddie #stony #thorki             11
# 3    'เป็นหมีที่ชอบนอนและกิน'| working | 𝙱𝚎𝚊𝚛 𝚒𝚗 𝚝𝚑...            271
# 4                                               ~1999~              4
# ..                                                 ...            ...
# 373  🍸Do you know what it feels like to fall in lov...           3176
# 374                       ขอให้เติบโตไปอย่างมีความสุข.            309
# 375  🍸Do you know what it feels like to fall in lov...           3176
# 376  🍸Do you know what it feels like to fall in lov...           3176
# 377  🍸Do you know what it feels like to fall in lov...           3176
#
#                                                   text           hashtag  \
# 0    #เขาชื่ออันวาร์ สปอยล์ตอนล่าสุดคือรู้เลยว่ามีค...   /เขาชื่ออันวาร์
# 1    #เขาชื่ออันวาร์\n\nขอแนะนำให้อ่านจากใจจจ ตอนล่...   /เขาชื่ออันวาร์
# 2    #เขาชื่ออันวาร์ นึกตอนช่วยน้องแต่งตัว อยากเห็น...   /เขาชื่ออันวาร์
# 3    เป็นนิยายที่อ่านแล้วร้อนท้องทุกครั้งเวลามีเอนซ...   /เขาชื่ออันวาร์
# 4    เนี่ยยยย มาหวะ!!!! \n#เขาชื่ออันวาร์ https://t...   /เขาชื่ออันวาร์
# ..                                                 ...               ...
# 373  #เขาชื่ออันวาร์ ยกให้เป็นเดอะเบสเลยอ่า ดือมาก ...   /เขาชื่ออันวาร์
# 374  ลืมแปะเพลย์ลิสต์ประกอบพาร์ท 3 ใครอ่านอยู่เปิดค...   /เขาชื่ออันวาร์
# 375            #เขาชื่ออันวาร์ https://t.co/cEGMZLlL3E   /เขาชื่ออันวาร์
# 376  ไปข้างนอกรีบกลับเข้ามาอ่านข้าวปลาไม่กินมันเป็น...   /เขาชื่ออันวาร์
# 377  กำลังตัดใจนะคะคุณอันวาร์🥺 #เขาชื่ออันวาร์ http...   /เขาชื่ออันวาร์
#
#      retweet_count  favourite_count       at_tweet  \
# 0              114               80         czn505
# 1               58               97        PTHx4x4
# 2                0                0      sinpba_oh
# 3                0                0      Temps_xxx
# 4                1                2  kaormloveyibo
# ..             ...              ...            ...
# 373              1                1  taeissopretty
# 374             48               39         czn505
# 375              2                0    lonelyhold8
# 376              1                0       onlymmeq
# 377              1                0      jsbn_film
#
#                                user_descriptions_owner
# 0    🍸Do you know what it feels like to fall in lov...
# 1    ≫ #ปรมาจารย์ลัทธิมาร | #BIGBANG 👑 | #Yuzhou |T...
# 2       #succulember #plantober #veddie #stony #thorki
# 3    'เป็นหมีที่ชอบนอนและกิน'| working | 𝙱𝚎𝚊𝚛 𝚒𝚗 𝚝𝚑...
# 4    สเป็ค : บิวกิ้น พุฒิพงศ์ อัสสรัตนกุล ❤️💙 𝘀𝗶𝗻𝗰𝗲...
# ..                                                 ...
# 373                    ชาติ ศาสนา พระมหาบังทันโซยอนดัน
# 374  🍸Do you know what it feels like to fall in lov...
# 375  full-time mommeaw, part-time anime addictor ; ...
# 376                                                NaN
# 377                                         EXO-L 🧡KH🧡
#
# [378 rows x 11 columns]

# %%
#Calculate rating for twitter
inTweet = df[df['countTweet'].notnull()]
inTweet.reset_index(drop=True, inplace=True)

import jenkspy

"""inTweet['ratingNoTweet_j'] = pd.cut(
    inTweet['countTweet'],
    bins=jenkspy.jenks_breaks(inTweet['countTweet'], nb_class=5),
    labels=[1,2,3,4,5],
    include_lowest=True)
inTweet['ratingNoTweet_j'] = inTweet['ratingNoTweet_j'].astype('float64')"""
inTweet['ratingNoTweet_q'] = pd.qcut(inTweet['countTweet'], 5, labels=False, duplicates = 'drop')
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].astype('float64')
#inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].fillna(1)
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].replace(0.0,1.25)
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].replace(1.0,2.5)
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].replace(2.0,3.75)
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].replace(3.0,5)

#Model 3 and 4
"""inTweet['ratingHashReview_j'] = pd.cut(
    inTweet['countHashReview'],
    bins=jenkspy.jenks_breaks(inTweet['countHashReview'], nb_class=5),
    labels=False,
    include_lowest=True, duplicates='drop')
inTweet['ratingHashReview_j'] = inTweet['ratingHashReview_j'].astype('float64')"""
inTweet['ratingHashReview_q'] = pd.qcut(inTweet['countHashReview'], 5, labels=False, duplicates = 'drop')
inTweet['ratingHashReview_q'] = inTweet['ratingHashReview_q'].astype('float64')
#inTweet['ratingHashReview_q'] = inTweet['ratingHashReview_q'].fillna(1.7)
inTweet['ratingHashReview_q'] = inTweet['ratingHashReview_q'].replace(0.0,2.5)
inTweet['ratingHashReview_q'] = inTweet['ratingHashReview_q'].replace(1.0,5)

"""inTweet['ratingAccountReview_j'] = pd.cut(
    inTweet['countAccountReview'],
    bins=jenkspy.jenks_breaks(inTweet['countAccountReview'], nb_class=5),
    labels=False,
    include_lowest=True, duplicates='drop')
inTweet['ratingAccountReview_j'] = inTweet['ratingAccountReview_j'].astype('float64')"""
inTweet['ratingAccountReview_q'] = pd.qcut(inTweet['countAccountReview'], 5, labels=False, duplicates = 'drop')
#inTweet['ratingAccountReview_q'] = inTweet['ratingAccountReview_q'].fillna(1.3)
#inTweet['ratingAccountReview_q'] = inTweet['ratingAccountReview_q'].replace(0.0,2.5)
inTweet['ratingAccountReview_q'] = inTweet['ratingAccountReview_q'].replace(0,2.5)
inTweet['ratingAccountReview_q'] = inTweet['ratingAccountReview_q'].replace(1,5.0)
#if inTweet['']

"""if inTweet['ratingAccountReview_j'].unique().all() < 4.0 and inTweet['ratingAccountReview_j'].unique().all() < 4.0 :
    inTweet[['ratingHashReview_j','ratingAccountReview_j']] = inTweet[['ratingHashReview_j','ratingAccountReview_j']].replace(3.0,5.0) 
    inTweet[['ratingHashReview_j','ratingAccountReview_j']] = inTweet[['ratingHashReview_j','ratingAccountReview_j']].replace(2.0,4.0) 
    inTweet[['ratingHashReview_j','ratingAccountReview_j']] = inTweet[['ratingHashReview_j','ratingAccountReview_j']].replace(1.0,3.0)
    inTweet[['ratingHashReview_j','ratingAccountReview_j']] = inTweet[['ratingHashReview_j','ratingAccountReview_j']].replace(0.0,2.0)"""
    

#inTweet['ratingTwitter3_j'] = ((inTweet.ratingAccountReview_j+inTweet.ratingHashReview_j+inTweet.ratingNoTweet_j)/3).round(1)
#inTweet['ratingTwitter4_j'] = ((inTweet.ratingAccountReview_j+inTweet.ratingHashReview_j+(inTweet.ratingNoTweet_j*2))/4).round(1)
inTweet['ratingTwitter3_q'] = ((inTweet.ratingAccountReview_q+inTweet.ratingHashReview_q+inTweet.ratingNoTweet_q)/3).round(1)
inTweet['ratingTwitter4_q'] = ((inTweet.ratingAccountReview_q+inTweet.ratingHashReview_q+(inTweet.ratingNoTweet_q*2))/4).round(1)
inTweet = inTweet[['hashtag', 'ratingNoTweet_q', 'ratingHashReview_q','ratingAccountReview_q','ratingTwitter3_q','ratingTwitter4_q']]
#inTweet[['countHashReview']][inTweet['countHashReview']>1.0].sort_values(by = 'countHashReview', ascending = False)
inTweet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  hashtag  ratingNoTweet_q  ratingHashReview_q  \
# 0             เข้ามาลึกๆ             1.25                 2.5
# 1        แด๊ดดี้คลั่งรัก             2.50                 2.5
# 2           คุณเป็นของผม             1.25                 2.5
# 3              เราของเธอ             3.75                 2.5
# 4               หลงใจรัก             1.25                 2.5
# ..                   ...              ...                 ...
# 226  ชีวิตประจำวันนัมธิน             3.75                 2.5
# 227       คุณเชนเอาแต่ใจ             3.75                 5.0
# 228  ที่รักข้ากลับมาแล้ว             3.75                 5.0
# 229               แดนฮวี             1.25                 2.5
# 230    เกิดเป็นสิงโตทะเล             1.25                 2.5
#
#      ratingAccountReview_q  ratingTwitter3_q  ratingTwitter4_q
# 0                      2.5               2.1               1.9
# 1                      2.5               2.5               2.5
# 2                      2.5               2.1               1.9
# 3                      2.5               2.9               3.1
# 4                      2.5               2.1               1.9
# ..                     ...               ...               ...
# 226                    2.5               2.9               3.1
# 227                    2.5               3.8               3.8
# 228                    5.0               4.6               4.4
# 229                    2.5               2.1               1.9
# 230                    2.5               2.1               1.9
#
# [231 rows x 6 columns]

# %%
"""print('j')
print(inTweet['ratingAccountReview_j'].unique())
print(inTweet['ratingHashReview_j'].unique())
print(inTweet['ratingNoTweet_j'].unique())"""
print('q')
print(inTweet['ratingNoTweet_q'].unique())
print(inTweet['ratingHashReview_q'].unique())
print(inTweet['ratingAccountReview_q'].unique())
#len(inTweet)
#inTweet['ratingTwitter3'].sort()
inTweet.sort_values(by='ratingTwitter3_q', ascending=False)
#inTweet.sort_values(by='ratingTwitter4', ascending=False)
# Out:
# q
# [1.25 2.5  3.75 5.  ]
# [2.5 5. ]
# [2.5 5. ]
#                         hashtag  ratingNoTweet_q  ratingHashReview_q  \
# 220            คุณติอร่อยที่สุด             5.00                 5.0
# 211                    นิยายวาย             5.00                 5.0
# 110             อย่าบอกป๊านะม๊า             5.00                 5.0
# 22                     อรุณรุ่ง             5.00                 5.0
# 185                 ฉลามสิ้นลาย             5.00                 5.0
# ..                          ...              ...                 ...
# 84                    พี่เลี้ยง             1.25                 2.5
# 81   ลู่หลินไม่อินประวัติศาสตร์             1.25                 2.5
# 79                  อย่าอ่อนไหว             1.25                 2.5
# 75       รักร้ายของกระต่ายแสนซน             1.25                 2.5
# 230           เกิดเป็นสิงโตทะเล             1.25                 2.5
#
#      ratingAccountReview_q  ratingTwitter3_q  ratingTwitter4_q
# 220                    5.0               5.0               5.0
# 211                    5.0               5.0               5.0
# 110                    5.0               5.0               5.0
# 22                     5.0               5.0               5.0
# 185                    5.0               5.0               5.0
# ..                     ...               ...               ...
# 84                     2.5               2.1               1.9
# 81                     2.5               2.1               1.9
# 79                     2.5               2.1               1.9
# 75                     2.5               2.1               1.9
# 230                    2.5               2.1               1.9
#
# [231 rows x 6 columns]

# %%
df = df.join(inTweet.set_index('hashtag'), on='hashtag', how='left')
inTweet.dtypes
# Out:
# hashtag                   object
# ratingNoTweet_q          float64
# ratingHashReview_q       float64
# ratingAccountReview_q    float64
# ratingTwitter3_q         float64
# ratingTwitter4_q         float64
# dtype: object

# %%
df['ratingTwitter3_q'] = df['ratingTwitter3_q'].fillna(0)
df['ratingTwitter4_q'] = df['ratingTwitter4_q'].fillna(0)
df['ratingNoTweet_q'] = df['ratingNoTweet_q'].fillna(0)
df['ratingHashReview_q'] = df['ratingHashReview_q'].fillna(0)
df['ratingAccountReview_q'] = df['ratingAccountReview_q'].fillna(0)
print(inTweet['ratingTwitter3_q'].unique())
print(inTweet['ratingTwitter4_q'].unique())
df[['title','countTweet','ratingNoTweet_q','ratingHashReview_q','ratingAccountReview_q','ratingTwitter3_q','ratingTwitter4_q']][df['ratingTwitter3_q'] == 0].sort_values(by = 'ratingTwitter4_q', ascending = False)
# Out:
# [2.1 2.5 2.9 4.2 3.3 3.8 5.  4.6]
# [1.9 2.5 3.1 4.4 3.8 5. ]
#                                                  title  countTweet  \
# 1                                           #คุณสงฆ์ขา         NaN
# 953                        Azurel Blue #สุดขอบทะเลคราม         NaN
# 951                             องศาชัญญา •C° #อามิลล์         NaN
# 950                               #ขอรักธรรมดาๆให้ผมที         NaN
# 949                           Butter🧀เนยไม่อ้วน#รามเนย         NaN
# ..                                                 ...         ...
# 472                        [BL] #ใต้อุ้งละอองของฝ่าบาท         NaN
# 471  BL : เพียงรวินท์ (The little secret of Lotus) ...         NaN
# 470                     #ต้องฮัก ฝันหวานเมื่อรักหวนคืน         NaN
# 469  #เสียงกระซิบขับขานในจักรวาลสีน้ำเงิน [Rainvers...         NaN
# 378              (◉ω◉) #สมชาติไม่ชอบนะค่ะ (ಥ﹏ಥ) [Yaoi]         NaN
#
#      ratingNoTweet_q  ratingHashReview_q  ratingAccountReview_q  \
# 1                0.0                 0.0                    0.0
# 953              0.0                 0.0                    0.0
# 951              0.0                 0.0                    0.0
# 950              0.0                 0.0                    0.0
# 949              0.0                 0.0                    0.0
# ..               ...                 ...                    ...
# 472              0.0                 0.0                    0.0
# 471              0.0                 0.0                    0.0
# 470              0.0                 0.0                    0.0
# 469              0.0                 0.0                    0.0
# 378              0.0                 0.0                    0.0
#
#      ratingTwitter3_q  ratingTwitter4_q
# 1                 0.0               0.0
# 953               0.0               0.0
# 951               0.0               0.0
# 950               0.0               0.0
# 949               0.0               0.0
# ..                ...               ...
# 472               0.0               0.0
# 471               0.0               0.0
# 470               0.0               0.0
# 469               0.0               0.0
# 378               0.0               0.0
#
# [1193 rows x 7 columns]

# %%
#rating of website
df['ratingCount'] = df['ratingCount'].str.replace(',', '')
df['viewer'] = df['viewer'].str.replace(',', '')
df[['ratingCount', 'viewer']] = df[['ratingCount', 'viewer']].apply(pd.to_numeric)

df['ratingLike_q'] = pd.qcut(df['ratingCount'], 5, labels=[1,2,3,4,5])


df['ratingView_q'] = pd.qcut(df['viewer'], 5, labels=[1,2,3,4,5])

df[['ratingView_q','ratingLike_q']] = df[['ratingView_q','ratingLike_q']].astype('float64')

df['ratingWebsite_q'] = (((df.ratingView_q*2)+(df.ratingLike_q))/3).round(1)

df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']]
# Out:
#                                                  title   viewer  ratingCount  \
# 0                   #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)   721051       1051.0
# 1                                           #คุณสงฆ์ขา      807          9.0
# 2                                 Shark#ฉลามอยากกินพืช      265          4.0
# 3    (Omegeverse) แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น...  3098602       5490.0
# 4               Midnight aquarium #อควาเรี่ยมเที่ยงคืน     1326         23.0
# ..                                                 ...      ...          ...
# 376                            ✎ #เขียนถึงคุณอา —☆「BL」     2981         16.0
# 377              ・゜AROWANA\'s Bride・゜ #เจ้าสาวปลามังกร     5256         28.0
# 378              (◉ω◉) #สมชาติไม่ชอบนะค่ะ (ಥ﹏ಥ) [Yaoi]    15593         52.0
# 379                              มีเมียเป็นหมู #แดนฮวี      449          4.0
# 380                              #เกิดเป็นสิงโตทะเล []   180743        975.0
#
#      ratingView_q  ratingLike_q  ratingWebsite_q
# 0             5.0           5.0              5.0
# 1             3.0           3.0              3.0
# 2             2.0           3.0              2.3
# 3             5.0           5.0              5.0
# 4             3.0           4.0              3.3
# ..            ...           ...              ...
# 376           4.0           4.0              4.0
# 377           4.0           4.0              4.0
# 378           4.0           4.0              4.0
# 379           3.0           3.0              3.0
# 380           5.0           5.0              5.0
#
# [1424 rows x 6 columns]

# %%
df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']][df['viewer'] == 3.0].sort_values(by='viewer', ascending = False).head(60) 
df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']][(df['viewer'] > 800) & (df['viewer'] < 1000)].sort_values(by='ratingCount',ascending = False)
df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']].sort_values(by='ratingWebsite_q', ascending = False).head(50)
# Out:
#                                                   title   viewer  ratingCount  \
# 0                    #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)   721051       1051.0
# 822                                      #รักริมระเบียง   112561        392.0
# 895   [END]บอสปล่อยผมไปเถอะครับ(Mpreg)(รอรีไรท์)#มาต...   340284        560.0
# 888                           #ไม่คิดว่าจะรักกัน (Yaoi)    98196        126.0
# 878                         yaoi | gugether #รับน้อง101    32270        351.0
# 870         #โลกหน้าหวังว่าจะไม่เจอกันอีก (multi-verse)    30927        152.0
# 869                           ผมเป็นสุนัขของคุณ #คอยรัก    41420        194.0
# 864                          Safe n Sound #ทะเลคุณยักษ์    28378        236.0
# 861                [END] Laboratory no.9 #ท่านนายพลขนฟู   677162       2163.0
# 854                            #รักวุ่นวายของนายแอคเค่อ    87493        351.0
# 839                       [END] #เหนือฟ้าคือชลธี [YAOI]    52425         97.0
# 835                          Fortune of Love #ศาสตร์รัก   160612        600.0
# 833                ได้ผัวเด็กเขาว่าอายุยืน #พู่กันแทงไท    21277        109.0
# 816                                TALK #เร้าโฬม [Yaoi]   517603       1147.0
# 908   ช่วยไม่ได้ก็ข้ามันเก่ง #ไอ้คมสันคนหยาบ (Y,จีนโ...    82412        319.0
# 809                                     Mr.Lee #ลีจานิน   184394        571.0
# 784                #ผมจะไม่เข้าด้อมไหนอีกต่อไป {Mpreg }    21849        106.0
# 781   [END] #ฟ้าสั่งให้เลิกรัก (YAOI) [สนพ.Deep Publ...   126279        523.0
# 776                      #เบต้าคั่นกลาง (3P/Omegaverse)   463795        923.0
# 763                          #หมอดินไม่อินเครื่องกล END   693868       2492.0
# 739                      หวงรัก #ภูเอย [ yaoi | Mpreg ]    26035        172.0
# 737   [Ebook มาแล้วจ้า] Love Baker #ที่รักของคุณดล [...   502724       1155.0
# 731                      ３０日まで #เริ่มต้นใหม่ในสามสิบวัน   249224       1349.0
# 727   หาเพื่อนนอนสนใจทัก DM ครับ #เพื่อนกล่อมนอน ที่...   299479       1066.0
# 723                                ค่อยๆ รัก | #เจ๋งพัท   292734       1206.0
# 716   My Boy น้องม.2อยากเป็นแฟนพี่ปี4 (โชตะ) #รุจอิน...    70278        126.0
# 896                                #จั๊ดกับผัวสาวของเขา    89763        449.0
# 918                 1st #คุณคืออันดับหนึ่ง [Omegaverse]   138924        677.0
# 708       #สามีของผมคือบอส My husband is a boss (Mpreg)    53089        117.0
# 1002                                            #น้ำกาม    74744         92.0
# 4          (END) Say Yes If you love me #เซย์เท่ไหมบุ๊ค    71462        123.0
# 2              A Liar to Love #เล่ห์รักลวงสังหาร (Yaoi)    55616        321.0
# 1                    #แด๊ดดี้ดีที่สุด [Call U daddiest]   189623        443.0
# 1041                      UNKNOWN LOVER #เขาชื่ออันวาร์  1340550       4098.0
# 1039  #รอนจะรัก Until true love fine you คำสาปร้าย.....    26835        144.0
# 1037                #ผมรับวาดรูปอย่างเดียว (Omegaverse)   225377       1293.0
# 1027                                  #ช่วงนี้เดือนหนาว    84675        682.0
# 1019                They call me “Nana” #ความลับของนานะ    60176        157.0
# 1008                     #ผมเป็นฮองเฮาเขาเป็นฮ่องเต้ BL   187461        907.0
# 1006             I\'m a baby red panda #ผมคือแพนด้าเด็ก   257007       2082.0
# 1003                                        #หัวหน้าเป๋   192582        874.0
# 1001             My omega boss (omegaverse) #โอเมก้าบอส    21349        199.0
# 923                       #แอปล่าแต้ม (น้องเพ้นท์ภาค 2)   104884        280.0
# 999                                  [BL] #พี่ครับเบานะ   107570        143.0
# 995   -END- [Mpreg / Harem] โอเมก้าควีนแห่งโลกครึ่งอ...    35797        121.0
# 990                           #ต้นข้าวไม่อยากตาย (Yaoi)    33455        126.0
# 983                    daddy love me harder #รักหอมแรงๆ    36043        195.0
# 978                     Put me in your mouth #มอมเมาคุณ   373500       1196.0
# 954                        Prussian Blue #สัญญาสาปสมุทร    28880        122.0
# 953                         Azurel Blue #สุดขอบทะเลคราม    50385        140.0
#
#       ratingView_q  ratingLike_q  ratingWebsite_q
# 0              5.0           5.0              5.0
# 822            5.0           5.0              5.0
# 895            5.0           5.0              5.0
# 888            5.0           5.0              5.0
# 878            5.0           5.0              5.0
# 870            5.0           5.0              5.0
# 869            5.0           5.0              5.0
# 864            5.0           5.0              5.0
# 861            5.0           5.0              5.0
# 854            5.0           5.0              5.0
# 839            5.0           5.0              5.0
# 835            5.0           5.0              5.0
# 833            5.0           5.0              5.0
# 816            5.0           5.0              5.0
# 908            5.0           5.0              5.0
# 809            5.0           5.0              5.0
# 784            5.0           5.0              5.0
# 781            5.0           5.0              5.0
# 776            5.0           5.0              5.0
# 763            5.0           5.0              5.0
# 739            5.0           5.0              5.0
# 737            5.0           5.0              5.0
# 731            5.0           5.0              5.0
# 727            5.0           5.0              5.0
# 723            5.0           5.0              5.0
# 716            5.0           5.0              5.0
# 896            5.0           5.0              5.0
# 918            5.0           5.0              5.0
# 708            5.0           5.0              5.0
# 1002           5.0           5.0              5.0
# 4              5.0           5.0              5.0
# 2              5.0           5.0              5.0
# 1              5.0           5.0              5.0
# 1041           5.0           5.0              5.0
# 1039           5.0           5.0              5.0
# 1037           5.0           5.0              5.0
# 1027           5.0           5.0              5.0
# 1019           5.0           5.0              5.0
# 1008           5.0           5.0              5.0
# 1006           5.0           5.0              5.0
# 1003           5.0           5.0              5.0
# 1001           5.0           5.0              5.0
# 923            5.0           5.0              5.0
# 999            5.0           5.0              5.0
# 995            5.0           5.0              5.0
# 990            5.0           5.0              5.0
# 983            5.0           5.0              5.0
# 978            5.0           5.0              5.0
# 954            5.0           5.0              5.0
# 953            5.0           5.0              5.0

# %%
df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']].sort_values(by='ratingCount', ascending  = True).head(50)
df[['viewer','ratingCount','title','ratingView_q','ratingLike_q','ratingWebsite_q','ratingWebsite_q']][df['ratingView_q'] > 4.0].sort_values(by='viewer', ascending = False)
# Out:
#       viewer  ratingCount                                              title  \
# 683  5479575      15802.0     (omegaverse) midnight fortune #อย่าบอกป๊านะม๊า
# 8    3787353       8109.0        I\'ll give you the world #เมกาโลมา (รีไรท์)
# 136  3662619       7393.0  pre-order[omegaverse/Mpreg] Finding Cinnamon B...
# 135  3484456      11639.0                             #ก็จะดื้อ (omegaverse)
# 40   3387938       7244.0                          LIVE #น้องไอไลฟ์สด [Yaoi]
# ..       ...          ...                                                ...
# 204    21288         99.0         Mission impossible #คนโปรดโคตรรัก [ Yaoi ]
# 833    21277        109.0               ได้ผัวเด็กเขาว่าอายุยืน #พู่กันแทงไท
# 486    20831         26.0                           พี่ชัชแซ่บมาก | #ชัชค่าย
# 580    20791         98.0                    Yours #ทั้งหมดเป็นของคุณ (BDSM)
# 693    20547         57.0                #นอกจากเอาคุณแล้วผมก็ไม่เก่งอะไรเลย
#
#      ratingView_q  ratingLike_q  ratingWebsite_q  ratingWebsite_q
# 683           5.0           5.0              5.0              5.0
# 8             5.0           5.0              5.0              5.0
# 136           5.0           5.0              5.0              5.0
# 135           5.0           5.0              5.0              5.0
# 40            5.0           5.0              5.0              5.0
# ..            ...           ...              ...              ...
# 204           5.0           5.0              5.0              5.0
# 833           5.0           5.0              5.0              5.0
# 486           5.0           4.0              4.7              4.7
# 580           5.0           5.0              5.0              5.0
# 693           5.0           4.0              4.7              4.7
#
# [285 rows x 7 columns]

# %%
#ver 1
"""df['finalRating1'] = (((df.ratingNoTweet_q*2) + df.ratingWebsite_q)/3).round(1)
df['finalRating1'].values[df['finalRating1'].values < 1.0] = 1.0

df['finalRating2'] = (((((df.ratingNoTweet_q + df.ratingHashReview_q)/2)*2) + df.ratingWebsite_q)/3).round(1)
df['finalRating2'].values[df['finalRating2'].values < 1.0] = 1.0

df['finalRating3'] = ((df.ratingWebsite_q + (df.ratingTwitter3_q*2))/3).round(1) 
df['finalRating3'].values[df['finalRating3'].values < 1.0] = 1.0

df['finalRating4'] = ((df.ratingWebsite_q + (df.ratingTwitter4_q*2))/3).round(1) 
df['finalRating4'].values[df['finalRating4'].values < 1.0] = 1.0"""

# %%
#ver 2
top = 92.0
w_hReview = 82/top
w_view = 38/top
w_like = 23/top
w_NoTweet = 92/top
w_accReview = 80/top

df['finalRating1'] = ((df.ratingLike_q+df.ratingView_q+df.ratingNoTweet_q)/3).round(1)
df['finalRating1'].values[df['finalRating1'].values < 1.0] = 1.0

df['finalRating1_w'] = (((df.ratingLike_q*w_like)+(df.ratingView_q*w_view)+(df.ratingNoTweet_q*w_NoTweet))/(w_view+w_NoTweet+w_like)).round(1)
df['finalRating1_w'].values[df['finalRating1_w'].values < 1.0] = 1.0

df['finalRating2'] = ((df.ratingLike_q+df.ratingView_q+df.ratingNoTweet_q+df.ratingHashReview_q)/4).round(1) 
df['finalRating2'].values[df['finalRating2'].values < 1.0] = 1.0

df['finalRating2_w'] = (((df.ratingLike_q*w_like)+(df.ratingView_q*w_view)+(df.ratingNoTweet_q*w_NoTweet)+(df.ratingHashReview_q*w_hReview))/(w_view+w_NoTweet+w_like+w_hReview)).round(1) 
df['finalRating2_w'].values[df['finalRating2_w'].values < 1.0] = 1.0

df['finalRating3'] = ((df.ratingLike_q+df.ratingView_q+df.ratingNoTweet_q+df.ratingHashReview_q+df.ratingAccountReview_q)/5).round(1) 
df['finalRating3'].values[df['finalRating3'].values < 1.0] = 1.0

df['finalRating3_w'] = (((df.ratingLike_q*w_like)+(df.ratingView_q*w_view)+(df.ratingNoTweet_q*w_NoTweet)+(df.ratingHashReview_q*w_hReview)+(df.ratingAccountReview_q*w_accReview))/(w_view+w_NoTweet+w_like+w_hReview+w_accReview)).round(1) 
df['finalRating3_w'].values[df['finalRating3_w'].values < 1.0] = 1.0

df[['title','viewer','ratingCount','hashtag','ratingView_q','ratingLike_q','ratingNoTweet_q','finalRating1','finalRating1_w','finalRating2','finalRating2_w','finalRating3','finalRating3_w']].sort_values(by='finalRating3_w', ascending  = False)
# Out:
#                                                  title   viewer  ratingCount  \
# 86   [yaoi] S H A R K #ฉลามสิ้นลาย l สนพ. 2U Publis...  1147614       3212.0
# 121                Real Love #รักแท้ของผมคือคุณ [YAOI]    39288        403.0
# 168                              Your Sky #กี่หมื่นฟ้า   158440        516.0
# 158                  METANOIA #อรุณรุ่ง [Omegaverse Ω]   970488       3924.0
# 683     (omegaverse) midnight fortune #อย่าบอกป๊านะม๊า  5479575      15802.0
# ..                                                 ...      ...          ...
# 598  #สวนสมุนไพรสกุลไป๋ #จะมาผักกาดขาวเหมือนกันไม่ไ...     1340         22.0
# 597  ผมเป็นโอเมก้าคนเดียวในโรงเรียนชายล้วน #โอเมก้า...   132144        203.0
# 596                      ฉากCut #น้องจอมทัพของพี่ทาร์ต    12880         20.0
# 595                           BEGIN AGAIN #รักอีกครั้ง     1176          3.0
# 712                                 #นักฆ่าอยู่ที่บ้าน      257          2.0
#
#                         hashtag  ratingView_q  ratingLike_q  ratingNoTweet_q  \
# 86                  ฉลามสิ้นลาย           5.0           5.0              5.0
# 121           รักแท้ของผมคือคุณ           5.0           5.0              5.0
# 168                 กี่หมื่นฟ้า           5.0           5.0              5.0
# 158                    อรุณรุ่ง           5.0           5.0              5.0
# 683             อย่าบอกป๊านะม๊า           5.0           5.0              5.0
# ..                          ...           ...           ...              ...
# 598           สวนสมุนไพรสกุลไป๋           3.0           4.0              0.0
# 597  โอเมก้าเวิร์สฉีกกฏนิดหน่อย           5.0           5.0              0.0
# 596       น้องจอมทัพของพี่ทาร์ต           4.0           4.0              0.0
# 595                 รักอีกครั้ง           3.0           2.0              0.0
# 712           นักฆ่าอยู่ที่บ้าน           2.0           2.0              0.0
#
#      finalRating1  finalRating1_w  finalRating2  finalRating2_w  finalRating3  \
# 86            5.0             5.0           5.0             5.0           5.0
# 121           5.0             5.0           5.0             5.0           5.0
# 168           5.0             5.0           5.0             5.0           5.0
# 158           5.0             5.0           5.0             5.0           5.0
# 683           5.0             5.0           5.0             5.0           5.0
# ..            ...             ...           ...             ...           ...
# 598           2.3             1.3           1.8             1.0           1.4
# 597           3.3             2.0           2.5             1.3           2.0
# 596           2.7             1.6           2.0             1.0           1.6
# 595           1.7             1.0           1.2             1.0           1.0
# 712           1.3             1.0           1.0             1.0           1.0
#
#      finalRating3_w
# 86              5.0
# 121             5.0
# 168             5.0
# 158             5.0
# 683             5.0
# ..              ...
# 598             1.0
# 597             1.0
# 596             1.0
# 595             1.0
# 712             1.0
#
# [1424 rows x 13 columns]

# %%
print(df['pic'])
# Out:
# 0      https://cdn.readawrite.com/articles/1944/19436...
# 1      https://cdn.readawrite.com/articles/1944/19439...
# 2      https://cdn.readawrite.com/articles/1954/19538...
# 3      https://cdn.readawrite.com/articles/1955/19546...
# 4      https://cdn.readawrite.com/articles/1957/19568...
#                              ...
# 376    https://cdn.readawrite.com/articles/307/306990...
# 377    https://cdn.readawrite.com/articles/385/384216...
# 378    https://cdn.readawrite.com/articles/407/406887...
# 379    https://cdn.readawrite.com/articles/390/389457...
# 380    https://cdn.readawrite.com/articles/397/396003...
# Name: pic, Length: 1424, dtype: object

# %%
df[['title','ratingTwitter3_q','ratingTwitter4_q','finalRating1','finalRating2','finalRating3','finalRating4']][df['hashtag'].str.contains('เขาชื่ออันวาร์')]
df[['title','ratingTwitter3_q','ratingTwitter4_q','finalRating1','finalRating2','finalRating3','finalRating4']][df['finalRating4'] >= 4.0]
# Out:
#                                                   title  ratingTwitter3_q  \
# 30                    #ดอกไม้หน้าร้อนแสนทุกข์เข็ญ 一盒巧克力               4.2
# 54                    Friend with Erotic #เพื่อนร่วมงาน               3.3
# 105          (fictober2020) Honey Trap #ชานนท์รสน้ำผึ้ง               3.8
# 112                                 #สถานะซึนโซน [yaoi]               5.0
# 121                 Real Love #รักแท้ของผมคือคุณ [YAOI]               5.0
# 158                   METANOIA #อรุณรุ่ง [Omegaverse Ω]               5.0
# 168                               Your Sky #กี่หมื่นฟ้า               5.0
# 169   [Omegaverse] Never Ωmega in the army (#โอเมก้า...               4.6
# 175                    (Mpreg) Endless Time #คืนรักธิมา               3.3
# 203               TAKE A DEEP BREATH #หายใจสิเจซ (YAOI)               3.3
# 224       The secret of falling angel | #นางฟ้าหลังม่าน               5.0
# 227       [Pre-Order 1/1/2021-/2/2021] #แด๊ดดี้บิ๊กไซส์               3.3
# 229   เรื่องราวหลัง ‘เทพมารอหังการ’ #ตัวร้ายอย่างข้า...               4.2
# 251                                  #อุบายกินรา [YAOI]               4.2
# 371   พี่น้องเอ๊ย ไอ้ปื๊ดได้ผัวฝรั่ง (BL) #ปื๊ดหิวฝรั่ง               4.2
# 492     (omegaverse) daylight destiny #ไม่รักป๊าหรือม๊า               5.0
# 577                                        #สภาวะลืมรัก               3.3
# 583                              Your voice #รักไม่ร้าย               3.8
# 614   [เปิดให้อ่านถึง 28/01] #บอสข้างบ้าน [สนพ.Hermi...               4.2
# 648                                      #ผาเพียงฟ้า ♡̷               4.6
# 657   [Omega] Come back to count from \'ZERO\' #นับศ...               3.3
# 683      (omegaverse) midnight fortune #อย่าบอกป๊านะม๊า               5.0
# 723                                ค่อยๆ รัก | #เจ๋งพัท               3.3
# 731                      ３０日まで #เริ่มต้นใหม่ในสามสิบวัน               4.2
# 763                          #หมอดินไม่อินเครื่องกล END               3.3
# 835                          Fortune of Love #ศาสตร์รัก               5.0
# 842                                          #เหนือวายุ               3.3
# 861                [END] Laboratory no.9 #ท่านนายพลขนฟู               4.6
# 864                          Safe n Sound #ทะเลคุณยักษ์               3.3
# 918                 1st #คุณคืออันดับหนึ่ง [Omegaverse]               3.8
# 926              เจ้าชายตัวร้ายพ่ายพายุ #เอื้อเฟื้อพายุ               4.2
# 933   I will be your everything #ปลาวาฬของคุณผีเสื้อ...               3.3
# 985     yaoi | เกมเมอร์และน้องเด๋อของเขา #ซอโซ่ล่ามธีร์               4.2
# 1003                                        #หัวหน้าเป๋               4.2
# 1027                                  #ช่วงนี้เดือนหนาว               3.3
# 1041                      UNKNOWN LOVER #เขาชื่ออันวาร์               5.0
# 83      (ฟาไฉ) OUTSIDE #ดอกไม้ป่าที่ริมหน้าต่าง (Mpreg)               3.3
# 86    [yaoi] S H A R K #ฉลามสิ้นลาย l สนพ. 2U Publis...               5.0
# 96                            JULIET IN SUMMER #หลงร้อน               3.8
# 135                              #ก็จะดื้อ (omegaverse)               4.2
# 136   pre-order[omegaverse/Mpreg] Finding Cinnamon B...               3.8
# 180      (daybreak) afternoon is rainy #ชั่วโมงเกือบรัก               4.6
# 240   Claws \'n\' Tender ตัวอย่าง #นิยายวาย #พารานอร...               5.0
# 251   [เปิดให้อ่านถึง 28/07] #คุณนิรันดร์ [สนพ.Hermi...               3.8
# 274   [Mpreg] Nevertheless, I still love you. #เวฬาห...               3.8
# 275   [MarriageMpreg] My Proposal (yaoi) #คุณติอร่อย...               5.0
# 352   END [สนพ.Facai] วันๆของจิ้งจอกลูก2ก็แบบนี้แหละ...               4.2
# 369       Sleep With Me, Free Breakfast #คุณเชนเอาแต่ใจ               3.8
# 370   ที่รัก...ข้ากลับมาแล้ว [Yaoi,Mpreg] #ที่รักข้า...               4.6
#
#       ratingTwitter4_q  finalRating1  finalRating2  finalRating3  finalRating4
# 30                 4.4           5.0           5.0           4.5           4.6
# 54                 3.8           5.0           4.4           4.0           4.2
# 105                3.8           4.6           4.7           4.2           4.2
# 112                5.0           5.0           5.0           5.0           5.0
# 121                5.0           5.0           5.0           5.0           5.0
# 158                5.0           5.0           5.0           5.0           5.0
# 168                5.0           5.0           5.0           5.0           5.0
# 169                4.4           4.6           4.7           4.8           4.6
# 175                3.8           4.7           4.1           3.8           4.0
# 203                3.8           5.0           4.4           4.0           4.2
# 224                5.0           5.0           5.0           5.0           5.0
# 227                3.8           5.0           4.4           4.0           4.2
# 229                4.4           4.3           3.9           4.1           4.3
# 251                4.4           4.7           4.8           4.3           4.4
# 371                4.4           5.0           4.4           4.5           4.6
# 492                5.0           5.0           5.0           5.0           5.0
# 577                3.8           5.0           4.4           4.0           4.2
# 583                3.8           4.6           4.1           4.2           4.2
# 614                4.4           5.0           5.0           4.5           4.6
# 648                4.4           3.9           4.2           4.4           4.3
# 657                3.8           5.0           4.4           4.0           4.2
# 683                5.0           5.0           5.0           5.0           5.0
# 723                3.8           5.0           4.4           4.0           4.2
# 731                4.4           5.0           4.4           4.5           4.6
# 763                3.8           5.0           4.4           4.0           4.2
# 835                5.0           5.0           5.0           5.0           5.0
# 842                3.8           4.7           4.1           3.8           4.0
# 861                4.4           4.6           4.7           4.8           4.6
# 864                3.8           5.0           4.4           4.0           4.2
# 918                3.8           4.6           4.7           4.2           4.2
# 926                4.4           4.3           4.5           4.1           4.3
# 933                3.8           5.0           4.4           4.0           4.2
# 985                4.4           4.7           4.1           4.3           4.4
# 1003               4.4           5.0           4.4           4.5           4.6
# 1027               3.8           5.0           4.4           4.0           4.2
# 1041               5.0           5.0           5.0           5.0           5.0
# 83                 3.8           5.0           4.4           4.0           4.2
# 86                 5.0           5.0           5.0           5.0           5.0
# 96                 3.8           4.6           4.1           4.2           4.2
# 135                4.4           5.0           5.0           4.5           4.6
# 136                3.8           4.6           4.1           4.2           4.2
# 180                4.4           4.6           4.7           4.8           4.6
# 240                5.0           4.3           4.5           4.6           4.7
# 251                3.8           4.6           4.1           4.2           4.2
# 274                3.8           4.6           4.7           4.2           4.2
# 275                5.0           5.0           5.0           5.0           5.0
# 352                4.4           5.0           5.0           4.5           4.6
# 369                3.8           4.6           4.7           4.2           4.2
# 370                4.4           4.6           4.7           4.8           4.6

# %%
df.to_csv(r'C:\Users\paton\Pick2ReadData\Rating\rating_v6.csv')
df.dtypes
df
# Out:
#                    author                    category commentCount  \
# 0                 mplusss  นิยาย Boy Love Secret Room        2,359
# 1            กลิ่นหอมกำจร  นิยาย Boy Love Secret Room           18
# 2               j\'li___.  นิยาย Boy Love Lovely Room            6
# 3                Overrain  นิยาย Boy Love Lovely Room       15,500
# 4           navybroccoli.  นิยาย Boy Love Lovely Room           32
# ..                    ...                         ...          ...
# 376                  24.8  นิยาย Boy Love Secret Room           47
# 377                วายศรี  นิยาย Boy Love Lovely Room           45
# 378    ฟองดูว์เป็นชื่อขนม  นิยาย Boy Love Lovely Room          103
# 379         I\'M WANNABLE  นิยาย Boy Love Lovely Room            4
# 380  ผู้ขี้เกียจเป็นหนึ่ง  นิยาย Boy Love Lovely Room        2,306
#
#                                            description favouriteCount  \
# 0    'เมื่อ 3P มาแบบ 4K พูดได้คำเดียวว่างานนี้ Full...          8,158
# 1    "หลวงพี่จะสึกเมื่อไหร่ครับ" จันทร์หอมเป็นเด็กเ...             78
# 2     Shark#ฉลามอยากกินพืช: นิยาย Boy Love Lovely Room             13
# 3    ความสัมพันธ์เพียงแค่คืนเดียว เปลี่ยนชีวิตของธี...         32,697
# 4               คุณอยากมาดูอควาเรี่ยมตอนเที่ยงคืนมั้ย?             93
# ..                                                 ...            ...
# 376  พ่อกับอาไม่ใช่พี่น้องกันแท้ๆ เพราะฉะนั้นผมกับอ...             74
# 377  คายง หนุ่มชาวบ้านที่สละตนเป็นเหยื่อเซ่นไหว้ภูต...            161
# 378                ขอสักคอมเม้นท์ได้ไหม ในฐานะค่ะก็ได้            445
# 379   แดนิค:ไอหมูโว้ยยยย!!!!! วี:กูชื่อวีว้อยยยยย!!!!!             12
# 380  ตายแล้วไปเกิดใหม่ ไฉนข้าจึงเกิดเป็นสิงโตทะเล แ...          4,103
#
#     isComplete  numOfchap                                                pic  \
# 0           จบ       18.0  https://cdn.readawrite.com/articles/1944/19436...
# 1           จบ        1.0  https://cdn.readawrite.com/articles/1944/19439...
# 2           จบ        2.0  https://cdn.readawrite.com/articles/1954/19538...
# 3           จบ       48.0  https://cdn.readawrite.com/articles/1955/19546...
# 4           จบ        1.0  https://cdn.readawrite.com/articles/1957/19568...
# ..         ...        ...                                                ...
# 376         จบ       10.0  https://cdn.readawrite.com/articles/307/306990...
# 377         จบ        6.0  https://cdn.readawrite.com/articles/385/384216...
# 378         จบ       15.0  https://cdn.readawrite.com/articles/407/406887...
# 379         จบ        0.0  https://cdn.readawrite.com/articles/390/389457...
# 380         จบ       18.0  https://cdn.readawrite.com/articles/397/396003...
#
#      ratingCount                                                tag  ...  \
# 0         1051.0  เข้ามาลึกๆ,insert here,Boy Love/Yaoi,18+,20+,น...  ...
# 1            9.0                  18+,Boy Love/Yaoi,นิยายวาย,บาปหนา  ...
# 2            4.0                                                NaN  ...
# 3         5490.0  Boy Love/Yaoi,Mpreg,นิยายวาย,18+,นิยายวายฟีลกู...  ...
# 4           23.0  Midnight aquarium,อควาเรี่ยมเที่ยงคืน,boyslove...  ...
# ..           ...                                                ...  ...
# 376         16.0                               Boy Love/Yaoi,อาหลาน  ...
# 377         28.0                                Boy Love/Yaoi,Mpreg  ...
# 378         52.0                         Boy Love/Yaoi,ตลก,นิยายรัก  ...
# 379          4.0                                  Boy Love/Yaoi,18+  ...
# 380        975.0  Boy Love/Yaoi,ตลก,แฟนตาซี,น่ารัก,คอมเมดี้,เกิด...  ...
#
#     ratingLike_q  ratingView_q ratingWebsite_q finalRating1 finalRating2  \
# 0            5.0           5.0             5.0          3.8          3.4
# 1            3.0           3.0             3.0          2.0          1.5
# 2            3.0           2.0             2.3          1.7          1.2
# 3            5.0           5.0             5.0          4.2          3.8
# 4            4.0           3.0             3.3          2.3          1.8
# ..           ...           ...             ...          ...          ...
# 376          4.0           4.0             4.0          2.7          2.0
# 377          4.0           4.0             4.0          2.7          2.0
# 378          4.0           4.0             4.0          2.7          2.0
# 379          3.0           3.0             3.0          2.4          2.4
# 380          5.0           5.0             5.0          3.8          3.4
#
#      finalRating3  finalRating4  finalRating1_w  finalRating2_w  \
# 0             3.2           2.9             2.7             2.7
# 1             1.2           1.0             1.2             1.0
# 2             1.0           1.0             1.0             1.0
# 3             3.5           3.3             3.5             3.1
# 4             1.4           1.1             1.3             1.0
# ..            ...           ...             ...             ...
# 376           1.6           1.3             1.6             1.0
# 377           1.6           1.3             1.6             1.0
# 378           1.6           1.3             1.6             1.0
# 379           2.4           2.3             1.9             2.1
# 380           3.2           2.9             2.7             2.7
#
#      finalRating3_w
# 0               2.6
# 1               1.0
# 2               1.0
# 3               3.0
# 4               1.0
# ..              ...
# 376             1.0
# 377             1.0
# 378             1.0
# 379             2.2
# 380             2.6
#
# [1424 rows x 33 columns]
