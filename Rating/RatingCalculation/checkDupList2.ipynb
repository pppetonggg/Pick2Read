# %%
import pandas as pd
import numpy as np
import string

import os.path
from os import path
i = 0
count = 0
folder1 = 'C:/Users/paton/Pick2ReadData/Rating/Rq12_noWeight' 
folder2 = 'C:/Users/paton/Pick2ReadData/Rating/Rq_W' 
file1 = os.listdir(folder1)
file2 = os.listdir(folder2)
print(file1)
# Out:
# ['Ratingrq1_1.csv', 'Ratingrq1_2.csv', 'Ratingrq1_3.csv', 'Ratingrq2_1.csv', 'Ratingrq2_11.csv', 'Ratingrq2_12.csv', 'Ratingrq2_13.csv', 'Ratingrq2_2.csv', 'Ratingrq2_21.csv', 'Ratingrq2_22.csv', 'Ratingrq2_23.csv', 'Ratingrq2_3.csv', 'Ratingrq2_31.csv', 'Ratingrq2_32.csv', 'Ratingrq2_33.csv']

# %%
#df.iloc[[1]] 
listname = []
for i in file1:
    if i.endswith('.csv'):
        namex = os.path.join(folder1,str(i))
        x = i.split(".csv",1)
        x = ''.join(x)
        exec("%s = pd.read_csv('%s')" % (x,namex))
        exec("%s = %s[['title']].head(15)" % (x,x))
        s1 = 'list' + str(x)
        exec("listname.append(s1)")
        exec("%s = %s['title'].tolist()" % (s1,x))

listname2 = []
for i in file2:
    if i.endswith('.csv'):
        namex = os.path.join(folder2,str(i))
        x = i.split(".csv",1)
        x = ''.join(x)
        exec("%s = pd.read_csv('%s')" % (x,namex))
        exec("%s = %s[['title']].head(15)" % (x,x))
        s1 = 'list' + str(x)
        exec("listname2.append(s1)")
        exec("%s = %s['title'].tolist()" % (s1,x))
        
        
        
        
print(len(listname))
print(listname)
l1 = [listRatingrq1_1, listRatingrq1_2, listRatingrq1_3, listRatingrq2_1, listRatingrq2_11, listRatingrq2_12, listRatingrq2_13, listRatingrq2_2, listRatingrq2_21, listRatingrq2_22, listRatingrq2_23, listRatingrq2_3, listRatingrq2_31, listRatingrq2_32, listRatingrq2_33]
print(len(l1))
l2 = [listRatingrq1_1w, listRatingrq1_2w, listRatingrq1_3w, listRatingrq2_1w, listRatingrq2_11w, listRatingrq2_12w, listRatingrq2_13w, listRatingrq2_2w, listRatingrq2_21w, listRatingrq2_22w, listRatingrq2_23w, listRatingrq2_3w, listRatingrq2_31w, listRatingrq2_32w, listRatingrq2_33w]
print(len(l2))
#l
# Out:
# 15
# ['listRatingrq1_1', 'listRatingrq1_2', 'listRatingrq1_3', 'listRatingrq2_1', 'listRatingrq2_11', 'listRatingrq2_12', 'listRatingrq2_13', 'listRatingrq2_2', 'listRatingrq2_21', 'listRatingrq2_22', 'listRatingrq2_23', 'listRatingrq2_3', 'listRatingrq2_31', 'listRatingrq2_32', 'listRatingrq2_33']
# 15
# 15

# %%
l[0]==l[1]
listRatingrq1_1
# Out:
# ['ชายาข้า ใครบังอาจหาญกล้ามาแตะ!!!',
#  'เหนือมังกร เคียงบัลลังก์(สนพ.บ้านวายบุ๊ค)',
#  'เกิดใหม่ทั้งทีมีแค่นี้?',
#  'ตัวนิดของคุณใหญ่ | BL-Omegaverse',
#  'คุณพฤกษ์รวยมาก - BL (สนพ.Onederwhy)',
#  '我的王妃很漂亮！ชายาข้างามยิ่งนัก',
#  'ไม้เรียวสีขาวกับเสื้อกาวน์เปื้อนชอล์ก > Mpreg&lt;',
#  'สามีนอกสมรส [Omegaverse , Mpreg]',
#  '[Pre - order เล่ม 1]ฮ่องเต้เหตุใดท่านจึงงดงามเช่นนี้ [Mpreg,จีนโบราณ]',
#  '(นิยายแปลจีน) Cannon Fodder Cheat System - ระบบโกงชะตาตาย',
#  '(omegaverse) daylight destiny #ไม่รักป๊าหรือม๊า',
#  '[Omegaverse] Never Ωmega in the army (#โอเมก้าตาบอด)',
#  'ผู้ชายที่เจอในแอปหาคู่คนนั้นรักจริงใช่ไหม (สนพ.พันแสง)',
#  '#อุบายกินรา [YAOI] (สนพ. Hermit)',
#  'ฝนหลงฤดู',
#  'เกิดใหม่อีกครั้งก็ยังห้าวไม่เลิก(yaoi,3p)',
#  'คุณสราญหาคู่',
#  '#ผมไหว้ล่ะพี่ปี [Yaoi]']

# %%
listRatingrq2_3
# Out:
# ['Thanks For You รู้แล้วว่ารัก (Franzis X Renny)',
#  'ต้นหนชลธี (set4ตัว100) [สนพ.Deep publishing]',
#  'ค่อยๆ รัก | #เจ๋งพัท',
#  'Your Sky #กี่หมื่นฟ้า',
#  '#ก็จะดื้อ (omegaverse)',
#  'UNKNOWN LOVER #เขาชื่ออันวาร์',
#  'yaoi | เกมเมอร์และน้องเด๋อของเขา #ซอโซ่ล่ามธีร์',
#  'ก็เมียผมเด็ด #สาววาย',
#  '{ yaoi } • One and Only หวนกลิ่นรัก',
#  'รัตติจันทร์พันกร : ( Mpreg )']

# %%
count = 0
for x in range(len(l1)):
    for y in range(len(l2)):
        if l1[x] == l2[y] and listname[x] != listname2[y]: 
            print(listname[x] + " equal to " + listname2[y])
            count = count + 1
print(count)
# Out:
# listRatingrq1_1 equal to listRatingrq1_1w
# listRatingrq1_2 equal to listRatingrq1_2w
# listRatingrq1_3 equal to listRatingrq1_3w
# listRatingrq2_1 equal to listRatingrq2_11w
# listRatingrq2_11 equal to listRatingrq2_12w
# listRatingrq2_11 equal to listRatingrq2_1w
# listRatingrq2_12 equal to listRatingrq2_13w
# listRatingrq2_13 equal to listRatingrq2_12w
# listRatingrq2_13 equal to listRatingrq2_1w
# listRatingrq2_2 equal to listRatingrq2_21w
# listRatingrq2_21 equal to listRatingrq2_22w
# listRatingrq2_22 equal to listRatingrq2_23w
# listRatingrq2_23 equal to listRatingrq2_2w
# listRatingrq2_3 equal to listRatingrq2_31w
# listRatingrq2_31 equal to listRatingrq2_32w
# listRatingrq2_32 equal to listRatingrq2_33w
# 16

# %%
listRating101[4002]
# Out:
# 'Yours (ของคุณ) (มีหนังสือ พร้อมส่ง)'

# %%
listRating102[4002]
# Out:
# 'Yours (ของคุณ) (มีหนังสือ พร้อมส่ง)'

# %%
for x in range(len(listRatingrq2_1)):
    for y in range(len(listRatingrq2_1w)):
        if listRatingrq2_1[x] == listRatingrq2_1w[y]:
            print(y)
            print(listRatingrq2_1[x])
            #print(listRatingrq1_3[x])
#listRating102[4508]
# Out:
# 0
# ค่อยๆ รัก | #เจ๋งพัท
# 1
# UNKNOWN LOVER #เขาชื่ออันวาร์
# 2
# #ของขวัญ
# 3
# รัตติจันทร์พันกร : ( Mpreg )
# 4
# เสือวิศวะอ่ะ เคยได้ยินป่ะ #กลรักรุ่นพี่ #ฉบับกูเอง
# 5
# (omegaverse) daylight destiny #ไม่รักป๊าหรือม๊า
# 6
# หม่อน |oikawa×Iwaizumi|
# 7
# [ END ] FOREVER #คิมคอป
# 8
# ห่างใกล้
# 9
# Thanks For You รู้แล้วว่ารัก (Franzis X Renny)
# 10
# 582 KM กรุงเทพ-เชียงใหม่
# 11
# PROJECT FANFICTION #ฮยอนบิน
# 12
# 🤍` มกปฟก ` | mewgulf
# 13
# #วันดีวิทยา [S E T วิ ท ย า]
# 14
# #อุบายกินรา [YAOI] (สนพ. Hermit)
# 15
# ต้นหนชลธี (set4ตัว100) [สนพ.Deep publishing]
# 16
# [yaoi] #อาการจะรัก
# 17
# The Scum Shou’s Survival Guide (BLแปลจีน)
# 18
# (1) พะเยา #ทัวร์เที่ยวไทย 77 จังหวัด
# 19
# Real Love #รักแท้ของผมคือคุณ [YAOI]

# %%
for x in range(len(listRating101)):
    for y in range(len(listRating102)):
        if listRating101[x] != listRating102[y] and x != y : 
            print(l[y])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-fcf72d255006> in <module>
#       2     for y in range(len(listRating102)):
#       3         if listRating101[x] != listRating102[y] and x != y :
# ----> 4             print(l[y])
#
# IndexError: list index out of range
