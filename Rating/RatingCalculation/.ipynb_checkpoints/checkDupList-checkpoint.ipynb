# %%
import pandas as pd
import numpy as np
import string

import os.path
from os import path
i = 0
count = 0
folder1 = 'C:/Users/paton/Pick2ReadData/Rating/Evaluation2' 
folder2 = 'C:/Users/paton/Pick2ReadData/Rating/Evaluation2' 
file1 = os.listdir(folder1)
file2 = os.listdir(folder2)
# Out:
# ['.ipynb_checkpoints',
#  '011.csv',
#  '012.csv',
#  '021.csv',
#  '101.csv',
#  '102.csv',
#  '111.csv',
#  '112.csv',
#  '121.csv',
#  '122.csv',
#  '201.csv',
#  '202.csv',
#  '211.csv',
#  '212.csv',
#  '221.csv',
#  '222.csv',
#  '301.csv',
#  '302A.csv',
#  '302B.csv',
#  '311.csv',
#  '312A.csv',
#  '312B.csv',
#  '321.csv',
#  '322A.csv',
#  '322B.csv',
#  'checkDupList.ipynb']

# %%
#df.iloc[[1]] 
for i in file1:
    if i.endswith('.csv'):
        namex = os.path.join(folder1,str(i))
        x = i.split(".csv",1)
        x = ''.join(i)
        print(x)
        for j in file2:
            namey = os.path.join(folder2,str(j))
            y = j.split(".csv",1)
            y = ''.join(j)
            print(y)
            if file_z1 == file: 
                exec("%s = pd.read_excel('%s')" % (x,namex))
                exec("%s = pd.read_excel('%s')" % (y,namey))
                exec("%s = %s.iloc[[10]] " % file)
                exec("%s = %s.iloc[[10]] " % file)
                exec("%s = %s.append(%s, ignore_index=True)" % (file, file, file_z1))
                exec("%s.drop_duplicates(subset=['text'])" % file)
                exec("%s.reset_index(drop=True, inplace=True)" % file)
            
print(i)
# Out:
# 011.csv
# .ipynb_checkpoints
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ffd4484686f5> in <module>
#      11             y = ''.join(j)
#      12             print(y)
# ---> 13             if file_z1 == file:
#      14                 exec("%s = pd.read_excel('%s')" % (x,namex))
#      15                 exec("%s = pd.read_excel('%s')" % (y,namey))
#
# NameError: name 'file_z1' is not defined
