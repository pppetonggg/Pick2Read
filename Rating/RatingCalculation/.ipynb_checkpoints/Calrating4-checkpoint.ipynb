# %%
import pandas as pd
import numpy as np
import string

df = pd.read_csv(r'C:\Users\paton\readawrite_fiction2_BL.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
print(df.index)
df
# Out:
# RangeIndex(start=0, stop=50456, step=1)
#                author                    category commentCount  \
# 0      พ่อบ้านผู้นั้น  นิยาย Boy Love Secret Room          303
# 1              ดองกี้  นิยาย Boy Love Secret Room          608
# 2        มายเนมอิสธว.                  แฟนฟิคชั่น            0
# 3           หมุขี้ชิป                  แฟนฟิคชั่น            5
# 4            เธียรศกร  นิยาย Boy Love Lovely Room           16
# ...               ...                         ...          ...
# 50451         โพธิ์ดำ  นิยาย Boy Love Lovely Room            6
# 50452          jaynet  นิยาย Boy Love Lovely Room           44
# 50453    แม่ค่ะหนูหิว  นิยาย Boy Love Lovely Room            7
# 50454        ☻Gussi☽​  นิยาย Boy Love Secret Room          180
# 50455              바이  นิยาย Boy Love Lovely Room            3
#
#                                              description favouriteCount  \
# 0      คำเตือน : เนื้อเรื่อง yaoi 18+ "เซสึนะ...เซสึน...            893
# 1      ผมได้พี่มาง่ายๆแต่ผมไม่ปล่อยพี่ไปง่ายๆหรอกนะ เ...          2,043
# 2      ...ดอกไม้งามส่งกลิ่นหอม กลีบดอกบานสะพรั่ง แม้ก...             11
# 3      การมีอยู่ของใครอีกคน รับรู้ทุกอย่างแต่สื่อไปไม...             13
# 4      หนึ่งชายตามมาเพราะความรัก หนึ่งบุรุษจดจำรักมิไ...             65
# ...                                                  ...            ...
# 50451                                      มีรักมักมีsex             18
# 50452  'ไว้ถึงตอนนั้นผมจะดูแลโนบิตะคุงตลอดไปครับ' #li...            119
# 50453  เหตุเพราะตัวผมที่ลืมตามาอีกทีก็อยู่กลางป่าพร้อ...             19
# 50454  *นิยายเรื่องนี้อาจมีการกระทำที่รุนแรง หยาบคาย ...          1,083
# 50455  อ่อไอ้เจ๋งลูกอาแป๊ะที่ขายน้ำเต้าหู้ซอยสี่หรอรู...              4
#
#       isComplete  numOfchap  \
# 0             จบ       18.0
# 1             จบ       35.0
# 2             จบ        0.0
# 3             จบ        0.0
# 4             จบ       36.0
# ...          ...        ...
# 50451         จบ        2.0
# 50452         จบ        4.0
# 50453         จบ        0.0
# 50454         จบ       10.0
# 50455         จบ        2.0
#
#                                                      pic ratingCount  \
# 0      https://cdn.readawrite.com/articles/451/450234...         147
# 1      https://cdn.readawrite.com/articles/451/450817...         306
# 2      https://cdn.readawrite.com/articles/460/459050...           0
# 3      https://cdn.readawrite.com/articles/460/459671...           5
# 4      https://cdn.readawrite.com/articles/465/464430...           7
# ...                                                  ...         ...
# 50451  https://cdn.readawrite.com/articles/1495/14946...         5.0
# 50452  https://cdn.readawrite.com/articles/1500/14999...        31.0
# 50453  https://cdn.readawrite.com/articles/1500/14999...         5.0
# 50454  https://cdn.readawrite.com/articles/1501/15002...       123.0
# 50455  https://cdn.readawrite.com/articles/1470/14691...         2.0
#
#                                                      tag  \
# 0      นิยายวาย,ชายรักชาย,ป๊ะป๋า,โชตะ,Boy Love/Yaoi,Y...
# 1                    18+,Boy Love/Yaoi,วิศวะ,มหาวิทยาลัย
# 2                BTS,Fanfiction แฟนฟิคชั่น,Boy Love/Yaoi
# 3                    Boy Love/Yaoi,Fanfiction แฟนฟิคชั่น
# 4      นิยายวาย,ย้อนยุค,นิยายแฟนตาซี,Boy Love/Yaoi,นิ...
# ...                                                  ...
# 50451                                                NaN
# 50452  listbyjaynet,เดคิสุงิ x โนบิตะ,โนบิตะ,เดคิโนบิ...
# 50453                                                NaN
# 50454                                 ร่าน,ผิดศีลธรรม,?p
# 50455                                                NaN
#
#                                                    title  \
# 0                                         รอยรัก [yaoi ]
# 1                                    ล่ามรักรุ่นพี่ [จบ]
# 2      Hachikusan No Hana 八 九 三の花 #ดอกไม้ของยากูซ่า [...
# 3                                  คุณในห้วงคำนึง#แดนฮุน
# 4                                                มาตะวัน
# ...                                                  ...
# 50451                                            ยั่วsex
# 50452  ทฤษฎีเปลี่ยนนายให้กลายเป็นคนรัก | เดคิสุงิxโนบิตะ
# 50453                            ใต้หล้านี้ข้าไฮเทค​สุด!
# 50454                                           ร่านราคะ
# 50455           ไอ้เจ๋งลูกอาแป๊ะที่ขายน้ำเต้าหู้ซอยสี่!!
#
#                                        url   viewer  \
# 0      https://www.readawrite.com/a/1zahit   64,455
# 1      https://www.readawrite.com/a/1zai0h  153,341
# 2      https://www.readawrite.com/a/1zaopp      267
# 3      https://www.readawrite.com/a/1zap8g      264
# 4      https://www.readawrite.com/a/1zat4f   10,163
# ...                                    ...      ...
# 50451  https://www.readawrite.com/a/mzyu55    2,089
# 50452  https://www.readawrite.com/a/mzyyex    1,943
# 50453  https://www.readawrite.com/a/mzyyg6      233
# 50454  https://www.readawrite.com/a/mzyyn0  122,471
# 50455  https://www.readawrite.com/a/mzy9a7      167
#
#                              new_title           hashtag
# 0                                  NaN               NaN
# 1                                  NaN               NaN
# 2                                  NaN  ดอกไม้ของยากูซ่า
# 3                       คุณในห้วงคำนึง               NaN
# 4                              มาตะวัน               NaN
# ...                                ...               ...
# 50451                              NaN               NaN
# 50452  ทฤษฎีเปลี่ยนนายให้กลายเป็นคนรัก               NaN
# 50453                              NaN               NaN
# 50454                              NaN               NaN
# 50455                              NaN               NaN
#
# [50456 rows x 15 columns]

# %%
#df[df['hashtag'].str.contains('โอเมก้า') == True]
#df[df['category']!= '']
df[df['category'].str.contains('Lovely|Secret') == False]
# Out:
#                author       category commentCount  \
# 2        มายเนมอิสธว.     แฟนฟิคชั่น            0
# 3           หมุขี้ชิป     แฟนฟิคชั่น            5
# 7      july-daisy-sun     แฟนฟิคชั่น            5
# 9               Stoni  ชุมชนคนขี้ชิป          543
# 10               PP_m     วายสเตชั่น         10.0
# ...               ...            ...          ...
# 39258          My kim     วายสเตชั่น            0
# 39260         monday🌞    ป่าเวทมนตร์           10
# 39262    RedHeadOnion  ชุมชนคนขี้ชิป           88
# 39263     รักนี้พันปี     วายสเตชั่น            0
# 39264        Mewalsax  ชุมชนคนขี้ชิป            4
#
#                                              description favouriteCount  \
# 2      ...ดอกไม้งามส่งกลิ่นหอม กลีบดอกบานสะพรั่ง แม้ก...             11
# 3      การมีอยู่ของใครอีกคน รับรู้ทุกอย่างแต่สื่อไปไม...             13
# 7      แดนดิไลอ้อนเหมือนนาย ตรงที่มันทั้งสดใส บอบบาง ...             24
# 9                                 ทนหน่อยนะ แค่3เดือนเอง            455
# 10     ‘ฉันก็บอกว่าชอบนายทำไมถึงไม่ยอมคบกับฉัน’ ‘แล้ว...             67
# ...                                                  ...            ...
# 39258  เรื่องราวของวัยรุ่นทั้งสอง "ซาเรน" และ "โยชิตะ...              1
# 39260  ถ้าไม่กลัวงูขึ้นสมองมึงก็ไม่ต้องมาอยู่เรเวนคลอ...            110
# 39262  หากถามงานเยอะไหม ฉันตอบเลยว่ามาก ((#DoubleBoss...             35
# 39263           ทำเพื่อความสนุกและต้องขออภัยกับรูปปกด้วย              4
# 39264         บุหรี่ไม่ดีต่อร่างกาย ส่วนพี่ไม่ดีต่อจิตใจ             16
#
#       isComplete  numOfchap  \
# 2             จบ        0.0
# 3             จบ        0.0
# 7             จบ        5.0
# 9             จบ       21.0
# 10            จบ        4.0
# ...          ...        ...
# 39258         จบ        2.0
# 39260         จบ        4.0
# 39262         จบ       15.0
# 39263         จบ        2.0
# 39264         จบ        3.0
#
#                                                      pic ratingCount  \
# 2      https://cdn.readawrite.com/articles/460/459050...           0
# 3      https://cdn.readawrite.com/articles/460/459671...           5
# 7      https://cdn.readawrite.com/articles/438/437939...           5
# 9      https://cdn.readawrite.com/articles/500/499944...         196
# 10     https://cdn.readawrite.com/articles/502/501104...        10.0
# ...                                                  ...         ...
# 39258  https://cdn.readawrite.com/articles/1283/12829...           0
# 39260  https://cdn.readawrite.com/articles/1318/13173...           5
# 39262  https://cdn.readawrite.com/articles/1292/12912...          18
# 39263  https://cdn.readawrite.com/articles/1409/14085...           0
# 39264  https://cdn.readawrite.com/articles/1380/13792...           4
#
#                                                      tag  \
# 2                BTS,Fanfiction แฟนฟิคชั่น,Boy Love/Yaoi
# 3                    Boy Love/Yaoi,Fanfiction แฟนฟิคชั่น
# 7                      EXO,Boy Love/Yaoi,Chanbaek,ชานแบค
# 9      นิยายรัก,นิยายโรแมนติก,Boy Love/Yaoi,Fanfictio...
# 10     Boy Love/Yaoi,Fanfiction แฟนฟิคชั่น,ตลก,ดราม่า...
# ...                                                  ...
# 39258                                                NaN
# 39260  NCT,JOHNJAE,Fanfiction แฟนฟิคชั่น,hogwarts,จอห...
# 39262                อูจินชาน,woochan,DoubleBossอูจินชาน
# 39263                                       รักนี้ของป๋อ
# 39264   jungil,Jungwoo,taeil,slice of life,บุหรี่,จองอิล
#
#                                                    title  \
# 2      Hachikusan No Hana 八 九 三の花 #ดอกไม้ของยากูซ่า [...
# 3                                  คุณในห้วงคำนึง#แดนฮุน
# 7                          to dandelion you, | #ชบชาวไร่
# 9                                 ผมมีแฟนแล้วครับ #stony
# 10                              นายเสือร้ายกับนายจอมตื้อ
# ...                                                  ...
# 39258                                      แอบรักวุ่นวาย
# 39260                              BLUE WISDOM l Johnjae
# 39262                  DOUBLE BOSS 📝 #DoubleBossอูจินชาน
# 39263                                   รักอันแสนวุ่นวาย
# 39264                          สูบบุหรี่อาจทำให้หัวใจวาย
#
#                                        url     viewer  \
# 2      https://www.readawrite.com/a/1zaopp        267
# 3      https://www.readawrite.com/a/1zap8g        264
# 7      https://www.readawrite.com/a/1za7hj        548
# 9      https://www.readawrite.com/a/1zbn44  3,049,261
# 10     https://www.readawrite.com/a/1zbo29      9,406
# ...                                    ...        ...
# 39258  https://www.readawrite.com/a/mztwb2        297
# 39260  https://www.readawrite.com/a/mzupdf     84,865
# 39262  https://www.readawrite.com/a/mzu41h    299,096
# 39263  https://www.readawrite.com/a/mzwtsy        518
# 39264  https://www.readawrite.com/a/mzw5x4      5,989
#
#                        new_title           hashtag
# 2                            NaN  ดอกไม้ของยากูซ่า
# 3                 คุณในห้วงคำนึง               NaN
# 7                            NaN          ชบชาวไร่
# 9                ผมมีแฟนแล้วครับ               NaN
# 10      นายเสือร้ายกับนายจอมตื้อ               NaN
# ...                          ...               ...
# 39258              แอบรักวุ่นวาย               NaN
# 39260                        NaN               NaN
# 39262                        NaN               NaN
# 39263           รักอันแสนวุ่นวาย               NaN
# 39264  สูบบุหรี่อาจทำให้หัวใจวาย               NaN
#
# [17823 rows x 15 columns]

# %%
#hashtag & title
hashtag = df['hashtag'].tolist()
hfile = []
for i in hashtag:
    name = '#'+str(i)+'.xlsx'
    hfile.append(name)
    

title = df3['new_title'].tolist()
tfile = []
thash = df3['hashtag'].tolist()
thfile = []
print(len(title))
print(len(thash))
for i in range(len(title)):
    name = '#'+str(title[i])+'.xlsx'
    name2= '#'+str(thash[i])+'.xlsx'
    tfile.append(name)
    thfile.append(name2) 
#print(tfile)
#print(thfile)
# Out:
# 4247
# 4247

# %%
#hashtag
import os.path
from os import path
i = 0
count = 0
folder = 'C:\Users\paton\Downloads\twitter\no_dup3_hashtag' 
noTweet = []
noAccountReview = []
noHashReview = []
for file in hfile:
    name = os.path.join(folder,file)
    #print(name)
    if path.exists(name): 
        #print(name)
        #print(hashtag[i])
        exec("%s = pd.read_excel('%s')" % (hashtag[i],name))
        exec("%s['user_descriptions_owner'] = %s['user_descriptions_owner'].astype('object')" % (hashtag[i],hashtag[i]))
        exec("%s.drop('Unnamed: 0', axis=1, inplace=True)" % (hashtag[i]))
        exec("noTweet.append(len(%s.index))" % (hashtag[i]))
        exec("noAccountReview.append(len(%s[%s['user_descriptions_owner'].str.contains('แนะนำนิยาย|รีวิวนิยาย') == True]))" % (hashtag[i],hashtag[i]))
        exec("noHashReview.append(len(%s[%s['text'].str.contains('#แนะนำนิยาย|#รีวิวนิยาย') == True]))" % (hashtag[i],hashtag[i]))
        count = count + 1
    else:
        noTweet.append(np.nan)
        noAccountReview.append(np.nan)
        noHashReview.append(np.nan)
    i = i+1
df['countTweet'] = noTweet
df['countAccountReview'] = noAccountReview
df['countHashReview'] = noHashReview
print('hashtag')
print(count)
# Out:
# hashtag
# 231

# %%
#title
folder = 'C:\Users\paton\Downloads\twitter\no_dup3_title' 
noTweet1 = []
noAccountReview1 = []
noHashReview1 = []
count1 = 0
for i in range(len(tfile)):
    name = os.path.join(folder,tfile[i])
    #print(name)
    #print(i)
    if path.exists(name) and thfile[i] not in hfile:  
        #print(name)
        #print(hashtag[i])
        exec("%s = pd.read_excel('%s')" % (title[i],name))
        exec("%s['user_descriptions_owner'] = %s['user_descriptions_owner'].astype('object')" % (title[i],title[i]))
        exec("%s.drop('Unnamed: 0', axis=1, inplace=True)" % (title[i]))
        exec("noTweet1.append(len(%s.index))" % (title[i]))
        exec("noAccountReview1.append(len(%s[%s['user_descriptions_owner'].str.contains('แนะนำนิยาย|รีวิวนิยาย') == True]))" % (title[i],title[i]))
        exec("noHashReview1.append(len(%s[%s['text'].str.contains('#แนะนำนิยาย|#รีวิวนิยาย') == True]))" % (title[i],title[i]))
        count1 = count1 + 1
    else:
        noTweet1.append(np.nan)
        noAccountReview1.append(np.nan)
        noHashReview1.append(np.nan)
df3['countTweet'] = noTweet1
df3['countAccountReview'] = noAccountReview1
df3['countHashReview'] = noHashReview1      
print(count1)
# Out:
# 374

# %%
df = pd.concat([df, df3])
df
# Out:
#                author                    category commentCount  \
# 0             mplusss  นิยาย Boy Love Secret Room        2,359
# 1        กลิ่นหอมกำจร  นิยาย Boy Love Secret Room           18
# 2           j\'li___.  นิยาย Boy Love Lovely Room            6
# 3            Overrain  นิยาย Boy Love Lovely Room       15,500
# 4       navybroccoli.  นิยาย Boy Love Lovely Room           32
# ...               ...                         ...          ...
# 4242        ควันหมอก.  นิยาย Boy Love Lovely Room            0
# 4243    I\'M WANNABLE  นิยาย Boy Love Lovely Room            4
# 4244  สลอธบนดาวอังคาร  นิยาย Boy Love Secret Room          273
# 4245     Rainpanpunch  นิยาย Boy Love Lovely Room          113
# 4246        Kawwansuk  นิยาย Boy Love Lovely Room          861
#
#                                             description favouriteCount  \
# 0     'เมื่อ 3P มาแบบ 4K พูดได้คำเดียวว่างานนี้ Full...          8,158
# 1     "หลวงพี่จะสึกเมื่อไหร่ครับ" จันทร์หอมเป็นเด็กเ...             78
# 2      Shark#ฉลามอยากกินพืช: นิยาย Boy Love Lovely Room             13
# 3     ความสัมพันธ์เพียงแค่คืนเดียว เปลี่ยนชีวิตของธี...         32,697
# 4                คุณอยากมาดูอควาเรี่ยมตอนเที่ยงคืนมั้ย?             93
# ...                                                 ...            ...
# 4242  **ขออนุญาติเจ้าของภาพ** นิยายเรื่องนี้เป็นเรื่...              0
# 4243   แดนิค:ไอหมูโว้ยยยย!!!!! วี:กูชื่อวีว้อยยยยย!!!!!             12
# 4244  จากลูกบุญธรรมผู้น่ารัก...กลับกลายเป็นสามีของผม...            551
# 4245  Don't speak ความลับที่ผมปิดไว้: นิยาย Boy Love...            207
# 4246  หลังจากแม่เสียชีวิตจากรถชน ชีวิตของภูตะวัน ก็ไ...            732
#
#      isComplete  numOfchap                                                pic  \
# 0            จบ       18.0  https://cdn.readawrite.com/articles/1944/19436...
# 1            จบ        1.0  https://cdn.readawrite.com/articles/1944/19439...
# 2            จบ        2.0  https://cdn.readawrite.com/articles/1954/19538...
# 3            จบ       48.0  https://cdn.readawrite.com/articles/1955/19546...
# 4            จบ        1.0  https://cdn.readawrite.com/articles/1957/19568...
# ...         ...        ...                                                ...
# 4242         จบ        0.0  https://cdn.readawrite.com/articles/388/387286...
# 4243         จบ        0.0  https://cdn.readawrite.com/articles/390/389457...
# 4244         จบ       27.0  https://cdn.readawrite.com/articles/389/388468...
# 4245         จบ       51.0  https://cdn.readawrite.com/articles/391/390900...
# 4246         จบ      150.0  https://cdn.readawrite.com/articles/392/391124...
#
#      ratingCount                                                tag  \
# 0          1,051  เข้ามาลึกๆ,insert here,Boy Love/Yaoi,18+,20+,น...
# 1              9                  18+,Boy Love/Yaoi,นิยายวาย,บาปหนา
# 2              4                                                NaN
# 3          5,490  Boy Love/Yaoi,Mpreg,นิยายวาย,18+,นิยายวายฟีลกู...
# 4             23  Midnight aquarium,อควาเรี่ยมเที่ยงคืน,boyslove...
# ...          ...                                                ...
# 4242         0.0                                                NaN
# 4243         4.0                                  Boy Love/Yaoi,18+
# 4244       119.0                                                NaN
# 4245        28.0  Boy Love/Yaoi,18+,SM,ดราม่า,นิยายรัก,นิยายโรแม...
# 4246       179.0                                                NaN
#
#                                                   title     viewer  \
# 0                    #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)    721,051
# 1                                            #คุณสงฆ์ขา        807
# 2                                  Shark#ฉลามอยากกินพืช        265
# 3     (Omegeverse) แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น...  3,098,602
# 4                Midnight aquarium #อควาเรี่ยมเที่ยงคืน      1,326
# ...                                                 ...        ...
# 4242                                        ร้ายแล้วรัก         62
# 4243                              มีเมียเป็นหมู #แดนฮวี        449
# 4244                                        คุณพ่อของผม     57,206
# 4245                    Don\'t speak ความลับที่ผมปิดไว้     26,268
# 4246                 โอกาสที่ได้ขอใช้ให้ดีที่สุด (YAOI)    171,323
#
#                               new_title              hashtag  \
# 0                                   NaN           เข้ามาลึกๆ
# 1                                   NaN            คุณสงฆ์ขา
# 2                                   NaN       ฉลามอยากกินพืช
# 3     แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น      แด๊ดดี้คลั่งรัก
# 4                                   NaN  อควาเรี่ยมเที่ยงคืน
# ...                                 ...                  ...
# 4242                        ร้ายแล้วรัก                  NaN
# 4243                      มีเมียเป็นหมู               แดนฮวี
# 4244                        คุณพ่อของผม                  NaN
# 4245                 ความลับที่ผมปิดไว้                  NaN
# 4246        โอกาสที่ได้ขอใช้ให้ดีที่สุด                  NaN
#
#                                       url  countTweet  countAccountReview  \
# 0                                     NaN         1.0                 0.0
# 1                                     NaN         NaN                 NaN
# 2                                     NaN         NaN                 NaN
# 3                                     NaN         3.0                 0.0
# 4                                     NaN         NaN                 NaN
# ...                                   ...         ...                 ...
# 4242  https://www.readawrite.com/a/lz915b         NaN                 NaN
# 4243  https://www.readawrite.com/a/lz92wc         NaN                 NaN
# 4244  https://www.readawrite.com/a/lz9243         NaN                 NaN
# 4245  https://www.readawrite.com/a/lz943k         NaN                 NaN
# 4246  https://www.readawrite.com/a/lz949y         NaN                 NaN
#
#       countHashReview
# 0                 1.0
# 1                 NaN
# 2                 NaN
# 3                 0.0
# 4                 NaN
# ...               ...
# 4242              NaN
# 4243              NaN
# 4244              NaN
# 4245              NaN
# 4246              NaN
#
# [5671 rows x 18 columns]

# %%
#จำนวนTweet
print("จำนวนทวิต")
nTweet = len(เขาชื่ออันวาร์.index)
print(nTweet)

#แอคแนะนำนิยาย
print("จำนวนแอคแนะนำนิยาย")
nAccountReview = len(เขาชื่ออันวาร์[เขาชื่ออันวาร์['user_descriptions_owner'].str.contains('แนะนำนิยาย|รีวิวนิยาย') == True])
print(nAccountReview)
เขาชื่ออันวาร์[เขาชื่ออันวาร์['user_descriptions_owner'].str.contains('แนะนำนิยาย|รีวิวนิยาย') == True]

#จำนวน#แนะนำนิยาย
print("จำนวน#แนะนำนิยาย")
nHashReview = len(เขาชื่ออันวาร์[เขาชื่ออันวาร์['text'].str.contains('#แนะนำนิยาย|#รีวิวนิยาย') == True])
print(nHashReview)
เขาชื่ออันวาร์[เขาชื่ออันวาร์['text'].str.contains('#แนะนำนิยาย|#รีวิวนิยาย') == True]

เขาชื่ออันวาร์
#inTweet[inTweet['ratingNoTweet_q'] > 3.0]
#inTweet
# Out:
# จำนวนทวิต
# 378
# จำนวนแอคแนะนำนิยาย
# 3
# จำนวน#แนะนำนิยาย
# 2
#               create_at      item_serach  user_account  \
# 0   2021-02-01 11:53:53  #เขาชื่ออันวาร์   Bambam__mie
# 1   2021-02-01 11:53:34  #เขาชื่ออันวาร์    bolovezhan
# 2   2021-02-01 11:52:11  #เขาชื่ออันวาร์     sinpba_oh
# 3   2021-02-01 11:45:01  #เขาชื่ออันวาร์     Temps_xxx
# 4   2021-02-01 11:00:00  #เขาชื่ออันวาร์       p_62442
# ..                  ...              ...           ...
# 373 2021-01-24 20:53:08  #เขาชื่ออันวาร์        czn505
# 374 2021-01-24 20:32:58  #เขาชื่ออันวาร์  Superautumnn
# 375 2021-01-24 20:18:17  #เขาชื่ออันวาร์        czn505
# 376 2021-01-24 20:18:09  #เขาชื่ออันวาร์        czn505
# 377 2021-01-24 20:18:07  #เขาชื่ออันวาร์        czn505
#
#                                       user_description  User_follower  \
# 0                                       💜 I purple U 💜            382
# 1    กูเคยคลั่งรักป๋อแต่ตอนนี้มากกว่าคลั่งรักแล้ว\n...             10
# 2       #succulember #plantober #veddie #stony #thorki             11
# 3    'เป็นหมีที่ชอบนอนและกิน'| working | 𝙱𝚎𝚊𝚛 𝚒𝚗 𝚝𝚑...            271
# 4                                               ~1999~              4
# ..                                                 ...            ...
# 373  🍸Do you know what it feels like to fall in lov...           3176
# 374                       ขอให้เติบโตไปอย่างมีความสุข.            309
# 375  🍸Do you know what it feels like to fall in lov...           3176
# 376  🍸Do you know what it feels like to fall in lov...           3176
# 377  🍸Do you know what it feels like to fall in lov...           3176
#
#                                                   text           hashtag  \
# 0    #เขาชื่ออันวาร์ สปอยล์ตอนล่าสุดคือรู้เลยว่ามีค...   /เขาชื่ออันวาร์
# 1    #เขาชื่ออันวาร์\n\nขอแนะนำให้อ่านจากใจจจ ตอนล่...   /เขาชื่ออันวาร์
# 2    #เขาชื่ออันวาร์ นึกตอนช่วยน้องแต่งตัว อยากเห็น...   /เขาชื่ออันวาร์
# 3    เป็นนิยายที่อ่านแล้วร้อนท้องทุกครั้งเวลามีเอนซ...   /เขาชื่ออันวาร์
# 4    เนี่ยยยย มาหวะ!!!! \n#เขาชื่ออันวาร์ https://t...   /เขาชื่ออันวาร์
# ..                                                 ...               ...
# 373  #เขาชื่ออันวาร์ ยกให้เป็นเดอะเบสเลยอ่า ดือมาก ...   /เขาชื่ออันวาร์
# 374  ลืมแปะเพลย์ลิสต์ประกอบพาร์ท 3 ใครอ่านอยู่เปิดค...   /เขาชื่ออันวาร์
# 375            #เขาชื่ออันวาร์ https://t.co/cEGMZLlL3E   /เขาชื่ออันวาร์
# 376  ไปข้างนอกรีบกลับเข้ามาอ่านข้าวปลาไม่กินมันเป็น...   /เขาชื่ออันวาร์
# 377  กำลังตัดใจนะคะคุณอันวาร์🥺 #เขาชื่ออันวาร์ http...   /เขาชื่ออันวาร์
#
#      retweet_count  favourite_count       at_tweet  \
# 0              114               80         czn505
# 1               58               97        PTHx4x4
# 2                0                0      sinpba_oh
# 3                0                0      Temps_xxx
# 4                1                2  kaormloveyibo
# ..             ...              ...            ...
# 373              1                1  taeissopretty
# 374             48               39         czn505
# 375              2                0    lonelyhold8
# 376              1                0       onlymmeq
# 377              1                0      jsbn_film
#
#                                user_descriptions_owner
# 0    🍸Do you know what it feels like to fall in lov...
# 1    ≫ #ปรมาจารย์ลัทธิมาร | #BIGBANG 👑 | #Yuzhou |T...
# 2       #succulember #plantober #veddie #stony #thorki
# 3    'เป็นหมีที่ชอบนอนและกิน'| working | 𝙱𝚎𝚊𝚛 𝚒𝚗 𝚝𝚑...
# 4    สเป็ค : บิวกิ้น พุฒิพงศ์ อัสสรัตนกุล ❤️💙 𝘀𝗶𝗻𝗰𝗲...
# ..                                                 ...
# 373                    ชาติ ศาสนา พระมหาบังทันโซยอนดัน
# 374  🍸Do you know what it feels like to fall in lov...
# 375  full-time mommeaw, part-time anime addictor ; ...
# 376                                                NaN
# 377                                         EXO-L 🧡KH🧡
#
# [378 rows x 11 columns]

# %%
#Calculate rating for twitter
inTweet = df[df['countTweet'].notnull()]
inTweet.reset_index(drop=True, inplace=True)

import jenkspy


inTweet['ratingNoTweet_q'] = pd.qcut(inTweet['countTweet'], 5, labels=False, duplicates = 'drop')
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].astype('float64')

inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].replace(0.0,1.25)
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].replace(1.0,2.5)
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].replace(2.0,3.75)
inTweet['ratingNoTweet_q'] = inTweet['ratingNoTweet_q'].replace(3.0,5)

#Model 3 and 4

inTweet['ratingHashReview_q'] = pd.qcut(inTweet['countHashReview'], 5, labels=False, duplicates = 'drop')
inTweet['ratingHashReview_q'] = inTweet['ratingHashReview_q'].astype('float64')

inTweet['ratingHashReview_q'] = inTweet['ratingHashReview_q'].replace(0.0,2.5)
inTweet['ratingHashReview_q'] = inTweet['ratingHashReview_q'].replace(1.0,5)


inTweet['ratingAccountReview_q'] = pd.qcut(inTweet['countAccountReview'], 5, labels=False, duplicates = 'drop')

inTweet['ratingAccountReview_q'] = inTweet['ratingAccountReview_q'].replace(0,2.5)
inTweet['ratingAccountReview_q'] = inTweet['ratingAccountReview_q'].replace(1,5.0)


inTweet['ratingTwitter3_q'] = ((inTweet.ratingAccountReview_q+inTweet.ratingHashReview_q+inTweet.ratingNoTweet_q)/3).round(1)
inTweet['ratingTwitter4_q'] = ((inTweet.ratingAccountReview_q+inTweet.ratingHashReview_q+(inTweet.ratingNoTweet_q*2))/4).round(1)
inTweet = inTweet[['title', 'ratingNoTweet_q', 'ratingHashReview_q','ratingAccountReview_q','ratingTwitter3_q','ratingTwitter4_q']]
#inTweet[['countHashReview']][inTweet['countHashReview']>1.0].sort_values(by = 'countHashReview', ascending = False)
inTweet
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                  title  ratingNoTweet_q  \
# 0                   #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)             1.25
# 1    (Omegeverse) แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น...             2.50
# 2                           #You are mine คุณเป็นของผม             1.25
# 3                                 Two Sides #เราของเธอ             5.00
# 4                        Take a risk #หลงใจรัก > Mpreg             1.25
# ..                                                 ...              ...
# 600                           ✿ ฮักนาย (พี่ขี้แกล้ง) ✿             1.25
# 601  Our Love ผมท้องกับเพื่อน (Mpreg) [Yaoi / Boy\'...             1.25
# 602                                         GB ปรุงรัก             2.50
# 603                                    ประสบการณ์เสียว             5.00
# 604                              รักหมดใจให้นายคนเดียว             1.25
#
#      ratingHashReview_q  ratingAccountReview_q  ratingTwitter3_q  \
# 0                   2.5                    2.5               2.1
# 1                   2.5                    2.5               2.5
# 2                   2.5                    2.5               2.1
# 3                   2.5                    2.5               3.3
# 4                   2.5                    2.5               2.1
# ..                  ...                    ...               ...
# 600                 2.5                    2.5               2.1
# 601                 2.5                    2.5               2.1
# 602                 2.5                    2.5               2.5
# 603                 2.5                    2.5               3.3
# 604                 2.5                    2.5               2.1
#
#      ratingTwitter4_q
# 0                 1.9
# 1                 2.5
# 2                 1.9
# 3                 3.8
# 4                 1.9
# ..                ...
# 600               1.9
# 601               1.9
# 602               2.5
# 603               3.8
# 604               1.9
#
# [605 rows x 6 columns]

# %%
"""print('j')
print(inTweet['ratingAccountReview_j'].unique())
print(inTweet['ratingHashReview_j'].unique())
print(inTweet['ratingNoTweet_j'].unique())"""
print('q')
print(inTweet['ratingNoTweet_q'].unique())
print(inTweet['ratingHashReview_q'].unique())
print(inTweet['ratingAccountReview_q'].unique())
#len(inTweet)
#inTweet['ratingTwitter3'].sort()
inTweet.sort_values(by='ratingTwitter3_q', ascending=False)
#inTweet.sort_values(by='ratingTwitter4', ascending=False)
# Out:
# q
# [1.25 2.5  5.   3.75]
# [2.5 5. ]
# [2.5 5. ]
#                                                  title  ratingNoTweet_q  \
# 136               [END] Laboratory no.9 #ท่านนายพลขนฟู             5.00
# 76     (omegaverse) daylight destiny #ไม่รักป๊าหรือม๊า             5.00
# 34       The secret of falling angel | #นางฟ้าหลังม่าน             5.00
# 211  Claws \'n\' Tender ตัวอย่าง #นิยายวาย #พารานอร...             5.00
# 132                         Fortune of Love #ศาสตร์รัก             5.00
# ..                                                 ...              ...
# 278       NO MORE SLAVE จะ(ไม่)ขอเป็นทาสทุกชาติไป Yaoi             1.25
# 275                               น้องเนิร์ดข้างห้อง:)             1.25
# 271                        Water Blue -น้ำเงิน x แม็ค-             1.25
# 270                                [OS] อธิษฐาน #ทูพัค             1.25
# 604                              รักหมดใจให้นายคนเดียว             1.25
#
#      ratingHashReview_q  ratingAccountReview_q  ratingTwitter3_q  \
# 136                 5.0                    5.0               5.0
# 76                  5.0                    5.0               5.0
# 34                  5.0                    5.0               5.0
# 211                 5.0                    5.0               5.0
# 132                 5.0                    5.0               5.0
# ..                  ...                    ...               ...
# 278                 2.5                    2.5               2.1
# 275                 2.5                    2.5               2.1
# 271                 2.5                    2.5               2.1
# 270                 2.5                    2.5               2.1
# 604                 2.5                    2.5               2.1
#
#      ratingTwitter4_q
# 136               5.0
# 76                5.0
# 34                5.0
# 211               5.0
# 132               5.0
# ..                ...
# 278               1.9
# 275               1.9
# 271               1.9
# 270               1.9
# 604               1.9
#
# [605 rows x 6 columns]

# %%
df = df.join(inTweet.set_index('title'), on='title', how='left')
inTweet.dtypes
# Out:
# title                     object
# ratingNoTweet_q          float64
# ratingHashReview_q       float64
# ratingAccountReview_q    float64
# ratingTwitter3_q         float64
# ratingTwitter4_q         float64
# dtype: object

# %%
df['ratingTwitter3_q'] = df['ratingTwitter3_q'].fillna(0)
df['ratingTwitter4_q'] = df['ratingTwitter4_q'].fillna(0)
df['ratingNoTweet_q'] = df['ratingNoTweet_q'].fillna(0)
df['ratingHashReview_q'] = df['ratingHashReview_q'].fillna(0)
df['ratingAccountReview_q'] = df['ratingAccountReview_q'].fillna(0)
print(inTweet['ratingTwitter3_q'].unique())
print(inTweet['ratingTwitter4_q'].unique())
df[['title','countTweet','ratingNoTweet_q','ratingHashReview_q','ratingAccountReview_q','ratingTwitter3_q','ratingTwitter4_q']].sort_values(by = 'ratingTwitter4_q', ascending = False)
print("Because account review is not zero only 3")
# Out:
# [2.1 2.5 3.3 4.2 3.8 5.  2.9 4.6]
# [1.9 2.5 3.8 4.4 5.  3.1]
# Because account review is not zero only 3

# %%
#rating of website
df['ratingCount'] = df['ratingCount'].str.replace(',', '')
df['viewer'] = df['viewer'].str.replace(',', '')
df[['ratingCount', 'viewer']] = df[['ratingCount', 'viewer']].apply(pd.to_numeric)

df['ratingLike_q'] = pd.qcut(df['ratingCount'], 5, labels=[1,2,3,4,5])


df['ratingView_q'] = pd.qcut(df['viewer'], 5, labels=[1,2,3,4,5])

df[['ratingView_q','ratingLike_q']] = df[['ratingView_q','ratingLike_q']].astype('float64')

df['ratingWebsite_q'] = (((df.ratingView_q*2)+(df.ratingLike_q))/3).round(1)

df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']]
# Out:
#                                                   title   viewer  ratingCount  \
# 0                    #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)   721051       1051.0
# 1                                            #คุณสงฆ์ขา      807          9.0
# 2                                  Shark#ฉลามอยากกินพืช      265          4.0
# 3     (Omegeverse) แด๊ดดี้คือสิ่งมีชีวิตที่ไม่จำเป็น...  3098602       5490.0
# 4                Midnight aquarium #อควาเรี่ยมเที่ยงคืน     1326         23.0
# ...                                                 ...      ...          ...
# 4242                                        ร้ายแล้วรัก       62          0.0
# 4243                              มีเมียเป็นหมู #แดนฮวี      449          4.0
# 4244                                        คุณพ่อของผม    57206        119.0
# 4245                    Don\'t speak ความลับที่ผมปิดไว้    26268         28.0
# 4246                 โอกาสที่ได้ขอใช้ให้ดีที่สุด (YAOI)   171323        179.0
#
#       ratingView_q  ratingLike_q  ratingWebsite_q
# 0              5.0           5.0              5.0
# 1              2.0           3.0              2.3
# 2              2.0           2.0              2.0
# 3              5.0           5.0              5.0
# 4              3.0           4.0              3.3
# ...            ...           ...              ...
# 4242           1.0           1.0              1.0
# 4243           2.0           2.0              2.0
# 4244           5.0           5.0              5.0
# 4245           4.0           4.0              4.0
# 4246           5.0           5.0              5.0
#
# [5671 rows x 6 columns]

# %%
df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']][df['viewer'] == 3.0].sort_values(by='viewer', ascending = False).head(60) 
df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']][(df['viewer'] > 800) & (df['viewer'] < 1000)].sort_values(by='ratingCount',ascending = False)
df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']].sort_values(by='ratingWebsite_q', ascending = False).head(50)
# Out:
#                                                   title   viewer  ratingCount  \
# 0                    #เข้ามาลึกๆ Side-XL(3P,BDSMบางตอน)   721051       1051.0
# 854                  ผมกำลังจะมีความสุข...ในสักวันหนึ่ง    58957        113.0
# 888                                     เล่ห์สมิง (BL )    82443        464.0
# 885   [Yaoi] บทลงโทษของคนที่ดองนิยาย คือกลับชาติมาเก...    45392        191.0
# 884                   Only you \"เพียงนาย\" (จอร์นxเชน)  2122705       3317.0
# 883                Exchange : กฎการแลกเปลี่ยนของความรัก   618003       1705.0
# 876               หมูพีที่รัก / My Honey (หนังสือทำมือ)    55302        116.0
# 874                                  หักเหลี่ยมรักซาตาน   195138        781.0
# 872       ระบบจะชี้นำเจ้าไปสู่การเป็นมารราคะผู้ยิ่งใหญ่    71393        210.0
# 870                            เจ้านายครับ รับรักผมเถอะ    71291        101.0
# 869              หากโลกนี้เป็นเกม ขอสร้างฮาเร็มเลยละกัน    89685        280.0
# 858                                มาเฟียอยากเลี้ยงเด็ก   249273        508.0
# 856                              ตัวๆอยากมีเมียมั้ยคับ?    34460        114.0
# 849                   อลวนรักย้อนเวลา ภรรยาผมเป็นผู้ชาย   425719        904.0
# 910             We\'re the same นายกับฉันเหมือนกันเลยนะ    91028        107.0
# 841          เป็นชู้กับหมี (Omegaverse) สนพ.inktreebook   401158        903.0
# 836                    Double dating ผมหรือเขา? (Mpreg)    40381        106.0
# 835                         สามีใหม่ของผมไม่ใช่มนุษย์[]   137987        254.0
# 832                                       ราคา ≠ มูลค่า   389847       1075.0
# 826   ADS คอลเซ็นเตอร์สวัสดีครับ :: This voice sound...    36975        113.0
# 809                     ชีวิตสุดระทึกของซีมัส [YAOI/BL]   114040        327.0
# 806   [END] Naked London เปลือย.ใจ.รัก [Sense Book P...   220378        456.0
# 796                  [Harem] เนื้อคู่ข้านะรึ? มีเป็นสิบ    39595        199.0
# 795                                นาทีที่ข้ามฟ้า (end)   168524        623.0
# 787                                   แฮกเกอร์ที่รัก ()    71373        147.0
# 786                           เสียงเรียกของ (สัตว์) ป่า   102094        217.0
# 899                                   แผลในใจ(4P/Mpreg)    68425        122.0
# 919   SKY  SEA ท้องฟ้ากับทะเล [สนพ. 2U Publishing] [...    79387        140.0
# 1101  An Unlucky Supporting Role : ระบบตัวประกอบผู้โ...    33154         94.0
# 986                        ชายาผู้ถูกลืม หมิงซิน (yaoi)   632226       1756.0
# 1079                        Daddy บุตรบุญธรรม (ท้องได้)   112030        221.0
# 1046                                    ตัวเล็กสเป็คป๋า   217751        343.0
# 1033            Sex Nerd เรื่องลับของเด็กเนิร์ด (คลัง )   146848        161.0
# 1030                     สุดทางเพื่อน(Mpreg/Yaoi) -end-   105178        211.0
# 1029   () Carnivore ลอกคราบ (Alien,Vector,Tentacles) **   113002        342.0
# 1022           ตรุษจีนปีนี้ ได้สามีถึงสาม [4P] [ 4 ตอน]   127088        316.0
# 1021           คุณตัวร้ายสนใจกินผมไหมครับ? (Omegaverse)   197095        428.0
# 1010           (E-Book) Seven days 7 วันที่ฉันได้รักนาย    84968        246.0
# 1009                            บอสอินคิวบัสขอ(ร่าน)รัก    77838        146.0
# 996                       โปรดอย่ากีดกันผมกับชานมไข่มุก    83062        330.0
# 995                         อาจารย์ครับ...อย่ายั่ว (6p)   106249        226.0
# 983                                     ซัดกันมัน(ส์)ดี  1752544       2751.0
# 924     (ฟาไฉ) OUTSIDE #ดอกไม้ป่าที่ริมหน้าต่าง (Mpreg)    91425        314.0
# 975                                   อย่าทำน้อง [Yaoi]    40747        115.0
# 966              อย่าให้ผมร้าย เดี๋ยวคุณจะรัก | yaoi 3p   182366        357.0
# 964   เอาละสิ อยู่ดีๆผมก็กลายเป็นตัวร้าย [ Yaoi Boy\...   665997       1738.0
# 951                                             หวงเมีย    53783        148.0
# 943                            สามีผมคือ \'นาย\' ตานี??    48068        261.0
# 942             จีบคนเถื่อน 2 ภาคเป็นแฟนคนเถื่อน [YAOI]    44899        203.0
# 941   [] The Perfect Destiny โชคชะตาที่แสนจะเพอร์เฟ็...   330591        805.0
#
#       ratingView_q  ratingLike_q  ratingWebsite_q
# 0              5.0           5.0              5.0
# 854            5.0           5.0              5.0
# 888            5.0           5.0              5.0
# 885            5.0           5.0              5.0
# 884            5.0           5.0              5.0
# 883            5.0           5.0              5.0
# 876            5.0           5.0              5.0
# 874            5.0           5.0              5.0
# 872            5.0           5.0              5.0
# 870            5.0           5.0              5.0
# 869            5.0           5.0              5.0
# 858            5.0           5.0              5.0
# 856            5.0           5.0              5.0
# 849            5.0           5.0              5.0
# 910            5.0           5.0              5.0
# 841            5.0           5.0              5.0
# 836            5.0           5.0              5.0
# 835            5.0           5.0              5.0
# 832            5.0           5.0              5.0
# 826            5.0           5.0              5.0
# 809            5.0           5.0              5.0
# 806            5.0           5.0              5.0
# 796            5.0           5.0              5.0
# 795            5.0           5.0              5.0
# 787            5.0           5.0              5.0
# 786            5.0           5.0              5.0
# 899            5.0           5.0              5.0
# 919            5.0           5.0              5.0
# 1101           5.0           5.0              5.0
# 986            5.0           5.0              5.0
# 1079           5.0           5.0              5.0
# 1046           5.0           5.0              5.0
# 1033           5.0           5.0              5.0
# 1030           5.0           5.0              5.0
# 1029           5.0           5.0              5.0
# 1022           5.0           5.0              5.0
# 1021           5.0           5.0              5.0
# 1010           5.0           5.0              5.0
# 1009           5.0           5.0              5.0
# 996            5.0           5.0              5.0
# 995            5.0           5.0              5.0
# 983            5.0           5.0              5.0
# 924            5.0           5.0              5.0
# 975            5.0           5.0              5.0
# 966            5.0           5.0              5.0
# 964            5.0           5.0              5.0
# 951            5.0           5.0              5.0
# 943            5.0           5.0              5.0
# 942            5.0           5.0              5.0
# 941            5.0           5.0              5.0

# %%
df[['title','viewer','ratingCount','ratingView_q','ratingLike_q','ratingWebsite_q']].sort_values(by='ratingCount', ascending  = True).head(50)
df[['viewer','ratingCount','title','ratingView_q','ratingLike_q','ratingWebsite_q','ratingWebsite_q']][df['ratingView_q'] > 4.0].sort_values(by='viewer', ascending = False)
# Out:
#        viewer  ratingCount                                           title  \
# 3119  7550855      15410.0              องค์ชายสามช่างไม่เอาไหน (สนพ.ฟาไฉ)
# 2003  6007803      11082.0                   ชายาข้า ใครบังอาจหาญกล้ามาแตะ
# 683   5479575      15802.0  (omegaverse) midnight fortune #อย่าบอกป๊านะม๊า
# 472   5065783      10884.0        สามี ข้าจะปกป้องท่านเอง(สนพ.บ้านวายบุ๊ค)
# 3139  4937046      13552.0                       มหาลัยครึ่งมนุษย์ (ebook)
# ...       ...          ...                                             ...
# 2737    31459         73.0                                 ภพรักท่านแม่ทัพ
# 2283    31444        110.0                       เมื่อผมติดเกาะกับอดีตสามี
# 2662    31406        104.0                   ศิลปะการอยู่ร่วมกับหมี [Yaoi]
# 1615    31385         60.0                   ADMISSION ผมเจอคุณหน้าห้องสอบ
# 1165    31344        117.0          [End]I\'m King ก้มหัวลงซะฉันคือพระราชา
#
#       ratingView_q  ratingLike_q  ratingWebsite_q  ratingWebsite_q
# 3119           5.0           5.0              5.0              5.0
# 2003           5.0           5.0              5.0              5.0
# 683            5.0           5.0              5.0              5.0
# 472            5.0           5.0              5.0              5.0
# 3139           5.0           5.0              5.0              5.0
# ...            ...           ...              ...              ...
# 2737           5.0           4.0              4.7              4.7
# 2283           5.0           5.0              5.0              5.0
# 2662           5.0           5.0              5.0              5.0
# 1615           5.0           4.0              4.7              4.7
# 1165           5.0           5.0              5.0              5.0
#
# [1134 rows x 7 columns]

# %%
#ver 1
"""df['finalRating1'] = (((df.ratingNoTweet_q*2) + df.ratingWebsite_q)/3).round(1)
df['finalRating1'].values[df['finalRating1'].values < 1.0] = 1.0

df['finalRating2'] = (((((df.ratingNoTweet_q + df.ratingHashReview_q)/2)*2) + df.ratingWebsite_q)/3).round(1)
df['finalRating2'].values[df['finalRating2'].values < 1.0] = 1.0

df['finalRating3'] = ((df.ratingWebsite_q + (df.ratingTwitter3_q*2))/3).round(1) 
df['finalRating3'].values[df['finalRating3'].values < 1.0] = 1.0

df['finalRating4'] = ((df.ratingWebsite_q + (df.ratingTwitter4_q*2))/3).round(1) 
df['finalRating4'].values[df['finalRating4'].values < 1.0] = 1.0"""

# %%
#ver 2
top = 92.0
w_hReview = 82/top
w_view = 38/top
w_like = 23/top
w_NoTweet = 92/top
w_accReview = 80/top

df['finalRating1'] = ((df.ratingLike_q+df.ratingView_q+df.ratingNoTweet_q)/3).round(1)
df['finalRating1'].values[df['finalRating1'].values < 1.0] = 1.0

df['finalRating1_w'] = (((df.ratingLike_q*w_like)+(df.ratingView_q*w_view)+(df.ratingNoTweet_q*w_NoTweet))/(w_view+w_NoTweet+w_like)).round(1)
df['finalRating1_w'].values[df['finalRating1_w'].values < 1.0] = 1.0

df['finalRating2'] = ((df.ratingLike_q+df.ratingView_q+df.ratingHashReview_q)/3).round(1) 
df['finalRating2'].values[df['finalRating2'].values < 1.0] = 1.0

df['finalRating2_w'] = (((df.ratingLike_q*w_like)+(df.ratingView_q*w_view)+(df.ratingHashReview_q*w_hReview))/(w_view+w_like+w_hReview)).round(1) 
df['finalRating2_w'].values[df['finalRating2_w'].values < 1.0] = 1.0

df['finalRating3'] = ((df.ratingNoTweet_q+df.ratingHashReview_q)/2).round(1) 
df['finalRating3'].values[df['finalRating3'].values < 1.0] = 1.0

df['finalRating3_w'] = (((df.ratingNoTweet_q*w_NoTweet)+(df.ratingHashReview_q*w_hReview))/(w_NoTweet+w_hReview)).round(1) 
df['finalRating3_w'].values[df['finalRating3_w'].values < 1.0] = 1.0

df[['title','viewer','ratingCount','hashtag','ratingView_q','ratingLike_q','ratingNoTweet_q','finalRating1','finalRating1_w','finalRating2','finalRating2_w','finalRating3','finalRating3_w']].sort_values(by='finalRating3_w', ascending  = False)
# Out:
#                                                   title   viewer  ratingCount  \
# 158                   METANOIA #อรุณรุ่ง [Omegaverse Ω]   970488       3924.0
# 1041                      UNKNOWN LOVER #เขาชื่ออันวาร์  1340550       4098.0
# 926              เจ้าชายตัวร้ายพ่ายพายุ #เอื้อเฟื้อพายุ     9833         38.0
# 121                 Real Love #รักแท้ของผมคือคุณ [YAOI]    39288        403.0
# 614   [เปิดให้อ่านถึง 28/01] #บอสข้างบ้าน [สนพ.Hermi...   437404       1804.0
# ...                                                 ...      ...          ...
# 628                            Farewell: ♖คำบอกลาจากผม♖       70          1.0
# 627                             🐇กระต่ายน้อย...แซนซื่อ🐇      105          3.0
# 626              เอาแหละ​ ผมกลายเป็นตัวละครลับในนิยายBL     4534         26.0
# 625                              พระเอกน่ะ ช่างแม่งเถอะ      551          9.0
# 4246                 โอกาสที่ได้ขอใช้ให้ดีที่สุด (YAOI)   171323        179.0
#
#                 hashtag  ratingView_q  ratingLike_q  ratingNoTweet_q  \
# 158            อรุณรุ่ง           5.0           5.0              5.0
# 1041     เขาชื่ออันวาร์           5.0           5.0              5.0
# 926      เอื้อเฟื้อพายุ           4.0           4.0              5.0
# 121   รักแท้ของผมคือคุณ           5.0           5.0              5.0
# 614         บอสข้างบ้าน           5.0           5.0              5.0
# ...                 ...           ...           ...              ...
# 628                 NaN           1.0           1.0              0.0
# 627                 NaN           1.0           2.0              0.0
# 626                 NaN           3.0           4.0              0.0
# 625                 NaN           2.0           3.0              0.0
# 4246                NaN           5.0           5.0              0.0
#
#       finalRating1  finalRating1_w  finalRating2  finalRating2_w  \
# 158            5.0             5.0           5.0             5.0
# 1041           5.0             5.0           5.0             5.0
# 926            4.3             4.6           4.3             4.6
# 121            5.0             5.0           5.0             5.0
# 614            5.0             5.0           5.0             5.0
# ...            ...             ...           ...             ...
# 628            1.0             1.0           1.0             1.0
# 627            1.0             1.0           1.0             1.0
# 626            2.3             1.3           2.3             1.4
# 625            1.7             1.0           1.7             1.0
# 4246           3.3             2.0           3.3             2.1
#
#       finalRating3  finalRating3_w
# 158            5.0             5.0
# 1041           5.0             5.0
# 926            5.0             5.0
# 121            5.0             5.0
# 614            5.0             5.0
# ...            ...             ...
# 628            1.0             1.0
# 627            1.0             1.0
# 626            1.0             1.0
# 625            1.0             1.0
# 4246           1.0             1.0
#
# [5671 rows x 13 columns]

# %%
print(df['pic'])
# Out:
# 0      https://cdn.readawrite.com/articles/1944/19436...
# 1      https://cdn.readawrite.com/articles/1944/19439...
# 2      https://cdn.readawrite.com/articles/1954/19538...
# 3      https://cdn.readawrite.com/articles/1955/19546...
# 4      https://cdn.readawrite.com/articles/1957/19568...
#                              ...
# 376    https://cdn.readawrite.com/articles/307/306990...
# 377    https://cdn.readawrite.com/articles/385/384216...
# 378    https://cdn.readawrite.com/articles/407/406887...
# 379    https://cdn.readawrite.com/articles/390/389457...
# 380    https://cdn.readawrite.com/articles/397/396003...
# Name: pic, Length: 1424, dtype: object

# %%
df[['title','ratingTwitter3_q','ratingTwitter4_q','finalRating1','finalRating2','finalRating3','finalRating4']][df['hashtag'].str.contains('เขาชื่ออันวาร์')]
df[['title','ratingTwitter3_q','ratingTwitter4_q','finalRating1','finalRating2','finalRating3','finalRating4']][df['finalRating4'] >= 4.0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-02b635ec2f0e> in <module>
# ----> 1 df[['title','ratingTwitter3_q','ratingTwitter4_q','finalRating1','finalRating2','finalRating3','finalRating4']][df['hashtag'].str.contains('เขาชื่ออันวาร์')]
#       2 df[['title','ratingTwitter3_q','ratingTwitter4_q','finalRating1','finalRating2','finalRating3','finalRating4']][df['finalRating4'] >= 4.0]
#
# D:\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
#    2910         # take() does not accept boolean indexers
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1252             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1253
# -> 1254         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1255         return keyarr, indexer
#    1256
#
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1302             if raise_missing:
#    1303                 not_found = list(set(key) - set(ax))
# -> 1304                 raise KeyError(f"{not_found} not in index")
#    1305
#    1306             # we skip the warning on Categorical
#
# KeyError: "['finalRating4'] not in index"

# %%
#df.to_csv(r'C:\Users\paton\Pick2ReadData\Rating\rating_v7.csv')
df.dtypes
df
# Out:
#                author                    category commentCount  \
# 0             mplusss  นิยาย Boy Love Secret Room        2,359
# 1        กลิ่นหอมกำจร  นิยาย Boy Love Secret Room           18
# 2           j\'li___.  นิยาย Boy Love Lovely Room            6
# 3            Overrain  นิยาย Boy Love Lovely Room       15,500
# 4       navybroccoli.  นิยาย Boy Love Lovely Room           32
# ...               ...                         ...          ...
# 4242        ควันหมอก.  นิยาย Boy Love Lovely Room            0
# 4243    I\'M WANNABLE  นิยาย Boy Love Lovely Room            4
# 4244  สลอธบนดาวอังคาร  นิยาย Boy Love Secret Room          273
# 4245     Rainpanpunch  นิยาย Boy Love Lovely Room          113
# 4246        Kawwansuk  นิยาย Boy Love Lovely Room          861
#
#                                             description favouriteCount  \
# 0     'เมื่อ 3P มาแบบ 4K พูดได้คำเดียวว่างานนี้ Full...          8,158
# 1     "หลวงพี่จะสึกเมื่อไหร่ครับ" จันทร์หอมเป็นเด็กเ...             78
# 2      Shark#ฉลามอยากกินพืช: นิยาย Boy Love Lovely Room             13
# 3     ความสัมพันธ์เพียงแค่คืนเดียว เปลี่ยนชีวิตของธี...         32,697
# 4                คุณอยากมาดูอควาเรี่ยมตอนเที่ยงคืนมั้ย?             93
# ...                                                 ...            ...
# 4242  **ขออนุญาติเจ้าของภาพ** นิยายเรื่องนี้เป็นเรื่...              0
# 4243   แดนิค:ไอหมูโว้ยยยย!!!!! วี:กูชื่อวีว้อยยยยย!!!!!             12
# 4244  จากลูกบุญธรรมผู้น่ารัก...กลับกลายเป็นสามีของผม...            551
# 4245  Don't speak ความลับที่ผมปิดไว้: นิยาย Boy Love...            207
# 4246  หลังจากแม่เสียชีวิตจากรถชน ชีวิตของภูตะวัน ก็ไ...            732
#
#      isComplete  numOfchap                                                pic  \
# 0            จบ       18.0  https://cdn.readawrite.com/articles/1944/19436...
# 1            จบ        1.0  https://cdn.readawrite.com/articles/1944/19439...
# 2            จบ        2.0  https://cdn.readawrite.com/articles/1954/19538...
# 3            จบ       48.0  https://cdn.readawrite.com/articles/1955/19546...
# 4            จบ        1.0  https://cdn.readawrite.com/articles/1957/19568...
# ...         ...        ...                                                ...
# 4242         จบ        0.0  https://cdn.readawrite.com/articles/388/387286...
# 4243         จบ        0.0  https://cdn.readawrite.com/articles/390/389457...
# 4244         จบ       27.0  https://cdn.readawrite.com/articles/389/388468...
# 4245         จบ       51.0  https://cdn.readawrite.com/articles/391/390900...
# 4246         จบ      150.0  https://cdn.readawrite.com/articles/392/391124...
#
#       ratingCount                                                tag  ...  \
# 0          1051.0  เข้ามาลึกๆ,insert here,Boy Love/Yaoi,18+,20+,น...  ...
# 1             9.0                  18+,Boy Love/Yaoi,นิยายวาย,บาปหนา  ...
# 2             4.0                                                NaN  ...
# 3          5490.0  Boy Love/Yaoi,Mpreg,นิยายวาย,18+,นิยายวายฟีลกู...  ...
# 4            23.0  Midnight aquarium,อควาเรี่ยมเที่ยงคืน,boyslove...  ...
# ...           ...                                                ...  ...
# 4242          0.0                                                NaN  ...
# 4243          4.0                                  Boy Love/Yaoi,18+  ...
# 4244        119.0                                                NaN  ...
# 4245         28.0  Boy Love/Yaoi,18+,SM,ดราม่า,นิยายรัก,นิยายโรแม...  ...
# 4246        179.0                                                NaN  ...
#
#      ratingTwitter4_q  ratingLike_q ratingView_q ratingWebsite_q finalRating1  \
# 0                 1.9           5.0          5.0             5.0          3.8
# 1                 0.0           3.0          2.0             2.3          1.7
# 2                 0.0           2.0          2.0             2.0          1.3
# 3                 2.5           5.0          5.0             5.0          4.2
# 4                 0.0           4.0          3.0             3.3          2.3
# ...               ...           ...          ...             ...          ...
# 4242              0.0           1.0          1.0             1.0          1.0
# 4243              1.9           2.0          2.0             2.0          1.8
# 4244              0.0           5.0          5.0             5.0          3.3
# 4245              0.0           4.0          4.0             4.0          2.7
# 4246              0.0           5.0          5.0             5.0          3.3
#
#       finalRating1_w  finalRating2  finalRating2_w  finalRating3  \
# 0                2.7           4.2             3.6           1.9
# 1                1.0           1.7             1.0           1.0
# 2                1.0           1.3             1.0           1.0
# 3                3.5           4.2             3.6           2.5
# 4                1.3           2.3             1.4           1.0
# ...              ...           ...             ...           ...
# 4242             1.0           1.0             1.0           1.0
# 4243             1.5           2.2             2.3           1.9
# 4244             2.0           3.3             2.1           1.0
# 4245             1.6           2.7             1.7           1.0
# 4246             2.0           3.3             2.1           1.0
#
#       finalRating3_w
# 0                1.8
# 1                1.0
# 2                1.0
# 3                2.5
# 4                1.0
# ...              ...
# 4242             1.0
# 4243             1.8
# 4244             1.0
# 4245             1.0
# 4246             1.0
#
# [5671 rows x 32 columns]
