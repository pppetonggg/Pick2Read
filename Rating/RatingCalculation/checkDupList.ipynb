# %%
import pandas as pd
import numpy as np
import string

import os.path
from os import path
i = 0
count = 0
folder1 = 'C:/Users/paton/Pick2ReadData/Rating/Evaluation' 
#folder2 = 'C:/Users/paton/Pick2ReadData/Rating/Rq_W' 
file1 = os.listdir(folder1)
#file2 = os.listdir(folder2)
print(file1)
# Out:
# ['Eva.csv', 'Ratingrq1_1.csv', 'Ratingrq1_2.csv', 'Ratingrq1_3.csv', 'Ratingrq2_1.csv', 'Ratingrq2_11.csv', 'Ratingrq2_12.csv', 'Ratingrq2_13.csv', 'Ratingrq2_2.csv', 'Ratingrq2_21.csv', 'Ratingrq2_22.csv', 'Ratingrq2_23.csv', 'Ratingrq2_3.csv', 'Ratingrq2_31.csv', 'Ratingrq2_32.csv', 'Ratingrq2_33.csv']

# %%
#df.iloc[[1]] 
listname = []
for i in file1:
    if i.endswith('.csv'):
        namex = os.path.join(folder1,str(i))
        x = i.split(".csv",1)
        x = ''.join(x)
        exec("%s = pd.read_csv('%s')" % (x,namex))
        exec("%s = %s[['title']].head(5)" % (x,x))
        s1 = 'list' + str(x)
        exec("listname.append(s1)")
        exec("%s = %s['title'].tolist()" % (s1,x))

print(len(listname))
print(listname)
l = [listEva,listRatingrq1_1, listRatingrq1_2, listRatingrq1_3, listRatingrq2_1, listRatingrq2_11, listRatingrq2_12, listRatingrq2_13, listRatingrq2_2, listRatingrq2_21, listRatingrq2_22, listRatingrq2_23, listRatingrq2_3, listRatingrq2_31, listRatingrq2_32, listRatingrq2_33]
#l = [listRatingrq1_1w, listRatingrq1_2w, listRatingrq1_3w, listRatingrq2_1w, listRatingrq2_11w, listRatingrq2_12w, listRatingrq2_13w, listRatingrq2_2w, listRatingrq2_21w, listRatingrq2_22w, listRatingrq2_23w, listRatingrq2_3w, listRatingrq2_31w, listRatingrq2_32w, listRatingrq2_33w]

print(len(l))
#l
# Out:
# 16
# ['listEva', 'listRatingrq1_1', 'listRatingrq1_2', 'listRatingrq1_3', 'listRatingrq2_1', 'listRatingrq2_11', 'listRatingrq2_12', 'listRatingrq2_13', 'listRatingrq2_2', 'listRatingrq2_21', 'listRatingrq2_22', 'listRatingrq2_23', 'listRatingrq2_3', 'listRatingrq2_31', 'listRatingrq2_32', 'listRatingrq2_33']
# 16

# %%
l[0]==l[1]
listRatingrq1_1
# Out:
# ['องค์ชายสามช่างไม่เอาไหน (สนพ.ฟาไฉ)',
#  'ชายาข้า ใครบังอาจหาญกล้ามาแตะ!!!',
#  '(omegaverse) midnight fortune #อย่าบอกป๊านะม๊า',
#  'มหาลัยครึ่งมนุษย์ (ebook)',
#  'เหนือมังกร เคียงบัลลังก์(สนพ.บ้านวายบุ๊ค)']

# %%
listRatingrq2_3
# Out:
# ['Thanks For You รู้แล้วว่ารัก (Franzis X Renny)',
#  'ต้นหนชลธี (set4ตัว100) [สนพ.Deep publishing]',
#  'ค่อยๆ รัก | #เจ๋งพัท',
#  'Your Sky #กี่หมื่นฟ้า',
#  '#ก็จะดื้อ (omegaverse)',
#  'UNKNOWN LOVER #เขาชื่ออันวาร์',
#  'yaoi | เกมเมอร์และน้องเด๋อของเขา #ซอโซ่ล่ามธีร์',
#  'ก็เมียผมเด็ด #สาววาย',
#  '{ yaoi } • One and Only หวนกลิ่นรัก',
#  'รัตติจันทร์พันกร : ( Mpreg )']

# %%
for x in range(len(l)):
    for y in range(len(l)):
        if l[x] == l[y] and listname[x] != listname[y]: 
            print(listname[x] + " equal to " + listname[y])
# Out:
# listRatingrq2_22 equal to listRatingrq2_23
# listRatingrq2_23 equal to listRatingrq2_22
# listRatingrq2_3 equal to listRatingrq2_31
# listRatingrq2_31 equal to listRatingrq2_3

# %%
listRating101[4002]
# Out:
# 'Yours (ของคุณ) (มีหนังสือ พร้อมส่ง)'

# %%
listRating102[4002]
# Out:
# 'Yours (ของคุณ) (มีหนังสือ พร้อมส่ง)'

# %%
for x in range(len(listRatingrq1_3)):
    for y in range(len(listRatingrq1_1)):
        if listRatingrq1_3[x] == listRatingrq1_1[y]:
            print(y)
            print(listRatingrq1_1[y])
            #print(listRatingrq1_3[x])
#listRating102[4508]
# Out:
# 0
# องค์ชายสามช่างไม่เอาไหน (สนพ.ฟาไฉ)
# องค์ชายสามช่างไม่เอาไหน (สนพ.ฟาไฉ)
# 1
# ชายาข้า ใครบังอาจหาญกล้ามาแตะ!!!
# ชายาข้า ใครบังอาจหาญกล้ามาแตะ!!!
# 2
# (omegaverse) midnight fortune #อย่าบอกป๊านะม๊า
# (omegaverse) midnight fortune #อย่าบอกป๊านะม๊า
# 3
# The time to kill \"เกมรักอำมหิต\"
# The time to kill \"เกมรักอำมหิต\"
# 4
# สามี ข้าจะปกป้องท่านเอง!(สนพ.บ้านวายบุ๊ค)
# สามี ข้าจะปกป้องท่านเอง!(สนพ.บ้านวายบุ๊ค)
# 5
# มหาลัยครึ่งมนุษย์ (ebook)
# มหาลัยครึ่งมนุษย์ (ebook)
# 6
# Eye Contact \"เพียงสบตา\"
# Eye Contact \"เพียงสบตา\"
# 7
# ชมรมนี้ผู้จัดการ ‘SEX’ เก่ง
# ชมรมนี้ผู้จัดการ ‘SEX’ เก่ง
# 9
# เหนือมังกร เคียงบัลลังก์(สนพ.บ้านวายบุ๊ค)
# เหนือมังกร เคียงบัลลังก์(สนพ.บ้านวายบุ๊ค)
# 8
# [นิยายแปล] ผมแต่งงานกับเจ้าสัวยังหนุ่ม : Second Marriage of a Wealthy Old Man
# [นิยายแปล] ผมแต่งงานกับเจ้าสัวยังหนุ่ม : Second Marriage of a Wealthy Old Man

# %%
for x in range(len(listRating101)):
    for y in range(len(listRating102)):
        if listRating101[x] != listRating102[y] and x != y : 
            print(l[y])
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-58-fcf72d255006> in <module>
#       2     for y in range(len(listRating102)):
#       3         if listRating101[x] != listRating102[y] and x != y :
# ----> 4             print(l[y])
#
# IndexError: list index out of range
